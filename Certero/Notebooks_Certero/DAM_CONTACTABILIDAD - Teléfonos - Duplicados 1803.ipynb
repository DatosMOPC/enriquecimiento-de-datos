# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Insiders/Datasets/Datos duplicados/Insiders_telefonos_1803_duplicados.csv')

# %%
df.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 1  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 2  DNI 4171534             DNI  4171534  27041715346  TEL.CELULAR  PERSONAL
# 3  RMS379977155103007      DNI  4173550  20041735504     TEL.FIJO  PERSONAL
# 4  RMS379977155103007      DNI  4173550  20041735504  TEL.CELULAR  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  1142089570           Propio             AD  2021-03-18 12:25:51.840208
# 1  1146871791           Propio             AD  2021-03-18 12:25:51.840208
# 2  1161078686           Propio             AD  2021-03-18 12:25:51.840208
# 3  1143729113           Propio             AD  2021-03-18 12:25:51.840208
# 4  1136028479           Propio             AD  2021-03-18 12:25:51.840208
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         2.0
# 2           0                 NaN                    NaN         2.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0

# %%
df.shape
# Out:
# (1913, 14)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1913, 14)

# %% [markdown]
# ## Dato a str + strip()

# %%
df ['DATO'] = df['DATO'].astype(str)

# %%
df['DATO'] = df['DATO'].str.strip()

# %% [markdown]
# ## Verificados

# %% [markdown]
# Si verificado es false, pasamos a NaN la fecha de verificación

# %%
df.loc[df['VERIFICADO'] == 0, 'FECHA_VERIFICACION'] = np.nan

# %%
df.tail()
# Out:
#                 IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL      TIPO   SUBTIPO  \
# 1908  DNI 41853840            DNI  41853840  27418538401  TEL.FIJO  PERSONAL
# 1909  DNI 43311146            DNI  43311146  27433111465  TEL.FIJO  PERSONAL
# 1910  DNIE92972790            DNI  92972790  20929727909  TEL.FIJO  PERSONAL
# 1911  DNIE94300255            DNI  94300255  27943002555  TEL.FIJO  PERSONAL
# 1912  DNIE94671953            DNI  94671953  27946719531  TEL.FIJO  PERSONAL
#
#             DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 1908  2234825816            Ajeno             AD  2021-03-18 12:25:51.840208
# 1909  1142713468            Ajeno             AD  2021-03-18 12:25:51.840208
# 1910  1142729071            Ajeno             AD  2021-03-18 12:25:51.840208
# 1911  1145561719            Ajeno             AD  2021-03-18 12:25:51.840208
# 1912  2974999396            Ajeno             AD  2021-03-18 12:25:51.840208
#
#       VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 1908           0                 NaN                    NaN         2.0
# 1909           0                 NaN                    NaN         2.0
# 1910           0                 NaN                    NaN         2.0
# 1911           0                 NaN                    NaN         2.0
# 1912           0                 NaN                    NaN         2.0

# %% [markdown]
# # Subset: Duplicados

# %% [markdown]
# Me quedo con los todos los que tienen duplicados la combinatoria IDMOROSO, DATO y PROVEEDOR DATO, y reviso qué pasa en cada caso

# %%
duplicates_subset = df[df.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
duplicates_subset.head()
# Out:
#               IDMOROSO TIPO_DOC  NRO_DOC    CUIT_CUIL      TIPO   SUBTIPO  \
# 7   DNI 4553548             DNI  4553548  27045535482  TEL.FIJO  PERSONAL
# 10  DNI 4553548             DNI  4553548  27045535482  TEL.FIJO  PERSONAL
# 16  RMS376710296861008      DNI  5255032  27052550322  TEL.FIJO  PERSONAL
# 17  RMS376710296861008      DNI  5255032  27052550322  TEL.FIJO  PERSONAL
# 18  DNI 5592216             DNI  5592216  27055922166  TEL.FIJO  PERSONAL
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 7   1142275223           Propio             AD  2021-03-18 12:25:51.840208
# 10  1142275223   Ajeno_familiar             AD  2021-03-18 12:25:51.840208
# 16  1147745633           Propio             AD  2021-03-18 12:25:51.840208
# 17  1147745633   Ajeno_familiar             AD  2021-03-18 12:25:51.840208
# 18  1144623807           Propio             AD  2021-03-18 12:25:51.840208
#
#     VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 7            0                 NaN                    NaN         2.0
# 10           0                 NaN                    NaN         2.0
# 16           0                 NaN                    NaN         2.0
# 17           0                 NaN                    NaN         2.0
# 18           0                 NaN                    NaN         2.0

# %%
duplicates_subset.shape
# Out:
# (234, 14)

# %%
#duplicates_subset[duplicates_subset['VERIFICADO'] == True]

# %% [markdown]
# # 1. Puntajes

# %% [markdown]
# Asignamos puntajes a cada posible dato que aparezca en las categorías:
#
# - Tipo.
# - Subtipo.
# - Propietario
# - Verificación

# %%
duplicates_subset.loc[duplicates_subset['VERIFICADO'] == 1, 'PUNTAJE_VERIFICADO'] = 6
# Out:
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
duplicates_subset.loc[duplicates_subset['VERIFICADO'] == 0, 'PUNTAJE_VERIFICADO'] = 0
# Out:
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
duplicates_subset.loc[duplicates_subset['PROPIETARIO_DATO'] == 'Propio', 'PUNTAJE_PROPIETARIO'] = 5
# Out:
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)

# %%
duplicates_subset.loc[duplicates_subset['PROPIETARIO_DATO'] == 'Ajeno_familiar', 'PUNTAJE_PROPIETARIO'] = 4

# %%
duplicates_subset.loc[duplicates_subset['PROPIETARIO_DATO'] == 'Ajeno_empleador', 'PUNTAJE_PROPIETARIO'] = 3

# %%
duplicates_subset.loc[duplicates_subset['PROPIETARIO_DATO'] == 'Ajeno', 'PUNTAJE_PROPIETARIO'] = 2

# %%
duplicates_subset.loc[duplicates_subset['SUBTIPO'] == 'PERSONAL', 'PUNTAJE_TIPO'] = 2

# %%
duplicates_subset.loc[duplicates_subset['SUBTIPO'] == 'LABORAL', 'PUNTAJE_TIPO'] = 0

# %%
duplicates_subset.loc[duplicates_subset['TIPO'] == 'EMAIL', 'PUNTAJE_SUBTIPO'] = 4

# %%
duplicates_subset.loc[duplicates_subset['TIPO'] == 'TEL.FIJO', 'PUNTAJE_SUBTIPO'] = 2

# %%
duplicates_subset.loc[duplicates_subset['TIPO'] == 'TEL.CELULAR', 'PUNTAJE_SUBTIPO'] = 4

# %% [markdown]
# ## Suma de Puntajes

# %%
columns_to_sum = ['PUNTAJE_VERIFICADO','PUNTAJE_PROPIETARIO','PUNTAJE_TIPO','PUNTAJE_SUBTIPO']

# %%
duplicates_subset['PUNTAJE_TOTAL'] = duplicates_subset[columns_to_sum].sum(axis=1)
# Out:
# <ipython-input-27-0ec8c926888a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_subset['PUNTAJE_TOTAL'] = duplicates_subset[columns_to_sum].sum(axis=1)

# %%
duplicates_subset.head()
# Out:
#               IDMOROSO TIPO_DOC  NRO_DOC    CUIT_CUIL      TIPO   SUBTIPO  \
# 7   DNI 4553548             DNI  4553548  27045535482  TEL.FIJO  PERSONAL
# 10  DNI 4553548             DNI  4553548  27045535482  TEL.FIJO  PERSONAL
# 16  RMS376710296861008      DNI  5255032  27052550322  TEL.FIJO  PERSONAL
# 17  RMS376710296861008      DNI  5255032  27052550322  TEL.FIJO  PERSONAL
# 18  DNI 5592216             DNI  5592216  27055922166  TEL.FIJO  PERSONAL
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 7   1142275223           Propio             AD  2021-03-18 12:25:51.840208
# 10  1142275223   Ajeno_familiar             AD  2021-03-18 12:25:51.840208
# 16  1147745633           Propio             AD  2021-03-18 12:25:51.840208
# 17  1147745633   Ajeno_familiar             AD  2021-03-18 12:25:51.840208
# 18  1144623807           Propio             AD  2021-03-18 12:25:51.840208
#
#     VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO  \
# 7            0                 NaN                    NaN         2.0
# 10           0                 NaN                    NaN         2.0
# 16           0                 NaN                    NaN         2.0
# 17           0                 NaN                    NaN         2.0
# 18           0                 NaN                    NaN         2.0
#
#     PUNTAJE_VERIFICADO  PUNTAJE_PROPIETARIO  PUNTAJE_TIPO  PUNTAJE_SUBTIPO  \
# 7                  0.0                  5.0           2.0              2.0
# 10                 0.0                  4.0           2.0              2.0
# 16                 0.0                  5.0           2.0              2.0
# 17                 0.0                  4.0           2.0              2.0
# 18                 0.0                  5.0           2.0              2.0
#
#     PUNTAJE_TOTAL
# 7             9.0
# 10            8.0
# 16            9.0
# 17            8.0
# 18            9.0

# %%
duplicates_subset.shape
# Out:
# (234, 19)

# %%
df
# Out:
#                 IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO  \
# 0     DNI 4171534             DNI   4171534  27041715346     TEL.FIJO
# 1     DNI 4171534             DNI   4171534  27041715346     TEL.FIJO
# 2     DNI 4171534             DNI   4171534  27041715346  TEL.CELULAR
# 3     RMS379977155103007      DNI   4173550  20041735504     TEL.FIJO
# 4     RMS379977155103007      DNI   4173550  20041735504  TEL.CELULAR
# ...                  ...      ...       ...          ...          ...
# 1908  DNI 41853840            DNI  41853840  27418538401     TEL.FIJO
# 1909  DNI 43311146            DNI  43311146  27433111465     TEL.FIJO
# 1910  DNIE92972790            DNI  92972790  20929727909     TEL.FIJO
# 1911  DNIE94300255            DNI  94300255  27943002555     TEL.FIJO
# 1912  DNIE94671953            DNI  94671953  27946719531     TEL.FIJO
#
#        SUBTIPO        DATO PROPIETARIO_DATO PROVEEDOR_DATO  \
# 0     PERSONAL  1142089570           Propio             AD
# 1     PERSONAL  1146871791           Propio             AD
# 2     PERSONAL  1161078686           Propio             AD
# 3     PERSONAL  1143729113           Propio             AD
# 4     PERSONAL  1136028479           Propio             AD
# ...        ...         ...              ...            ...
# 1908  PERSONAL  2234825816            Ajeno             AD
# 1909  PERSONAL  1142713468            Ajeno             AD
# 1910  PERSONAL  1142729071            Ajeno             AD
# 1911  PERSONAL  1145561719            Ajeno             AD
# 1912  PERSONAL  2974999396            Ajeno             AD
#
#               FECHA_INGRESO_DATO  VERIFICADO  FECHA_VERIFICACION  \
# 0     2021-03-18 12:25:51.840208           0                 NaN
# 1     2021-03-18 12:25:51.840208           0                 NaN
# 2     2021-03-18 12:25:51.840208           0                 NaN
# 3     2021-03-18 12:25:51.840208           0                 NaN
# 4     2021-03-18 12:25:51.840208           0                 NaN
# ...                          ...         ...                 ...
# 1908  2021-03-18 12:25:51.840208           0                 NaN
# 1909  2021-03-18 12:25:51.840208           0                 NaN
# 1910  2021-03-18 12:25:51.840208           0                 NaN
# 1911  2021-03-18 12:25:51.840208           0                 NaN
# 1912  2021-03-18 12:25:51.840208           0                 NaN
#
#       OPERADOR_VERIFICACION  SCORE_DATO
# 0                       NaN         2.0
# 1                       NaN         2.0
# 2                       NaN         2.0
# 3                       NaN         2.0
# 4                       NaN         2.0
# ...                     ...         ...
# 1908                    NaN         2.0
# 1909                    NaN         2.0
# 1910                    NaN         2.0
# 1911                    NaN         2.0
# 1912                    NaN         2.0
#
# [1913 rows x 14 columns]

# %% [markdown]
# ## Agrupo

# %%
#duplicates_subset['ID'] = duplicates_subset['ID'].astype(str)

# %%
df_best = duplicates_subset.groupby(['IDMOROSO','DATO','PROVEEDOR_DATO'], as_index = False).max(numeric_only=True)

# %%
df_best
# Out:
#                IDMOROSO        DATO PROVEEDOR_DATO   NRO_DOC    CUIT_CUIL  \
# 0    DNI 10605197        1146861823             AD  10605197  20106051977
# 1    DNI 11465214        3424892833             AD  11465214  20114652149
# 2    DNI 12937737        1141757819             AD  12937737  20129377373
# 3    DNI 14095164        1142494483             AD  14095164  20140951642
# 4    DNI 16571979        2374627166             AD  16571979  23165719794
# ..                  ...         ...            ...       ...          ...
# 110  RMS376688790431009  1144680256             AD   7698616  23076986169
# 111  RMS376710296861008  1147745633             AD   5255032  27052550322
# 112  RMS376710889232005  3462431846             AD  18433456  23184334569
# 113  RMS376711042492007  1147626691             AD  92545935  20925459357
# 114  RMS379975022111005  1156261111             AD  17824698  23178246984
#
#      VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO  \
# 0             0                 NaN                    NaN         2.0
# 1             0                 NaN                    NaN         2.0
# 2             0                 NaN                    NaN         2.0
# 3             0                 NaN                    NaN         2.0
# 4             0                 NaN                    NaN         2.0
# ..          ...                 ...                    ...         ...
# 110           0                 NaN                    NaN         2.0
# 111           0                 NaN                    NaN         2.0
# 112           0                 NaN                    NaN         2.0
# 113           0                 NaN                    NaN         2.0
# 114           0                 NaN                    NaN         2.0
#
#      PUNTAJE_VERIFICADO  PUNTAJE_PROPIETARIO  PUNTAJE_TIPO  PUNTAJE_SUBTIPO  \
# 0                   0.0                  5.0           2.0              2.0
# 1                   0.0                  5.0           2.0              2.0
# 2                   0.0                  5.0           2.0              4.0
# 3                   0.0                  5.0           2.0              2.0
# 4                   0.0                  5.0           2.0              2.0
# ..                  ...                  ...           ...              ...
# 110                 0.0                  5.0           2.0              2.0
# 111                 0.0                  5.0           2.0              2.0
# 112                 0.0                  5.0           2.0              2.0
# 113                 0.0                  5.0           2.0              2.0
# 114                 0.0                  5.0           2.0              4.0
#
#      PUNTAJE_TOTAL
# 0              9.0
# 1              9.0
# 2             11.0
# 3              9.0
# 4              9.0
# ..             ...
# 110            9.0
# 111            9.0
# 112            9.0
# 113            9.0
# 114           11.0
#
# [115 rows x 14 columns]

# %% [markdown]
# # Join

# %%
df_joined = pd.merge(duplicates_subset,df_best,on=['IDMOROSO','DATO','PROVEEDOR_DATO','PUNTAJE_TOTAL'])

# %%
df_joined.shape
# Out:
# (115, 29)

# %%
df_joined.head(10)
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC_x  CUIT_CUIL_x      TIPO   SUBTIPO  \
# 0  DNI 4553548             DNI    4553548  27045535482  TEL.FIJO  PERSONAL
# 1  RMS376710296861008      DNI    5255032  27052550322  TEL.FIJO  PERSONAL
# 2  DNI 5592216             DNI    5592216  27055922166  TEL.FIJO  PERSONAL
# 3  DNI 6409139             DNI    6409139  27064091390  TEL.FIJO  PERSONAL
# 4  RMS376688790431009      DNI    7698616  23076986169  TEL.FIJO  PERSONAL
# 5  RMS376413535023007      DNI    8273973  20082739735  TEL.FIJO  PERSONAL
# 6  RMS376635010093002      DNI    8273973  20082739735  TEL.FIJO  PERSONAL
# 7  DNI 10605197            DNI   10605197  20106051977  TEL.FIJO  PERSONAL
# 8  RMS376636725322009      DNI   10678367  20106783676  TEL.FIJO  PERSONAL
# 9  DNI 11465214            DNI   11465214  20114652149  TEL.FIJO  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  1142275223           Propio             AD  2021-03-18 12:25:51.840208
# 1  1147745633           Propio             AD  2021-03-18 12:25:51.840208
# 2  1144623807           Propio             AD  2021-03-18 12:25:51.840208
# 3  1146350323           Propio             AD  2021-03-18 12:25:51.840208
# 4  1144680256           Propio             AD  2021-03-18 12:25:51.840208
# 5  1147389014           Propio             AD  2021-03-18 12:25:51.840208
# 6  1147389014           Propio             AD  2021-03-18 12:25:51.840208
# 7  1146861823           Propio             AD  2021-03-18 12:25:51.840208
# 8  1142364303           Propio             AD  2021-03-18 12:25:51.840208
# 9  3424892833           Propio             AD  2021-03-18 12:25:51.840208
#
#    ...  NRO_DOC_y  CUIT_CUIL_y  VERIFICADO_y  FECHA_VERIFICACION_y  \
# 0  ...    4553548  27045535482             0                   NaN
# 1  ...    5255032  27052550322             0                   NaN
# 2  ...    5592216  27055922166             0                   NaN
# 3  ...    6409139  27064091390             0                   NaN
# 4  ...    7698616  23076986169             0                   NaN
# 5  ...    8273973  20082739735             0                   NaN
# 6  ...    8273973  20082739735             0                   NaN
# 7  ...   10605197  20106051977             0                   NaN
# 8  ...   10678367  20106783676             0                   NaN
# 9  ...   11465214  20114652149             0                   NaN
#
#    OPERADOR_VERIFICACION_y  SCORE_DATO_y  PUNTAJE_VERIFICADO_y  \
# 0                      NaN           2.0                   0.0
# 1                      NaN           2.0                   0.0
# 2                      NaN           2.0                   0.0
# 3                      NaN           2.0                   0.0
# 4                      NaN           2.0                   0.0
# 5                      NaN           2.0                   0.0
# 6                      NaN           2.0                   0.0
# 7                      NaN           2.0                   0.0
# 8                      NaN           2.0                   0.0
# 9                      NaN           2.0                   0.0
#
#    PUNTAJE_PROPIETARIO_y  PUNTAJE_TIPO_y  PUNTAJE_SUBTIPO_y
# 0                    5.0             2.0                2.0
# 1                    5.0             2.0                2.0
# 2                    5.0             2.0                2.0
# 3                    5.0             2.0                2.0
# 4                    5.0             2.0                2.0
# 5                    5.0             2.0                2.0
# 6                    5.0             2.0                2.0
# 7                    5.0             2.0                2.0
# 8                    5.0             2.0                2.0
# 9                    5.0             2.0                2.0
#
# [10 rows x 29 columns]

# %% [markdown]
# # Duplicados con diferentes fechas de ingreso

# %%
duplicates_fecha = df_joined[df_joined.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
duplicates_fecha = duplicates_fecha.sort_values('FECHA_INGRESO_DATO').drop_duplicates('IDMOROSO',keep='first')

# %% [markdown]
# # Append

# %%
df_joined = df_joined[['IDMOROSO','TIPO_DOC','NRO_DOC_x','CUIT_CUIL_x','TIPO','SUBTIPO','DATO','PROPIETARIO_DATO'
                               ,'PROVEEDOR_DATO','FECHA_INGRESO_DATO','VERIFICADO_x','FECHA_VERIFICACION_x'
                               ,'OPERADOR_VERIFICACION_x','SCORE_DATO_x']]

# %%
df_joined.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC_x  CUIT_CUIL_x      TIPO   SUBTIPO  \
# 0  DNI 4553548             DNI    4553548  27045535482  TEL.FIJO  PERSONAL
# 1  RMS376710296861008      DNI    5255032  27052550322  TEL.FIJO  PERSONAL
# 2  DNI 5592216             DNI    5592216  27055922166  TEL.FIJO  PERSONAL
# 3  DNI 6409139             DNI    6409139  27064091390  TEL.FIJO  PERSONAL
# 4  RMS376688790431009      DNI    7698616  23076986169  TEL.FIJO  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  1142275223           Propio             AD  2021-03-18 12:25:51.840208
# 1  1147745633           Propio             AD  2021-03-18 12:25:51.840208
# 2  1144623807           Propio             AD  2021-03-18 12:25:51.840208
# 3  1146350323           Propio             AD  2021-03-18 12:25:51.840208
# 4  1144680256           Propio             AD  2021-03-18 12:25:51.840208
#
#    VERIFICADO_x  FECHA_VERIFICACION_x  OPERADOR_VERIFICACION_x  SCORE_DATO_x
# 0             0                   NaN                      NaN           2.0
# 1             0                   NaN                      NaN           2.0
# 2             0                   NaN                      NaN           2.0
# 3             0                   NaN                      NaN           2.0
# 4             0                   NaN                      NaN           2.0

# %%
df_joined.shape
# Out:
# (115, 14)

# %%
df_joined = df_joined.rename(columns={"VERIFICADO_x": "VERIFICADO", "SCORE_DATO_x": "SCORE_DATO"
                                     ,'NRO_DOC_x': 'NRO_DOC','CUIT_CUIL_x':'CUIT_CUIL'
                                     ,'FECHA_VERIFICACION_x':'FECHA_VERIFICACION'})

# %%
df_joined = df_joined[~df_joined.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
df_joined.shape
# Out:
# (115, 14)

# %%
duplicates_fecha = duplicates_fecha[['IDMOROSO','TIPO_DOC','NRO_DOC_x','CUIT_CUIL_x','TIPO','SUBTIPO','DATO','PROPIETARIO_DATO'
                               ,'PROVEEDOR_DATO','FECHA_INGRESO_DATO','VERIFICADO_x','FECHA_VERIFICACION_x'
                               ,'OPERADOR_VERIFICACION_x','SCORE_DATO_x']]

# %%
duplicates_fecha.shape
# Out:
# (0, 14)

# %%
duplicates_fecha = duplicates_fecha.rename(columns={"VERIFICADO_x": "VERIFICADO", "SCORE_DATO_x": "SCORE_DATO"})

# %% [markdown]
# Dataframe inicial sin los duplicados

# %%
df.shape
# Out:
# (1913, 14)

# %%
non_duplicates = df[~df.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
non_duplicates.shape
# Out:
# (1679, 14)

# %% [markdown]
# Unimos los 3 dataframes y revisamos que no haya duplicados en el mismo subset IDMOROSO-DATO-PROVEEDOR

# %%
non_duplicates = non_duplicates.dropna(subset=['DATO'])

# %%
non_duplicates [non_duplicates['NRO_DOC'].isnull()]
# Out:
# Empty DataFrame
# Columns: [IDMOROSO, TIPO_DOC, NRO_DOC, CUIT_CUIL, TIPO, SUBTIPO, DATO, PROPIETARIO_DATO, PROVEEDOR_DATO, FECHA_INGRESO_DATO, VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, SCORE_DATO]
# Index: []

# %%
non_duplicates.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 1  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 2  DNI 4171534             DNI  4171534  27041715346  TEL.CELULAR  PERSONAL
# 3  RMS379977155103007      DNI  4173550  20041735504     TEL.FIJO  PERSONAL
# 4  RMS379977155103007      DNI  4173550  20041735504  TEL.CELULAR  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  1142089570           Propio             AD  2021-03-18 12:25:51.840208
# 1  1146871791           Propio             AD  2021-03-18 12:25:51.840208
# 2  1161078686           Propio             AD  2021-03-18 12:25:51.840208
# 3  1143729113           Propio             AD  2021-03-18 12:25:51.840208
# 4  1136028479           Propio             AD  2021-03-18 12:25:51.840208
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         2.0
# 2           0                 NaN                    NaN         2.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0

# %% [markdown]
# **SÓLO** concateno estos dos porque DUPLICATES_FECHA tiene nulls. Sino, hay que concatenar todos.

# %%
#df_export = pd.concat([non_duplicates,df_joined,duplicates_fecha])
df_export = pd.concat([non_duplicates,df_joined])

# %%
df_export.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 1  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 2  DNI 4171534             DNI  4171534  27041715346  TEL.CELULAR  PERSONAL
# 3  RMS379977155103007      DNI  4173550  20041735504     TEL.FIJO  PERSONAL
# 4  RMS379977155103007      DNI  4173550  20041735504  TEL.CELULAR  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  1142089570           Propio             AD  2021-03-18 12:25:51.840208
# 1  1146871791           Propio             AD  2021-03-18 12:25:51.840208
# 2  1161078686           Propio             AD  2021-03-18 12:25:51.840208
# 3  1143729113           Propio             AD  2021-03-18 12:25:51.840208
# 4  1136028479           Propio             AD  2021-03-18 12:25:51.840208
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO  \
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         2.0
# 2           0                 NaN                    NaN         2.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0
#
#    OPERADOR_VERIFICACION_x
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df_export.shape
# Out:
# (1794, 15)

# %% [markdown]
# # QA Duplicados

# %%
qa_duplicados = df_export[df_export.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
qa_duplicados
# Out:
# Empty DataFrame
# Columns: [IDMOROSO, TIPO_DOC, NRO_DOC, CUIT_CUIL, TIPO, SUBTIPO, DATO, PROPIETARIO_DATO, PROVEEDOR_DATO, FECHA_INGRESO_DATO, VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, SCORE_DATO, OPERADOR_VERIFICACION_x]
# Index: []

# %%
df_export.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 1  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 2  DNI 4171534             DNI  4171534  27041715346  TEL.CELULAR  PERSONAL
# 3  RMS379977155103007      DNI  4173550  20041735504     TEL.FIJO  PERSONAL
# 4  RMS379977155103007      DNI  4173550  20041735504  TEL.CELULAR  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  1142089570           Propio             AD  2021-03-18 12:25:51.840208
# 1  1146871791           Propio             AD  2021-03-18 12:25:51.840208
# 2  1161078686           Propio             AD  2021-03-18 12:25:51.840208
# 3  1143729113           Propio             AD  2021-03-18 12:25:51.840208
# 4  1136028479           Propio             AD  2021-03-18 12:25:51.840208
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO  \
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         2.0
# 2           0                 NaN                    NaN         2.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0
#
#    OPERADOR_VERIFICACION_x
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df_export['VERIFICADO'].value_counts()
# Out:
# 0    1794
# Name: VERIFICADO, dtype: int64

# %%
non_duplicates['VERIFICADO'].value_counts()
# Out:
# 0    1679
# Name: VERIFICADO, dtype: int64

# %%
df_joined['VERIFICADO'].value_counts()
# Out:
# 0    115
# Name: VERIFICADO, dtype: int64

# %%
duplicates_fecha['VERIFICADO'].value_counts()
# Out:
# Series([], Name: VERIFICADO, dtype: int64)

# %% [markdown]
# # Export a DAM_CONTACTABILIDAD

# %%
df_export = df_export[['IDMOROSO', 'TIPO_DOC','NRO_DOC','CUIT_CUIL','TIPO','SUBTIPO','DATO','PROPIETARIO_DATO','PROVEEDOR_DATO','FECHA_INGRESO_DATO','VERIFICADO','FECHA_VERIFICACION','OPERADOR_VERIFICACION','SCORE_DATO']]

# %%
df_export.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 1  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 2  DNI 4171534             DNI  4171534  27041715346  TEL.CELULAR  PERSONAL
# 3  RMS379977155103007      DNI  4173550  20041735504     TEL.FIJO  PERSONAL
# 4  RMS379977155103007      DNI  4173550  20041735504  TEL.CELULAR  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  1142089570           Propio             AD  2021-03-18 12:25:51.840208
# 1  1146871791           Propio             AD  2021-03-18 12:25:51.840208
# 2  1161078686           Propio             AD  2021-03-18 12:25:51.840208
# 3  1143729113           Propio             AD  2021-03-18 12:25:51.840208
# 4  1136028479           Propio             AD  2021-03-18 12:25:51.840208
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         2.0
# 2           0                 NaN                    NaN         2.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0

# %%
df_export.to_csv('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Insiders/Exports/DAM_CONTACTABILIDAD/DAM_CONTACTABILIDAD_TELEFONOS_1803.csv',index=False)
