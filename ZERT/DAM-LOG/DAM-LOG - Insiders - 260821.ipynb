# %%
import pandas as pd
import numpy as np
import sys
from datetime import datetime, date

sys.path.append("/home/tetotille/Escritorio/MOPC/enriquecimiento")

# %% [markdown]
# # LOG

# %% [markdown]
# # 1. Datos enviados

# %%
df_log = pd.read_csv("../Datos_Enriquecimiento.csv")
df_log.head()
# Out:
#           IDMOROSO                                    NOMBRE  \
# 0     CI  62933702  JOSE LUIS,FERNANDEZ FERNANDEZ
# 1  CUIT30607032978  ,MARCOS FERNANDEZ SRL
# 2  CUIT30698087648  ,ITACUA CONSTRUCCIONES SRL
# 3  CUIT30703557674  ,IONES COMUNICACIONES SRL
# 4  CUIT30707047085  ,PATER SHOW SRL
#
#               IDCLIENTE                ESTADO               FILTROA  \
# 0  BSR_TARDIA            EN GESTION_PORTAL     Campana Extrajud Emp
# 1  BSR_TARDIA            EN GESTION_PORTAL     Campana Extrajud Emp
# 2  BSR_TARDIA            NO UBICADO            Campana Extrajud Emp
# 3  BSR_TARDIA            NO UBICADO            Campana Extrajud Emp
# 4  BSR_TARDIA            NO UBICADO            Campana Extrajud Emp
#
#                          DATOADIC    DOCUMENTO  TIPO
# 0                                   CI62933702  CUIT
# 1  30607032978                     30607032978  CUIT
# 2  30698087648                     30698087648  CUIT
# 3  30703557674                     30703557674  CUIT
# 4  30707047085                     30707047085  CUIT

# %%
df_log.head()
# Out:
#           IDMOROSO                                    NOMBRE  \
# 0     CI  62933702  JOSE LUIS,FERNANDEZ FERNANDEZ
# 1  CUIT30607032978  ,MARCOS FERNANDEZ SRL
# 2  CUIT30698087648  ,ITACUA CONSTRUCCIONES SRL
# 3  CUIT30703557674  ,IONES COMUNICACIONES SRL
# 4  CUIT30707047085  ,PATER SHOW SRL
#
#               IDCLIENTE                ESTADO               FILTROA  \
# 0  BSR_TARDIA            EN GESTION_PORTAL     Campana Extrajud Emp
# 1  BSR_TARDIA            EN GESTION_PORTAL     Campana Extrajud Emp
# 2  BSR_TARDIA            NO UBICADO            Campana Extrajud Emp
# 3  BSR_TARDIA            NO UBICADO            Campana Extrajud Emp
# 4  BSR_TARDIA            NO UBICADO            Campana Extrajud Emp
#
#                          DATOADIC    DOCUMENTO  TIPO
# 0                                   CI62933702  CUIT
# 1  30607032978                     30607032978  CUIT
# 2  30698087648                     30698087648  CUIT
# 3  30703557674                     30703557674  CUIT
# 4  30707047085                     30707047085  CUIT

# %%
df_log = df_log.rename(columns={"ESTADO": "ESTADO_ANTERIOR"})

# %%
df_log = df_log [['IDMOROSO','DATOADIC','IDCLIENTE','ESTADO_ANTERIOR']]
#df_log = df_log [['IDMOROSO','IDCLIENTE','ESTADO_ANTERIOR']]

# %%
fecha_envio_log = '2021-08-26'

# %%
fecha_insercion_log = '2021-08-27'

# %%
fecha_estados_log = '2021-08-31'

# %%
df_log = df_log.assign(FECHA_ENVIO_ENRIQUECIMIENTO=fecha_envio_log)

# %%
df_log = df_log.assign(FECHA_INSERCION_DATO=fecha_insercion_log)

# %%
df_log = df_log.assign(FECHA_CAMBIO_ESTADO=fecha_estados_log)

# %%
df_log.head()
# Out:
#           IDMOROSO                        DATOADIC             IDCLIENTE  \
# 0     CI  62933702                                  BSR_TARDIA
# 1  CUIT30607032978  30607032978                     BSR_TARDIA
# 2  CUIT30698087648  30698087648                     BSR_TARDIA
# 3  CUIT30703557674  30703557674                     BSR_TARDIA
# 4  CUIT30707047085  30707047085                     BSR_TARDIA
#
#         ESTADO_ANTERIOR FECHA_ENVIO_ENRIQUECIMIENTO FECHA_INSERCION_DATO  \
# 0  EN GESTION_PORTAL                     2021-08-26           2021-08-27
# 1  EN GESTION_PORTAL                     2021-08-26           2021-08-27
# 2  NO UBICADO                            2021-08-26           2021-08-27
# 3  NO UBICADO                            2021-08-26           2021-08-27
# 4  NO UBICADO                            2021-08-26           2021-08-27
#
#   FECHA_CAMBIO_ESTADO
# 0          2021-08-31
# 1          2021-08-31
# 2          2021-08-31
# 3          2021-08-31
# 4          2021-08-31

# %%
df_log = df_log.assign(PROVEEDOR='ZERT')

# %%
df_log['ESTADO_ANTERIOR'] = [(str(df_log['ESTADO_ANTERIOR'][i]).strip()) for i in range (df_log['ESTADO_ANTERIOR'].count())]

# %%
df_log.loc[(df_log['ESTADO_ANTERIOR'] == 'INTERESADO') | 
           (df_log['ESTADO_ANTERIOR'] == 'NO VISTO') | 
           (df_log['ESTADO_ANTERIOR'] == 'EN GESTION') |
           (df_log['ESTADO_ANTERIOR'] == 'ASIGNADO') |
           (df_log['ESTADO_ANTERIOR'] == 'ROTACION') |
           (df_log['ESTADO_ANTERIOR'] == 'ASIGNADO') |
           (df_log['ESTADO_ANTERIOR'] == 'PLAN V') |
           (df_log['ESTADO_ANTERIOR'] == 'NO INTERESADO') |
           (df_log['ESTADO_ANTERIOR'] == 'ACUERDO CAIDO') |
           (df_log['ESTADO_ANTERIOR'] == 'CANCELO_RECHAZADA') 
           , 'CATEGORIA'] = 'NEUTRO'

# %%
df_log.loc[(df_log['ESTADO_ANTERIOR'] == 'NO UBICADO') | 
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL') |
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL 1') |
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL 1 OK') |
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL 2') |
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL 3') |
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL 3 OK') |
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL3 OK') |
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL1 OK') |
           (df_log['ESTADO_ANTERIOR'] == 'SKIP LEVEL1') |
           (df_log['ESTADO_ANTERIOR'] == 'NO_VISTO_CONTACTABLE') |
           (df_log['ESTADO_ANTERIOR'] == 'NO_VISTO_MASIVO') 
           , 'CATEGORIA'] = 'NEGATIVO POR CONTACTABILIDAD'

# %%
df_log.loc[(df_log['ESTADO_ANTERIOR'] == 'PAGO PARCIAL') | 
           (df_log['ESTADO_ANTERIOR'] == 'PLAN DE PAGOS') |
           (df_log['ESTADO_ANTERIOR'] == 'POSIBLE REFI') |
           (df_log['ESTADO_ANTERIOR'] == 'REFINANCIACION') |
           (df_log['ESTADO_ANTERIOR'] == 'PROPUESTA') |
           (df_log['ESTADO_ANTERIOR'] == 'PROPUESTA OK') |
           (df_log['ESTADO_ANTERIOR'] == 'COMPROMISO') |
           (df_log['ESTADO_ANTERIOR'] == 'CANCELO') |
           (df_log['ESTADO_ANTERIOR'] == 'CANCELO_DEVUELTO') |
           (df_log['ESTADO_ANTERIOR'] == 'CANCELO DEVUELTO') |
           (df_log['ESTADO_ANTERIOR'] == 'CANCELO FULL') |
           (df_log['ESTADO_ANTERIOR'] == 'CANCELO SIN ACP') 
           , 'CATEGORIA'] = 'POSITIVO CON CAJA'

# %%
df_log.loc[(df_log['ESTADO_ANTERIOR'] == 'CONVENIO') | 
           (df_log['ESTADO_ANTERIOR'] == 'CONVENIO QUITA') |
           (df_log['ESTADO_ANTERIOR'] == 'NUEVOS CARGOS') |
           (df_log['ESTADO_ANTERIOR'] == 'CONVENIO_QUITA') 
           , 'CATEGORIA'] = 'POSITIVO CON CAJA SOBRE COUTA'

# %%
df_log.loc[(df_log['ESTADO_ANTERIOR'] == 'PROPUESTA REFI') | 
           (df_log['ESTADO_ANTERIOR'] == 'REFI ARMADA') |
           (df_log['ESTADO_ANTERIOR'] == 'REFI EN TRAMITE') |
           (df_log['ESTADO_ANTERIOR'] == 'REFI A LIQUIDAR') 
           , 'CATEGORIA'] = 'POSITIVO CON CAJA CON REFI PENDIENTE DE LIQUIDACIO'

# %%
df_log.loc[(df_log['ESTADO_ANTERIOR'] == 'REFI APROBADA') | 
           (df_log['ESTADO_ANTERIOR'] == 'DEVUELTO/CANCELO CON COBRO DE HONORARIO PENDIENTE')
           , 'CATEGORIA'] = 'POSITIVO CON CAJA CON REFI/CANCELACIÓN LIQUIDADA'

# %%
df_log.loc[(df_log['ESTADO_ANTERIOR'] == 'DEVUELTO') | 
           (df_log['ESTADO_ANTERIOR'] == 'FALLECIDO') |
           (df_log['ESTADO_ANTERIOR'] == 'PROBLEMA') |
           (df_log['ESTADO_ANTERIOR'] == 'SALDO INSOLUTO') |
           (df_log['ESTADO_ANTERIOR'] == 'NO GESTIONAR') 
           , 'CATEGORIA'] = 'INACTIVO'

# %%
df_log.shape
# Out:
# (20110, 9)

# %%
df_log.head()
# Out:
#           IDMOROSO                        DATOADIC             IDCLIENTE  \
# 0     CI  62933702                                  BSR_TARDIA
# 1  CUIT30607032978  30607032978                     BSR_TARDIA
# 2  CUIT30698087648  30698087648                     BSR_TARDIA
# 3  CUIT30703557674  30703557674                     BSR_TARDIA
# 4  CUIT30707047085  30707047085                     BSR_TARDIA
#
#      ESTADO_ANTERIOR FECHA_ENVIO_ENRIQUECIMIENTO FECHA_INSERCION_DATO  \
# 0  EN GESTION_PORTAL                  2021-08-26           2021-08-27
# 1  EN GESTION_PORTAL                  2021-08-26           2021-08-27
# 2         NO UBICADO                  2021-08-26           2021-08-27
# 3         NO UBICADO                  2021-08-26           2021-08-27
# 4         NO UBICADO                  2021-08-26           2021-08-27
#
#   FECHA_CAMBIO_ESTADO PROVEEDOR                     CATEGORIA
# 0          2021-08-31      ZERT                           NaN
# 1          2021-08-31      ZERT                           NaN
# 2          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD
# 3          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD
# 4          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD

# %% [markdown]
# ## 2. Devolución de PyP

# %% [markdown]
# Levantamos los DNIs desde el archivo que devuelve PyP para cruzar contra los IDs y ver cuáles están enriquecidos.

# %%
fecha_insercion_log
# Out:
# '2021-08-27'

# %%
#Esta fecha para el formato en el path
fecha_inser = fecha_insercion_log[0:5]+fecha_insercion_log[8:10]+fecha_insercion_log[4:7]
df_pyp1 = pd.read_csv('../insiders/mail_fis_'+fecha_insercion_log+'.csv')
df_pyp2 = df_pyp = pd.read_csv('../insiders/phone_fis_'+fecha_insercion_log+'.csv')

# %%
df_pyp2.head()
# Out:
#        IDMOROSO TIPO_DOC   NRO_DOC     CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 10039621      DNI  10039621  2.710040e+10  TEL.CELULAR  PERSONAL
# 1  DNI 10039621      DNI  10039621  2.710040e+10  TEL.CELULAR  PERSONAL
# 2  DNI 10039621      DNI  10039621  2.710040e+10  TEL.CELULAR  PERSONAL
# 3  DNI 10039621      DNI  10039621  2.710040e+10     TEL.FIJO  PERSONAL
# 4  DNI 10046071      DNI  10046071  2.710046e+10  TEL.CELULAR  PERSONAL
#
#            DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  261156113429           Propio           ZERT  2021-08-27 11:46:36.410642
# 1  223155707846           Propio           ZERT  2021-08-27 11:46:36.410642
# 2  223156168996           Propio           ZERT  2021-08-27 11:46:36.410642
# 3    2234746758           Propio           ZERT  2021-08-27 11:46:36.410642
# 4  351156257130           Propio           ZERT  2021-08-27 11:46:36.410642
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         2.0
# 2           0                 NaN                    NaN         2.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0

# %%
df_reduced1 = df_pyp1[['CUIT_CUIL','NRO_DOC']]
df_reduced2 = df_pyp2[['CUIT_CUIL','NRO_DOC']]

df_reduced = df_reduced1.merge(df_reduced2, on="NRO_DOC", how="outer")
df_reduced = df_reduced.rename(columns = {'CUIT_CUIL_x':'CUIT_CUIL'})
df_reduced = df_reduced.drop(columns = ['CUIT_CUIL_y'])
df_reduced.head()
# Out:
#       CUIT_CUIL   NRO_DOC
# 0  2.710040e+10  10039621
# 1  2.710040e+10  10039621
# 2  2.710040e+10  10039621
# 3  2.710040e+10  10039621
# 4  2.710040e+10  10039621

# %%
df_reduced = df_reduced.drop_duplicates(subset=["NRO_DOC"])

# %%
df_reduced.head()
# Out:
#        CUIT_CUIL   NRO_DOC
# 0   2.710040e+10  10039621
# 8   2.710046e+10  10046071
# 10  2.710084e+10  10083637
# 14  2.010086e+10  10085866
# 16  2.010117e+10  10117117

# %% [markdown]
# Eliminamos el multilevel de las columnas, y las renombramos:

# %%
df_reduceda = df_reduced["NRO_DOC"].dropna()
df_reduceda.shape
# Out:
# (17617,)

# %% [markdown]
# ## NRO_DOC para union de dataframes

# %% [markdown]
# Creamos una columna que contenga IDMOROSO + DATOADIC según corresponda

# %%
df_log.loc[(df_log['IDCLIENTE'].str.startswith('AMEX')) , 'NRO_DOC'] = df_log['DATOADIC']
df_log.loc[(~df_log['IDCLIENTE'].str.startswith('AMEX')) , 'NRO_DOC'] = df_log['IDMOROSO']
#df_log ['NRO_DOC'] = df_log ['IDMOROSO']

# %%
df_log = df_log.dropna(subset=['NRO_DOC'])

# %%
df_log.tail()
# Out:
#           IDMOROSO                        DATOADIC             IDCLIENTE  \
# 20105  LE  6305211                                  FRANCES_2012
# 20106  LE  6305512                                  FRANCES_2012
# 20107  LE  6434675                                  FRANCES_2012
# 20108  LE  6852994                                  FRANCES_2012
# 20109  LE  7007498                                  FRANCES_2012
#
#       ESTADO_ANTERIOR FECHA_ENVIO_ENRIQUECIMIENTO FECHA_INSERCION_DATO  \
# 20105   PLAN DE PAGOS                  2021-08-26           2021-08-27
# 20106        ASIGNADO                  2021-08-26           2021-08-27
# 20107       FALLECIDO                  2021-08-26           2021-08-27
# 20108       FALLECIDO                  2021-08-26           2021-08-27
# 20109       FALLECIDO                  2021-08-26           2021-08-27
#
#       FECHA_CAMBIO_ESTADO PROVEEDOR          CATEGORIA      NRO_DOC TIPO_DOC
# 20105          2021-08-31      ZERT  POSITIVO CON CAJA  LE  6305211       LE
# 20106          2021-08-31      ZERT             NEUTRO  LE  6305512       LE
# 20107          2021-08-31      ZERT           INACTIVO  LE  6434675       LE
# 20108          2021-08-31      ZERT           INACTIVO  LE  6852994       LE
# 20109          2021-08-31      ZERT           INACTIVO  LE  7007498       LE

# %% [markdown]
# ## 12.2) DNI Cleaning

# %% [markdown]
# Limpiamos el dataframe __df_pyp__, ya que dentro de DATO_A_ENVIAR tenemos 9 tipos de casos diferentes de datos:
#
# - DNI 12345678
# - DNI12345678
# - DNIE1234678
# - LC  1234567
# - LE  1234567
# - CUIT00123456780
# - 00123456780 --> Es un CUIT.
# - 00 12345678 0 --> Es un CUIT.
# - DNI 00123456780 --> Dice DNI pero es un CUIT de una persona __jurídica__ (TO DO)

# %% [markdown]
# Para eso definimos 5 funciones:
#
# - __Tipo_DOC__: Se definen dos funciones para determinar el tipo de DNI. Una inicial, y otra para corregir sobre el dataframe resultante.
# - __Standard DNI__: Estandariza los DNI para 7 de los casos. Esta función debe ejecutarse en primer lugar.
# - __DNI Spaces__: Elimina los espacios.
# - __DNI Zero__: Elimina los ceros iniciales de ciertos CUITs para que coincidan con los DNI.
# - __Cuit__: Decisión sobre dejar un cuit o volverlo DNI

# %%
def tipo_doc_1 (string_dni):
    
    if 'DNI' in string_dni:
        tipo = 'DNI'
    
    elif 'LC' in string_dni:
        tipo = 'LC'
    
    elif 'LE' in string_dni:
        tipo = 'LE'
    
    elif 'PAS' in string_dni:
        tipo = 'PAS'
    
    elif 'DNIE' in string_dni:
        tipo = 'DNIE'    
    
    elif ((string_dni.startswith(('CUIT30','CUIT33','CUIT34'))) & (len(string_dni)>8)):
        tipo = 'CUIT'
        
    elif ((string_dni.startswith(('30','33','34'))) & (len(string_dni)>8)):
        tipo = 'CUIT'

    elif ((string_dni.startswith(('20','23','24','27'))) & (len(string_dni)>8)):
        tipo = 'DNI'

    elif ((string_dni.startswith(('CUIT20','CUIT23','CUIT24','CUIT27'))) & (len(string_dni)>8)):
        tipo = 'DNI'
        
    else:
        tipo = 'DNI'
    
    return tipo

# %%
def tipo_doc_2 (string_dni, tipo_original):
    
    if (len(string_dni) > 8) & (tipo_original == 'DNI'):
        tipo = 'CUIT'
    else:
        tipo = tipo_original
    return tipo

# %%
def standard_dni (string_dni):
    """DNI separation by each case.
    """
    
    if 'DNI ' in string_dni:
        dni = string_dni.split('DNI ')[1]
        
    elif 'DNIE' in string_dni:
        dni = string_dni.split('DNIE')[1]
    
    elif 'DNI' in string_dni:
        dni = string_dni.split('DNI')[1]
    
    elif 'PAS' in string_dni:
        dni = string_dni.split('PAS')[1]
    
    elif 'LC  ' in string_dni:
        dni = string_dni.split('LC  ')[1]
    
    elif 'LE  ' in string_dni:
        dni = string_dni.split('LE  ')[1]
    
    elif 'CUIT' in string_dni:
        dni = string_dni.split('CUIT')[1]
        
    else:
        dni = string_dni
        
    return dni

# %%
def dni_characters (string_dni):
    
    if ' ' in string_dni:
        dni = string_dni.replace(' ','')
        
    elif '-' in string_dni:
        dni = string_dni.replace('-','')

    else:
        dni = string_dni
    
    return dni

# %%
def cuit (string_dni):
    
    if ((string_dni.startswith('20')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]
        
    elif ((string_dni.startswith('23')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]
        
    elif ((string_dni.startswith('24')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]

    elif ((string_dni.startswith('27')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]

    else:
        cuit = string_dni
        
    return cuit

# %%
def dni_zero (string_dni):
    
    if string_dni.startswith('0'):
        dni = string_dni [1:]

    else:
        dni = string_dni
    
    return dni

# %% [markdown]
# En primer lugar, trimmeamos los espacios que sobran:

# %%
df_log['NRO_DOC'] = df_log['NRO_DOC'].str.strip()

# %% [markdown]
# Se implementan estas funciones:

# %% [markdown]
# Para determinar el __TIPO DE DOCUMENTO__ en primer lugar:

# %%
df_log['TIPO_DOC'] = df_log['NRO_DOC'].map(tipo_doc_1)

# %% [markdown]
# Para la limpieza de DNIs:

# %%
df_log['NRO_DOC'] = df_log['NRO_DOC'].map(standard_dni)

# %%
df_log['NRO_DOC'] = df_log['NRO_DOC'].map(dni_characters)

# %%
df_log['NRO_DOC'] = df_log['NRO_DOC'].map(cuit)

# %%
df_log['NRO_DOC'] = df_log['NRO_DOC'].map(dni_zero)

# %% [markdown]
# Para corregir el __TIPO DE DOCUMENTO__ sobre el dataframe resultante

# %%
df_log['TIPO_DOC'] = df_log.apply(lambda x: tipo_doc_2(x.NRO_DOC, x.TIPO_DOC), axis=1)

# %%
df_log.head()
# Out:
#           IDMOROSO                        DATOADIC             IDCLIENTE  \
# 0     CI  62933702                                  BSR_TARDIA
# 1  CUIT30607032978  30607032978                     BSR_TARDIA
# 2  CUIT30698087648  30698087648                     BSR_TARDIA
# 3  CUIT30703557674  30703557674                     BSR_TARDIA
# 4  CUIT30707047085  30707047085                     BSR_TARDIA
#
#      ESTADO_ANTERIOR FECHA_ENVIO_ENRIQUECIMIENTO FECHA_INSERCION_DATO  \
# 0  EN GESTION_PORTAL                  2021-08-26           2021-08-27
# 1  EN GESTION_PORTAL                  2021-08-26           2021-08-27
# 2         NO UBICADO                  2021-08-26           2021-08-27
# 3         NO UBICADO                  2021-08-26           2021-08-27
# 4         NO UBICADO                  2021-08-26           2021-08-27
#
#   FECHA_CAMBIO_ESTADO PROVEEDOR                     CATEGORIA      NRO_DOC  \
# 0          2021-08-31      ZERT                           NaN   CI62933702
# 1          2021-08-31      ZERT                           NaN  30607032978
# 2          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD  30698087648
# 3          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD  30703557674
# 4          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD  30707047085
#
#   TIPO_DOC
# 0     CUIT
# 1     CUIT
# 2     CUIT
# 3     CUIT
# 4     CUIT

# %%
df_log.shape
# Out:
# (20110, 11)

# %% [markdown]
# # 13) Union de Dataframes

# %% [markdown]
# Se unen ambos dataframes en la columna NRO_DOC

# %% [markdown]
# Convertimos la columna NRO_DOC de objeto a INT para hacer la unión

# %%
df_reduced = df_reduced.astype({'NRO_DOC': 'str'})

# %%
df_reduced ['NRO_DOC'] = df_reduced ['NRO_DOC'].str.split('.').str[0]

# %%
df_reduced['ENRIQUECIDO']=1

# %%
df_union = pd.merge(df_reduced, df_log,  on='NRO_DOC', how='right')

# %%
df_union.shape
# Out:
# (20110, 13)

# %%
df_union['ENRIQUECIDO']=df_union["ENRIQUECIDO"].fillna(0)

# %%
df_union.head()
# Out:
#    CUIT_CUIL      NRO_DOC  ENRIQUECIDO         IDMOROSO  \
# 0        NaN   CI62933702          0.0     CI  62933702
# 1        NaN  30607032978          0.0  CUIT30607032978
# 2        NaN  30698087648          0.0  CUIT30698087648
# 3        NaN  30703557674          0.0  CUIT30703557674
# 4        NaN  30707047085          0.0  CUIT30707047085
#
#                          DATOADIC             IDCLIENTE    ESTADO_ANTERIOR  \
# 0                                  BSR_TARDIA            EN GESTION_PORTAL
# 1  30607032978                     BSR_TARDIA            EN GESTION_PORTAL
# 2  30698087648                     BSR_TARDIA                   NO UBICADO
# 3  30703557674                     BSR_TARDIA                   NO UBICADO
# 4  30707047085                     BSR_TARDIA                   NO UBICADO
#
#   FECHA_ENVIO_ENRIQUECIMIENTO FECHA_INSERCION_DATO FECHA_CAMBIO_ESTADO  \
# 0                  2021-08-26           2021-08-27          2021-08-31
# 1                  2021-08-26           2021-08-27          2021-08-31
# 2                  2021-08-26           2021-08-27          2021-08-31
# 3                  2021-08-26           2021-08-27          2021-08-31
# 4                  2021-08-26           2021-08-27          2021-08-31
#
#   PROVEEDOR                     CATEGORIA TIPO_DOC
# 0      ZERT                           NaN     CUIT
# 1      ZERT                           NaN     CUIT
# 2      ZERT  NEGATIVO POR CONTACTABILIDAD     CUIT
# 3      ZERT  NEGATIVO POR CONTACTABILIDAD     CUIT
# 4      ZERT  NEGATIVO POR CONTACTABILIDAD     CUIT

# %%
df_clean = df_union.drop_duplicates()

# %%
df_clean.shape
# Out:
# (20110, 13)

# %%
duplicateRowsDF = df_union[df_union.duplicated(subset=['IDMOROSO'], keep=False)]

# %%
duplicateRowsDF
# Out:
#           CUIT_CUIL   NRO_DOC  ENRIQUECIDO      IDMOROSO  \
# 591    2.027132e+10  27131955          1.0  DNI 27131955
# 1377   2.027132e+10  27131955          1.0  DNI 27131955
# 1416   2.729952e+10  29952254          1.0  DNI 29952254
# 1691   2.021143e+10  21142882          1.0  DNI 21142882
# 2295   2.094947e+10  94947101          1.0  DNI 94947101
# 3662   2.321474e+10  21474282          1.0  DNI 21474282
# 3732            NaN  21624747          1.0  DNI 21624747
# 4695   2.024577e+10  24576519          1.0  DNI 24576519
# 4863   2.024577e+10  24576519          1.0  DNI 24576519
# 4887   2.030008e+10  30007978          1.0  DNI 30007978
# 5167   2.321474e+10  21474282          1.0  DNI 21474282
# 6305   2.727825e+10  27825169          1.0  DNI 27825169
# 7034            NaN  21624747          1.0  DNI 21624747
# 7349   2.028014e+10  28014118          1.0  DNI 28014118
# 7458            NaN  24040832          1.0  DNI 24040832
# 9563   2.726337e+10  26337359          1.0  DNI 26337359
# 10776  2.726337e+10  26337359          1.0  DNI 26337359
# 10995  2.028014e+10  28014118          1.0  DNI 28014118
# 11058  2.793769e+10  93768950          1.0  DNIE93768950
# 11208  2.033719e+10  33718942          1.0  DNI 33718942
# 12003  2.734438e+10  34437822          1.0  DNI 34437822
# 12004  2.734438e+10  34437822          1.0  DNI 34437822
# 12351           NaN  36594444          1.0  DNI 36594444
# 12972  2.731195e+10  31195091          1.0  DNI 31195091
# 13157           NaN  25785824          1.0  DNI 25785824
# 13217  2.093007e+10  93006681          1.0  DNIE93006681
# 13242  2.021143e+10  21142882          1.0  DNI 21142882
# 13361  2.732611e+10  32611355          1.0  DNI 32611355
# 13390           NaN  36594444          1.0  DNI 36594444
# 13701           NaN  24040832          1.0  DNI 24040832
# 14646           NaN  25785824          1.0  DNI 25785824
# 15410  2.094947e+10  94947101          1.0  DNI 94947101
# 17147  2.727825e+10  27825169          1.0  DNI 27825169
# 18008  2.729952e+10  29952254          1.0  DNI 29952254
# 18013  2.030008e+10  30007978          1.0  DNI 30007978
# 18135  2.736947e+10  36947058          1.0  DNI 36947058
# 18589  2.030577e+10  30577262          1.0  DNI 30577262
# 18685  2.730894e+10  30893687          1.0  DNI 30893687
# 18777  2.030577e+10  30577262          1.0  DNI 30577262
# 18914  2.730894e+10  30893687          1.0  DNI 30893687
# 18950  2.731195e+10  31195091          1.0  DNI 31195091
# 19007  2.093007e+10  93006681          1.0  DNIE93006681
# 19250  2.793769e+10  93768950          1.0  DNIE93768950
# 19304  2.736947e+10  36947058          1.0  DNI 36947058
# 19581  2.732611e+10  32611355          1.0  DNI 32611355
# 19726  2.033719e+10  33718942          1.0  DNI 33718942
#
#                              DATOADIC             IDCLIENTE  \
# 591                                    BBVA_LEGALES_PREJU_5
# 1377                                   BSR_TARDIA
# 1416                                   BBVA_LEGALES_PREJU
# 1691                                   BSR_TARDIA
# 2295                                   BBVA_LEGALES_PREJU
# 3662                                   COTO_TARDIA
# 3732                                   COTO_TARDIA
# 4695                                   COTO_TARDIA
# 4863                                   PRENDARIOS_LEGALES
# 4887   POTIGIAN GOLOSINA               PRENDARIOS_LEGALES
# 5167                                   BSR_TARDIA
# 6305   Documento Nacional de Identida  FRANCES_2012
# 7034                                   BSR_TARDIA
# 7349                                   FRANCES_2012
# 7458   Documento Nacional de Identida  HSBC_LEGALES14
# 9563   Documento Nacional de Identida  HSBC_LEGALES_TEMP
# 10776  Documento Nacional de Identida  FRANCES_2012
# 10995                                  HSBC_LEGALES14
# 11058                                  FRANCES_2012
# 11208                                  BSR_TARDIA
# 12003  Documento Nacional de Identida  HSBC_LEGALES_TEMP
# 12004  Documento Nacional de Identida  FRANCES_2012
# 12351  Documento Nacional de Identida  HSBC_LEGALES_TEMP
# 12972  altos alem srl                  BSR_TARDIA
# 13157                                  BSR_TARDIA
# 13217                                  FRANCES_2012
# 13242                                  BBVA_LEGALES_PREJU_5
# 13361                                  BSR_TARDIA
# 13390  Documento Nacional de Identida  HSBC_LEGALES14
# 13701  Documento Nacional de Identida  BSR_TARDIA
# 14646                                  FRANCES_2012
# 15410                                  HSBC_LEGALES_TEMP
# 17147  Documento Nacional de Identida  HSBC_LEGALES_TEMP
# 18008                                  HSBC_FOGAR
# 18013  POTIGIAN GOLOSINA               COTO_TARDIA
# 18135                                  FRANCES_2012
# 18589  PEPSICO                         BSR_TARDIA
# 18685  INADI                           BSR_TARDIA
# 18777  PEPSICO                         COTO_TARDIA
# 18914  INADI                           COTO_TARDIA
# 18950  altos alem srl                  COTO_TARDIA
# 19007                                  BSR_TARDIA
# 19250                                  BSR_TARDIA
# 19304                                  BSR_TARDIA
# 19581                                  COTO_TARDIA
# 19726                                  COTO_TARDIA
#
#          ESTADO_ANTERIOR FECHA_ENVIO_ENRIQUECIMIENTO FECHA_INSERCION_DATO  \
# 591           EN GESTION                  2021-08-26           2021-08-27
# 1377          EN GESTION                  2021-08-26           2021-08-27
# 1416          EN GESTION                  2021-08-26           2021-08-27
# 1691       NO INTERESADO                  2021-08-26           2021-08-27
# 2295          NO UBICADO                  2021-08-26           2021-08-27
# 3662            NO VISTO                  2021-08-26           2021-08-27
# 3732   COMPROMISO_PORTAL                  2021-08-26           2021-08-27
# 4695            NO VISTO                  2021-08-26           2021-08-27
# 4863            NO VISTO                  2021-08-26           2021-08-27
# 4887            NO VISTO                  2021-08-26           2021-08-27
# 5167          NO UBICADO                  2021-08-26           2021-08-27
# 6305            ASIGNADO                  2021-08-26           2021-08-27
# 7034       NO INTERESADO                  2021-08-26           2021-08-27
# 7349       PLAN DE PAGOS                  2021-08-26           2021-08-27
# 7458          EN GESTION                  2021-08-26           2021-08-27
# 9563          NO UBICADO                  2021-08-26           2021-08-27
# 10776           NO VISTO                  2021-08-26           2021-08-27
# 10995      ACUERDO CAIDO                  2021-08-26           2021-08-27
# 11058           ASIGNADO                  2021-08-26           2021-08-27
# 11208         NO UBICADO                  2021-08-26           2021-08-27
# 12003         NO UBICADO                  2021-08-26           2021-08-27
# 12004           NO VISTO                  2021-08-26           2021-08-27
# 12351      ACUERDO CAIDO                  2021-08-26           2021-08-27
# 12972         NO UBICADO                  2021-08-26           2021-08-27
# 13157         NO UBICADO                  2021-08-26           2021-08-27
# 13217           ASIGNADO                  2021-08-26           2021-08-27
# 13242         EN GESTION                  2021-08-26           2021-08-27
# 13361         NO UBICADO                  2021-08-26           2021-08-27
# 13390         NO UBICADO                  2021-08-26           2021-08-27
# 13701         NO UBICADO                  2021-08-26           2021-08-27
# 14646         INTERESADO                  2021-08-26           2021-08-27
# 15410         NO UBICADO                  2021-08-26           2021-08-27
# 17147         NO UBICADO                  2021-08-26           2021-08-27
# 18008           NO VISTO                  2021-08-26           2021-08-27
# 18013           NO VISTO                  2021-08-26           2021-08-27
# 18135     SKIP LEVEL3 OK                  2021-08-26           2021-08-27
# 18589         NO UBICADO                  2021-08-26           2021-08-27
# 18685         NO UBICADO                  2021-08-26           2021-08-27
# 18777           NO VISTO                  2021-08-26           2021-08-27
# 18914           NO VISTO                  2021-08-26           2021-08-27
# 18950           NO VISTO                  2021-08-26           2021-08-27
# 19007         NO UBICADO                  2021-08-26           2021-08-27
# 19250         NO UBICADO                  2021-08-26           2021-08-27
# 19304      NO INTERESADO                  2021-08-26           2021-08-27
# 19581  INTERESADO_PORTAL                  2021-08-26           2021-08-27
# 19726           NO VISTO                  2021-08-26           2021-08-27
#
#       FECHA_CAMBIO_ESTADO PROVEEDOR                     CATEGORIA TIPO_DOC
# 591            2021-08-31      ZERT                        NEUTRO      DNI
# 1377           2021-08-31      ZERT                        NEUTRO      DNI
# 1416           2021-08-31      ZERT                        NEUTRO      DNI
# 1691           2021-08-31      ZERT                        NEUTRO      DNI
# 2295           2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 3662           2021-08-31      ZERT                        NEUTRO      DNI
# 3732           2021-08-31      ZERT                           NaN      DNI
# 4695           2021-08-31      ZERT                        NEUTRO      DNI
# 4863           2021-08-31      ZERT                        NEUTRO      DNI
# 4887           2021-08-31      ZERT                        NEUTRO      DNI
# 5167           2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 6305           2021-08-31      ZERT                        NEUTRO      DNI
# 7034           2021-08-31      ZERT                        NEUTRO      DNI
# 7349           2021-08-31      ZERT             POSITIVO CON CAJA      DNI
# 7458           2021-08-31      ZERT                        NEUTRO      DNI
# 9563           2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 10776          2021-08-31      ZERT                        NEUTRO      DNI
# 10995          2021-08-31      ZERT                        NEUTRO      DNI
# 11058          2021-08-31      ZERT                        NEUTRO      DNI
# 11208          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 12003          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 12004          2021-08-31      ZERT                        NEUTRO      DNI
# 12351          2021-08-31      ZERT                        NEUTRO      DNI
# 12972          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 13157          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 13217          2021-08-31      ZERT                        NEUTRO      DNI
# 13242          2021-08-31      ZERT                        NEUTRO      DNI
# 13361          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 13390          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 13701          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 14646          2021-08-31      ZERT                        NEUTRO      DNI
# 15410          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 17147          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 18008          2021-08-31      ZERT                        NEUTRO      DNI
# 18013          2021-08-31      ZERT                        NEUTRO      DNI
# 18135          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 18589          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 18685          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 18777          2021-08-31      ZERT                        NEUTRO      DNI
# 18914          2021-08-31      ZERT                        NEUTRO      DNI
# 18950          2021-08-31      ZERT                        NEUTRO      DNI
# 19007          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 19250          2021-08-31      ZERT  NEGATIVO POR CONTACTABILIDAD      DNI
# 19304          2021-08-31      ZERT                        NEUTRO      DNI
# 19581          2021-08-31      ZERT                           NaN      DNI
# 19726          2021-08-31      ZERT                        NEUTRO      DNI

# %% [markdown]
# ## Nuevo Estado

# %% [markdown]
# Como no se usaron nuevos estados, se deja en nulo

# %%
df_clean = df_clean.assign(NUEVO_ESTADO=np.nan)

# %% [markdown]
# ## Enriquecido

# %% [markdown]
# Nota: sólo estoy mirando los enriquecidos. Si no se enriqueció, no lo mando al LOG.

# %%
#df_clean = df_clean.assign(ENRIQUECIDO=1)

# %%
df_clean.head()
# Out:
#    CUIT_CUIL      NRO_DOC  ENRIQUECIDO         IDMOROSO  \
# 0        NaN   CI62933702          0.0     CI  62933702
# 1        NaN  30607032978          0.0  CUIT30607032978
# 2        NaN  30698087648          0.0  CUIT30698087648
# 3        NaN  30703557674          0.0  CUIT30703557674
# 4        NaN  30707047085          0.0  CUIT30707047085
#
#                          DATOADIC             IDCLIENTE    ESTADO_ANTERIOR  \
# 0                                  BSR_TARDIA            EN GESTION_PORTAL
# 1  30607032978                     BSR_TARDIA            EN GESTION_PORTAL
# 2  30698087648                     BSR_TARDIA                   NO UBICADO
# 3  30703557674                     BSR_TARDIA                   NO UBICADO
# 4  30707047085                     BSR_TARDIA                   NO UBICADO
#
#   FECHA_ENVIO_ENRIQUECIMIENTO FECHA_INSERCION_DATO FECHA_CAMBIO_ESTADO  \
# 0                  2021-08-26           2021-08-27          2021-08-31
# 1                  2021-08-26           2021-08-27          2021-08-31
# 2                  2021-08-26           2021-08-27          2021-08-31
# 3                  2021-08-26           2021-08-27          2021-08-31
# 4                  2021-08-26           2021-08-27          2021-08-31
#
#   PROVEEDOR                     CATEGORIA TIPO_DOC  NUEVO_ESTADO
# 0      ZERT                           NaN     CUIT           NaN
# 1      ZERT                           NaN     CUIT           NaN
# 2      ZERT  NEGATIVO POR CONTACTABILIDAD     CUIT           NaN
# 3      ZERT  NEGATIVO POR CONTACTABILIDAD     CUIT           NaN
# 4      ZERT  NEGATIVO POR CONTACTABILIDAD     CUIT           NaN

# %%
df_clean = df_clean [['IDMOROSO','IDCLIENTE','ESTADO_ANTERIOR','CATEGORIA','NUEVO_ESTADO','ENRIQUECIDO','FECHA_ENVIO_ENRIQUECIMIENTO','FECHA_INSERCION_DATO','FECHA_CAMBIO_ESTADO','PROVEEDOR']]

# %%
df_clean.head()
# Out:
#           IDMOROSO             IDCLIENTE    ESTADO_ANTERIOR  \
# 0     CI  62933702  BSR_TARDIA            EN GESTION_PORTAL
# 1  CUIT30607032978  BSR_TARDIA            EN GESTION_PORTAL
# 2  CUIT30698087648  BSR_TARDIA                   NO UBICADO
# 3  CUIT30703557674  BSR_TARDIA                   NO UBICADO
# 4  CUIT30707047085  BSR_TARDIA                   NO UBICADO
#
#                       CATEGORIA  NUEVO_ESTADO  ENRIQUECIDO  \
# 0                           NaN           NaN          0.0
# 1                           NaN           NaN          0.0
# 2  NEGATIVO POR CONTACTABILIDAD           NaN          0.0
# 3  NEGATIVO POR CONTACTABILIDAD           NaN          0.0
# 4  NEGATIVO POR CONTACTABILIDAD           NaN          0.0
#
#   FECHA_ENVIO_ENRIQUECIMIENTO FECHA_INSERCION_DATO FECHA_CAMBIO_ESTADO  \
# 0                  2021-08-26           2021-08-27          2021-08-31
# 1                  2021-08-26           2021-08-27          2021-08-31
# 2                  2021-08-26           2021-08-27          2021-08-31
# 3                  2021-08-26           2021-08-27          2021-08-31
# 4                  2021-08-26           2021-08-27          2021-08-31
#
#   PROVEEDOR
# 0      ZERT
# 1      ZERT
# 2      ZERT
# 3      ZERT
# 4      ZERT

# %%
df_clean.shape
# Out:
# (20110, 10)

# %%
df_clean['ENRIQUECIDO']=df_clean['ENRIQUECIDO'].astype(int)

# %%
df_clean['ENRIQUECIDO'].value_counts()
# Out:
# 1    17669
# 0     2441
# Name: ENRIQUECIDO, dtype: int64

# %% [markdown]
# # Export

# %%
df_clean.to_csv("dam_log_21-08-31.csv")
