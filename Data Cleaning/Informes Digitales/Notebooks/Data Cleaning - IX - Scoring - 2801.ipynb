# %% [markdown]
# # 1) Datasets

# %% [markdown]
# Vamos a leer el dataset que envía PyP

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Informes Digitales/Datasets/Datos Recibidos/MOPC_INFORMES_DIGITALES_2801_1 - Copy.xlsx', header=1)

# %%
df1.head()
# Out:
#    Orden    Tipo         DNI                           Nombre      Cuit/Cuil  \
# 0   1.01  DNI-EB  32.413.854               Marchesi Ana Paula  23-32413854-4
# 1   1.02  DNI-EB  32.413.854               Marchesi Ana Paula  23-32413854-4
# 2    NaN     NaN         NaN                              NaN            NaN
# 3   2.01  DNI-EC  35.179.685  Almada Medina Jonathan Emmanuel  20-35179685-6
# 4   2.02  DNI-EC  35.179.685  Almada Medina Jonathan Emmanuel  20-35179685-6
#
#   Genero                  Edad Observ.  \
# 0   Fem.  34 Años (26/09/1986)     NaN
# 1   Fem.  34 Años (26/09/1986)     NaN
# 2    NaN                   NaN     NaN
# 3   Mas.  30 Años (22/04/1990)     NaN
# 4   Mas.  30 Años (22/04/1990)     NaN
#
#                                            Actividad  Unnamed: 9  ...  \
# 0  Servicios De Gestión Y Logística Para El Trans...         NaN  ...
# 1  Servicios De Gestión Y Logística Para El Trans...         NaN  ...
# 2                                                NaN         NaN  ...
# 3  Servicio De Transporte Automotor De Pasajeros ...         NaN  ...
# 4  Servicio De Transporte Automotor De Pasajeros ...         NaN  ...
#
#         Celular 1       Celular 2 Celular 3 Celular 4 Celular 5 Email  \
# 0             NaN             NaN       NaN       NaN       NaN   NaN
# 1             NaN             NaN       NaN       NaN       NaN   NaN
# 2             NaN             NaN       NaN       NaN       NaN   NaN
# 3  (11) 3368-7922  (11) 3368-7434       NaN       NaN       NaN   NaN
# 4             NaN             NaN       NaN       NaN       NaN   NaN
#
#   Unnamed: 78  Categoria_monotributo       Rubro_monotributo Unnamed: 81
# 0         NaN                      G  Locaciones De Servicio         NaN
# 1         NaN                    NaN                     NaN         NaN
# 2         NaN                    NaN                     NaN         NaN
# 3         NaN                      D  Locaciones De Servicio         NaN
# 4         NaN                    NaN                     NaN         NaN
#
# [5 rows x 82 columns]

# %%
df1.shape
# Out:
# (1292, 82)

# %%
df1.head()
# Out:
#    Orden    Tipo         DNI                           Nombre      Cuit/Cuil  \
# 0   1.01  DNI-EB  32.413.854               Marchesi Ana Paula  23-32413854-4
# 1   1.02  DNI-EB  32.413.854               Marchesi Ana Paula  23-32413854-4
# 2    NaN     NaN         NaN                              NaN            NaN
# 3   2.01  DNI-EC  35.179.685  Almada Medina Jonathan Emmanuel  20-35179685-6
# 4   2.02  DNI-EC  35.179.685  Almada Medina Jonathan Emmanuel  20-35179685-6
#
#   Genero                  Edad Observ.  \
# 0   Fem.  34 Años (26/09/1986)     NaN
# 1   Fem.  34 Años (26/09/1986)     NaN
# 2    NaN                   NaN     NaN
# 3   Mas.  30 Años (22/04/1990)     NaN
# 4   Mas.  30 Años (22/04/1990)     NaN
#
#                                            Actividad  Unnamed: 9  ...  \
# 0  Servicios De Gestión Y Logística Para El Trans...         NaN  ...
# 1  Servicios De Gestión Y Logística Para El Trans...         NaN  ...
# 2                                                NaN         NaN  ...
# 3  Servicio De Transporte Automotor De Pasajeros ...         NaN  ...
# 4  Servicio De Transporte Automotor De Pasajeros ...         NaN  ...
#
#         Celular 1       Celular 2 Celular 3 Celular 4 Celular 5 Email  \
# 0             NaN             NaN       NaN       NaN       NaN   NaN
# 1             NaN             NaN       NaN       NaN       NaN   NaN
# 2             NaN             NaN       NaN       NaN       NaN   NaN
# 3  (11) 3368-7922  (11) 3368-7434       NaN       NaN       NaN   NaN
# 4             NaN             NaN       NaN       NaN       NaN   NaN
#
#   Unnamed: 78  Categoria_monotributo       Rubro_monotributo Unnamed: 81
# 0         NaN                      G  Locaciones De Servicio         NaN
# 1         NaN                    NaN                     NaN         NaN
# 2         NaN                    NaN                     NaN         NaN
# 3         NaN                      D  Locaciones De Servicio         NaN
# 4         NaN                    NaN                     NaN         NaN
#
# [5 rows x 82 columns]

# %% [markdown]
# Cargamos el segundo dataset:

# %%
df2 = pd.read_excel('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Informes Digitales/Datasets/Datos Recibidos/MOPC_INFORMES_DIGITALES_2801_2 - Copy.xlsx', header=1)

# %%
df2.shape
# Out:
# (5066, 82)

# %%
df2.tail()
# Out:
#        Orden    Tipo         DNI                              Nombre  \
# 5061  255.05  DNI-EC  23.200.122  Morales Perla Andrea (Barrionuevo)
# 5062  255.06  DNI-EC  23.200.122  Morales Perla Andrea (Barrionuevo)
# 5063  255.07  DNI-EC  23.200.122  Morales Perla Andrea (Barrionuevo)
# 5064  255.08  DNI-EC  23.200.122  Morales Perla Andrea (Barrionuevo)
# 5065     NaN     NaN         NaN                                 NaN
#
#           Cuit/Cuil Genero                  Edad Observ.  \
# 5061  23-23200122-4   Fem.  48 Años (05/12/1972)     NaN
# 5062  23-23200122-4   Fem.  48 Años (05/12/1972)     NaN
# 5063  23-23200122-4   Fem.  48 Años (05/12/1972)     NaN
# 5064  23-23200122-4   Fem.  48 Años (05/12/1972)     NaN
# 5065            NaN    NaN                   NaN     NaN
#
#                                               Actividad  Unnamed: 9  ...  \
# 5061  Venta Al Por Mayor En Comisión O Consignación ...         NaN  ...
# 5062  Venta Al Por Mayor En Comisión O Consignación ...         NaN  ...
# 5063  Venta Al Por Mayor En Comisión O Consignación ...         NaN  ...
# 5064  Venta Al Por Mayor En Comisión O Consignación ...         NaN  ...
# 5065                                                NaN         NaN  ...
#
#      Celular 1 Celular 2 Celular 3 Celular 4 Celular 5 Email Unnamed: 78  \
# 5061       NaN       NaN       NaN       NaN       NaN   NaN         NaN
# 5062       NaN       NaN       NaN       NaN       NaN   NaN         NaN
# 5063       NaN       NaN       NaN       NaN       NaN   NaN         NaN
# 5064       NaN       NaN       NaN       NaN       NaN   NaN         NaN
# 5065       NaN       NaN       NaN       NaN       NaN   NaN         NaN
#
#       Categoria_monotributo Rubro_monotributo Unnamed: 81
# 5061                    NaN               NaN         NaN
# 5062                    NaN               NaN         NaN
# 5063                    NaN               NaN         NaN
# 5064                    NaN               NaN         NaN
# 5065                    NaN               NaN         NaN
#
# [5 rows x 82 columns]

# %% [markdown]
# ## 1.1) Join de Datasets

# %% [markdown]
# Vamos a unir los dos dataframes para trabajar sobre uno solo.

# %%
df = df1.append(df2, ignore_index = True)

# %%
df.shape
# Out:
# (6358, 82)

# %%
df.tail()
# Out:
#        Orden    Tipo         DNI                              Nombre  \
# 6353  255.05  DNI-EC  23.200.122  Morales Perla Andrea (Barrionuevo)
# 6354  255.06  DNI-EC  23.200.122  Morales Perla Andrea (Barrionuevo)
# 6355  255.07  DNI-EC  23.200.122  Morales Perla Andrea (Barrionuevo)
# 6356  255.08  DNI-EC  23.200.122  Morales Perla Andrea (Barrionuevo)
# 6357     NaN     NaN         NaN                                 NaN
#
#           Cuit/Cuil Genero                  Edad Observ.  \
# 6353  23-23200122-4   Fem.  48 Años (05/12/1972)     NaN
# 6354  23-23200122-4   Fem.  48 Años (05/12/1972)     NaN
# 6355  23-23200122-4   Fem.  48 Años (05/12/1972)     NaN
# 6356  23-23200122-4   Fem.  48 Años (05/12/1972)     NaN
# 6357            NaN    NaN                   NaN     NaN
#
#                                               Actividad  Unnamed: 9  ...  \
# 6353  Venta Al Por Mayor En Comisión O Consignación ...         NaN  ...
# 6354  Venta Al Por Mayor En Comisión O Consignación ...         NaN  ...
# 6355  Venta Al Por Mayor En Comisión O Consignación ...         NaN  ...
# 6356  Venta Al Por Mayor En Comisión O Consignación ...         NaN  ...
# 6357                                                NaN         NaN  ...
#
#      Celular 1 Celular 2 Celular 3 Celular 4 Celular 5 Email Unnamed: 78  \
# 6353       NaN       NaN       NaN       NaN       NaN   NaN         NaN
# 6354       NaN       NaN       NaN       NaN       NaN   NaN         NaN
# 6355       NaN       NaN       NaN       NaN       NaN   NaN         NaN
# 6356       NaN       NaN       NaN       NaN       NaN   NaN         NaN
# 6357       NaN       NaN       NaN       NaN       NaN   NaN         NaN
#
#       Categoria_monotributo Rubro_monotributo Unnamed: 81
# 6353                    NaN               NaN         NaN
# 6354                    NaN               NaN         NaN
# 6355                    NaN               NaN         NaN
# 6356                    NaN               NaN         NaN
# 6357                    NaN               NaN         NaN
#
# [5 rows x 82 columns]

# %% [markdown]
# ## 1.2) Data Cleaning: Datasets

# %% [markdown]
# Vamos a dropear aquellas columnas y filas que no tengan ningún valor (es decir, que sean todos NaNs)

# %%
df = df.dropna(axis=0, how='all')

# %%
df = df.dropna(axis=1, how='all')

# %%
df.shape
# Out:
# (5845, 56)

# %% [markdown]
# Ahora todas las columnas tienen al menos 1 dato.

# %% [markdown]
# Elimino el multilevel de las columnas

# %%
#df.columns = df.columns.droplevel()

# %%
df.head()
# Out:
#    Orden    Tipo         DNI                           Nombre      Cuit/Cuil  \
# 0   1.01  DNI-EB  32.413.854               Marchesi Ana Paula  23-32413854-4
# 1   1.02  DNI-EB  32.413.854               Marchesi Ana Paula  23-32413854-4
# 3   2.01  DNI-EC  35.179.685  Almada Medina Jonathan Emmanuel  20-35179685-6
# 4   2.02  DNI-EC  35.179.685  Almada Medina Jonathan Emmanuel  20-35179685-6
# 6   3.01  DNI-EB  37.497.005           Suilice Melina Giselle  23-37497005-4
#
#   Genero                  Edad Observ.  \
# 0   Fem.  34 Años (26/09/1986)     NaN
# 1   Fem.  34 Años (26/09/1986)     NaN
# 3   Mas.  30 Años (22/04/1990)     NaN
# 4   Mas.  30 Años (22/04/1990)     NaN
# 6   Fem.  27 Años (30/07/1993)     NaN
#
#                                            Actividad  \
# 0  Servicios De Gestión Y Logística Para El Trans...
# 1  Servicios De Gestión Y Logística Para El Trans...
# 3  Servicio De Transporte Automotor De Pasajeros ...
# 4  Servicio De Transporte Automotor De Pasajeros ...
# 6                                                NaN
#
#                         Tipo_domicilio  ... Telefono_linea_4 Telefono_linea_5  \
# 0          Domicilio legal: 01/07/2017  ...              NaN              NaN
# 1                   Domicilio legal: -  ...              NaN              NaN
# 3         Domicilio fiscal: 05/09/2014  ...              NaN              NaN
# 4  Domicilio alternativo 1: 30/06/2018  ...              NaN              NaN
# 6         Domicilio fiscal: 01/07/2014  ...              NaN              NaN
#
#         Celular 1       Celular 2 Celular 3 Celular 4 Celular 5 Email  \
# 0             NaN             NaN       NaN       NaN       NaN   NaN
# 1             NaN             NaN       NaN       NaN       NaN   NaN
# 3  (11) 3368-7922  (11) 3368-7434       NaN       NaN       NaN   NaN
# 4             NaN             NaN       NaN       NaN       NaN   NaN
# 6             NaN             NaN       NaN       NaN       NaN   NaN
#
#    Categoria_monotributo       Rubro_monotributo
# 0                      G  Locaciones De Servicio
# 1                    NaN                     NaN
# 3                      D  Locaciones De Servicio
# 4                    NaN                     NaN
# 6                      F  Locaciones De Servicio
#
# [5 rows x 56 columns]

# %% [markdown]
# # 3) Condiciones

# %% [markdown]
# Analizar:
#
# - Cantidad de autos
# - Aquellos que tengan +2 propiedades, que tengan 1 o que no tengan.
# - Situación BCRA 1 o 2.
# - Rango de ingresos.

# %% [markdown]
# ## 3.1) Patentados

# %%
df.loc[((df['Patentados 2020'] != 0) | (df['Patentados 2019'] != 0)
            | (df['Patentados 2018'] != 0) | (df['Patentados 2017'] != 0)
            | (df['Patentados 2016'] != 0) | (df['Patentados 2015'] != 0)
            ) , 'PATENTADOS 2015-2020'] = 1

# %%
df.head()
# Out:
#           Cuil      Dni Fecha de Nac. Fecha de Defuncion Sexo  \
# 0  27037093993  3709399    1937-12-08                NaN    F
# 1  27056924243  5692424    1947-10-25                NaN    F
# 2  27059339341  5933934    1948-09-24                NaN    F
# 3  20061549715  6154971    1936-01-01                NaN    M
# 4  27063607423  6360742    1950-05-12                NaN    F
#
#                  Titular                    Calle Numero Piso y Depto  \
# 0         RODRIGUEZ HEBE             BUENOS AIRES   2747          NaN
# 1    BULFONI GLADYS ROSA  H YRIGOYEN S/N-CARDALES    S/N          NaN
# 2      BENITEZ ANA MARIA                    ZINNY   7210          NaN
# 3      OLIVER OSCAR RAUL              TRIUNVIRATO   2873          NaN
# 4  PORTALEA ALICIA NOEMI              SAN VICENTE   5430          NaN
#
#    Codigo Postal  ... Celular 1 Celular 2 Celular 3 Celular 4  Celular 5  \
# 0           7600  ...       NaN       NaN       NaN       NaN        NaN
# 1           2814  ...       NaN       NaN       NaN       NaN        NaN
# 2           1758  ...       NaN       NaN       NaN       NaN        NaN
# 3           1736  ...       NaN       NaN       NaN       NaN        NaN
# 4           1650  ...       NaN       NaN       NaN       NaN        NaN
#
#    Email               Nombre      Telefono  SCORE  PATENTADOS 2015-2020
# 0    NaN                  NaN           NaN    980                   NaN
# 1    NaN                  NaN           NaN    222                   NaN
# 2    NaN     MILLAHUEL ROSA I  2.202438e+09    831                   NaN
# 3    NaN                  NaN           NaN    955                   NaN
# 4    NaN  FRASCHERI CHRISTIAN  1.147548e+09    120                   NaN
#
# [5 rows x 225 columns]

# %%
df.loc[((df['Patentados 2014'] != 0) | (df['Patentados 2013'] != 0)
            | (df['Patentados 2012'] != 0) | (df['Patentados 2011'] != 0)
            | (df['Patentados 2010'] != 0) | (df['Patentados 2009'] != 0)
            | (df['Patentados 2008'] != 0) | (df['Patentados 2007'] != 0)
            | (df['Patentados 2006'] != 0) | (df['Patentados 2005'] != 0)
            | (df['Patentados 2004'] != 0) | (df['Patentados 2003'] != 0)
            | (df['Patentados 2002'] != 0) | (df['Patentados 2001'] != 0)
            | (df['Patentados menor al año 2001'] != 0)
            ) , 'PATENTADOS MENOR AL 2015'] = 1

# %%
df.head()
# Out:
#           Cuil      Dni Fecha de Nac. Fecha de Defuncion Sexo  \
# 0  27037093993  3709399    1937-12-08                NaN    F
# 1  27056924243  5692424    1947-10-25                NaN    F
# 2  27059339341  5933934    1948-09-24                NaN    F
# 3  20061549715  6154971    1936-01-01                NaN    M
# 4  27063607423  6360742    1950-05-12                NaN    F
#
#                  Titular                    Calle Numero Piso y Depto  \
# 0         RODRIGUEZ HEBE             BUENOS AIRES   2747          NaN
# 1    BULFONI GLADYS ROSA  H YRIGOYEN S/N-CARDALES    S/N          NaN
# 2      BENITEZ ANA MARIA                    ZINNY   7210          NaN
# 3      OLIVER OSCAR RAUL              TRIUNVIRATO   2873          NaN
# 4  PORTALEA ALICIA NOEMI              SAN VICENTE   5430          NaN
#
#    Codigo Postal  ... Celular 2 Celular 3 Celular 4 Celular 5  Email  \
# 0           7600  ...       NaN       NaN       NaN       NaN    NaN
# 1           2814  ...       NaN       NaN       NaN       NaN    NaN
# 2           1758  ...       NaN       NaN       NaN       NaN    NaN
# 3           1736  ...       NaN       NaN       NaN       NaN    NaN
# 4           1650  ...       NaN       NaN       NaN       NaN    NaN
#
#                 Nombre      Telefono  SCORE  PATENTADOS 2015-2020  \
# 0                  NaN           NaN    980                   NaN
# 1                  NaN           NaN    222                   NaN
# 2     MILLAHUEL ROSA I  2.202438e+09    831                   NaN
# 3                  NaN           NaN    955                   NaN
# 4  FRASCHERI CHRISTIAN  1.147548e+09    120                   NaN
#
#    PATENTADOS MENOR AL 2015
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       1.0
# 4                       NaN
#
# [5 rows x 226 columns]

# %%
df.loc[((df['Patentados 2014'] == 0) & (df['Patentados 2013'] == 0)
            & (df['Patentados 2012'] == 0) & (df['Patentados 2011'] == 0)
            & (df['Patentados 2010'] == 0) & (df['Patentados 2009'] == 0)
            & (df['Patentados 2008'] == 0) & (df['Patentados 2007'] == 0)
            & (df['Patentados 2006'] == 0) & (df['Patentados 2005'] == 0)
            & (df['Patentados 2004'] == 0) & (df['Patentados 2003'] == 0)
            & (df['Patentados 2002'] == 0) & (df['Patentados 2001'] == 0)
            & (df['Patentados menor al año 2001'] == 0)
            & (df['Patentados 2020'] == 0) & (df['Patentados 2019'] == 0)
            & (df['Patentados 2018'] == 0) & (df['Patentados 2017'] == 0)
            & (df['Patentados 2016'] == 0) & (df['Patentados 2015'] == 0)
            ) , 'SIN AUTOS PATENTADOS'] = 1

# %%
df.head()
# Out:
#           Cuil      Dni Fecha de Nac. Fecha de Defuncion Sexo  \
# 0  27037093993  3709399    1937-12-08                NaN    F
# 1  27056924243  5692424    1947-10-25                NaN    F
# 2  27059339341  5933934    1948-09-24                NaN    F
# 3  20061549715  6154971    1936-01-01                NaN    M
# 4  27063607423  6360742    1950-05-12                NaN    F
#
#                  Titular                    Calle Numero Piso y Depto  \
# 0         RODRIGUEZ HEBE             BUENOS AIRES   2747          NaN
# 1    BULFONI GLADYS ROSA  H YRIGOYEN S/N-CARDALES    S/N          NaN
# 2      BENITEZ ANA MARIA                    ZINNY   7210          NaN
# 3      OLIVER OSCAR RAUL              TRIUNVIRATO   2873          NaN
# 4  PORTALEA ALICIA NOEMI              SAN VICENTE   5430          NaN
#
#    Codigo Postal  ... Celular 3 Celular 4 Celular 5 Email  \
# 0           7600  ...       NaN       NaN       NaN   NaN
# 1           2814  ...       NaN       NaN       NaN   NaN
# 2           1758  ...       NaN       NaN       NaN   NaN
# 3           1736  ...       NaN       NaN       NaN   NaN
# 4           1650  ...       NaN       NaN       NaN   NaN
#
#                 Nombre      Telefono  SCORE  PATENTADOS 2015-2020  \
# 0                  NaN           NaN    980                   NaN
# 1                  NaN           NaN    222                   NaN
# 2     MILLAHUEL ROSA I  2.202438e+09    831                   NaN
# 3                  NaN           NaN    955                   NaN
# 4  FRASCHERI CHRISTIAN  1.147548e+09    120                   NaN
#
#    PATENTADOS MENOR AL 2015  SIN AUTOS PATENTADOS
# 0                       NaN                   1.0
# 1                       NaN                   1.0
# 2                       NaN                   1.0
# 3                       1.0                   NaN
# 4                       NaN                   1.0
#
# [5 rows x 227 columns]

# %% [markdown]
# ## 3.2 Inmuebles

# %%
df.loc[((df['Propiedades'] >= 2)
            ) , 'DOS O MAS PROPIEDADES'] = 1

# %%
df.head()
# Out:
#           Cuil      Dni Fecha de Nac. Fecha de Defuncion Sexo  \
# 0  27037093993  3709399    1937-12-08                NaN    F
# 1  27056924243  5692424    1947-10-25                NaN    F
# 2  27059339341  5933934    1948-09-24                NaN    F
# 3  20061549715  6154971    1936-01-01                NaN    M
# 4  27063607423  6360742    1950-05-12                NaN    F
#
#                  Titular                    Calle Numero Piso y Depto  \
# 0         RODRIGUEZ HEBE             BUENOS AIRES   2747          NaN
# 1    BULFONI GLADYS ROSA  H YRIGOYEN S/N-CARDALES    S/N          NaN
# 2      BENITEZ ANA MARIA                    ZINNY   7210          NaN
# 3      OLIVER OSCAR RAUL              TRIUNVIRATO   2873          NaN
# 4  PORTALEA ALICIA NOEMI              SAN VICENTE   5430          NaN
#
#    Codigo Postal  ... Celular 4 Celular 5 Email               Nombre  \
# 0           7600  ...       NaN       NaN   NaN                  NaN
# 1           2814  ...       NaN       NaN   NaN                  NaN
# 2           1758  ...       NaN       NaN   NaN     MILLAHUEL ROSA I
# 3           1736  ...       NaN       NaN   NaN                  NaN
# 4           1650  ...       NaN       NaN   NaN  FRASCHERI CHRISTIAN
#
#        Telefono  SCORE  PATENTADOS 2015-2020  PATENTADOS MENOR AL 2015  \
# 0           NaN    980                   NaN                       NaN
# 1           NaN    222                   NaN                       NaN
# 2  2.202438e+09    831                   NaN                       NaN
# 3           NaN    955                   NaN                       1.0
# 4  1.147548e+09    120                   NaN                       NaN
#
#    SIN AUTOS PATENTADOS  DOS O MAS PROPIEDADES
# 0                   1.0                    1.0
# 1                   1.0                    NaN
# 2                   1.0                    NaN
# 3                   NaN                    1.0
# 4                   1.0                    NaN
#
# [5 rows x 228 columns]

# %%
df.loc[((df['Propiedades'] == 1)
            ) , 'UNA PROPIEDAD'] = 1

# %%
df.loc[((df['Propiedades'] == 0)
            ) , 'SIN PROPIEDADES'] = 1

# %%
df.head()
# Out:
#           Cuil      Dni Fecha de Nac. Fecha de Defuncion Sexo  \
# 0  27037093993  3709399    1937-12-08                NaN    F
# 1  27056924243  5692424    1947-10-25                NaN    F
# 2  27059339341  5933934    1948-09-24                NaN    F
# 3  20061549715  6154971    1936-01-01                NaN    M
# 4  27063607423  6360742    1950-05-12                NaN    F
#
#                  Titular                    Calle Numero Piso y Depto  \
# 0         RODRIGUEZ HEBE             BUENOS AIRES   2747          NaN
# 1    BULFONI GLADYS ROSA  H YRIGOYEN S/N-CARDALES    S/N          NaN
# 2      BENITEZ ANA MARIA                    ZINNY   7210          NaN
# 3      OLIVER OSCAR RAUL              TRIUNVIRATO   2873          NaN
# 4  PORTALEA ALICIA NOEMI              SAN VICENTE   5430          NaN
#
#    Codigo Postal  ... Email               Nombre      Telefono SCORE  \
# 0           7600  ...   NaN                  NaN           NaN   980
# 1           2814  ...   NaN                  NaN           NaN   222
# 2           1758  ...   NaN     MILLAHUEL ROSA I  2.202438e+09   831
# 3           1736  ...   NaN                  NaN           NaN   955
# 4           1650  ...   NaN  FRASCHERI CHRISTIAN  1.147548e+09   120
#
#    PATENTADOS 2015-2020  PATENTADOS MENOR AL 2015  SIN AUTOS PATENTADOS  \
# 0                   NaN                       NaN                   1.0
# 1                   NaN                       NaN                   1.0
# 2                   NaN                       NaN                   1.0
# 3                   NaN                       1.0                   NaN
# 4                   NaN                       NaN                   1.0
#
#    DOS O MAS PROPIEDADES  UNA PROPIEDAD  SIN PROPIEDADES
# 0                    1.0            NaN              NaN
# 1                    NaN            1.0              NaN
# 2                    NaN            NaN              1.0
# 3                    1.0            NaN              NaN
# 4                    NaN            NaN              1.0
#
# [5 rows x 230 columns]

# %% [markdown]
# # 3.3 Situación frente a BCRA: Titular

# %%
df.loc[((df['Cant. Sit 1 Titular'] != 0) | (df['Cant. Sit 2 Titular'] != 0)
            ) , 'TITULAR CON SITUACION 1 o 2'] = 1

# %%
df.loc[((df['Cant. Sit 1 grupo familiar'] != 0) | (df['Cant. Sit 2 grupo familiar'] != 0)
            ) , 'GRUPO FAMILIAR CON SITUACION 1 o 2'] = 1

# %%
df.head()
# Out:
#           Cuil      Dni Fecha de Nac. Fecha de Defuncion Sexo  \
# 0  27037093993  3709399    1937-12-08                NaN    F
# 1  27056924243  5692424    1947-10-25                NaN    F
# 2  27059339341  5933934    1948-09-24                NaN    F
# 3  20061549715  6154971    1936-01-01                NaN    M
# 4  27063607423  6360742    1950-05-12                NaN    F
#
#                  Titular                    Calle Numero Piso y Depto  \
# 0         RODRIGUEZ HEBE             BUENOS AIRES   2747          NaN
# 1    BULFONI GLADYS ROSA  H YRIGOYEN S/N-CARDALES    S/N          NaN
# 2      BENITEZ ANA MARIA                    ZINNY   7210          NaN
# 3      OLIVER OSCAR RAUL              TRIUNVIRATO   2873          NaN
# 4  PORTALEA ALICIA NOEMI              SAN VICENTE   5430          NaN
#
#    Codigo Postal  ...      Telefono SCORE PATENTADOS 2015-2020  \
# 0           7600  ...           NaN   980                  NaN
# 1           2814  ...           NaN   222                  NaN
# 2           1758  ...  2.202438e+09   831                  NaN
# 3           1736  ...           NaN   955                  NaN
# 4           1650  ...  1.147548e+09   120                  NaN
#
#   PATENTADOS MENOR AL 2015  SIN AUTOS PATENTADOS  DOS O MAS PROPIEDADES  \
# 0                      NaN                   1.0                    1.0
# 1                      NaN                   1.0                    NaN
# 2                      NaN                   1.0                    NaN
# 3                      1.0                   NaN                    1.0
# 4                      NaN                   1.0                    NaN
#
#    UNA PROPIEDAD  SIN PROPIEDADES  TITULAR CON SITUACION 1 o 2  \
# 0            NaN              NaN                          1.0
# 1            1.0              NaN                          1.0
# 2            NaN              1.0                          1.0
# 3            NaN              NaN                          1.0
# 4            NaN              1.0                          1.0
#
#    GRUPO FAMILIAR CON SITUACION 1 o 2
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 1.0
# 4                                 NaN
#
# [5 rows x 232 columns]

# %%
#df.to_csv ('test_columns.csv')

# %% [markdown]
# # 4) Concatenación con .csv enviado

# %% [markdown]
# Vamos a concatenar nuestro dataframe con el dataframe enviado para enriquecer. Para esto, vamos a hacer una limpieza inicial de cómo se enviaron esos datos. Finalmente, se uniran ambos dataframes por __DNI__.

# %% [markdown]
# ## 4.1) Dataset: PyP

# %% [markdown]
# Vamos a analizar y limpiar el dataset enviado a PyP para el enriquecimiento:

# %%
df_pyp = pd.read_excel('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/PyP/Datasets/Datasets enviados/0114-BBVA-Estados-FiltroA.xlsx')

# %%
df_pyp.head()
# Out:
#              IDMOROSO                                    NOMBRE  \
# 0  DNI 10021189        MOYA ALBERTO RENE
# 1  DNI 11225038        FORAY SUSANA MARGARITA
# 2  DNI 11352773        BAEZ DANIEL
# 3  DNI 11704949        HUELMO CARLOS AVELINO
# 4  DNI 11734026        CELANO OSCAR ALBERTO
#
#               IDCLIENTE                ESTADO               FILTROA
# 0  FRANCES_2012          ASIGNADO              2 - Ag 2ra
# 1  FRANCES_2012          FALLECIDO             1 - Ag 1ra
# 2  FRANCES_2012          INTERESADO            2 - Ag 2ra
# 3  FRANCES_2012          ROTACION              1 - Ag 1ra
# 4  FRANCES_2012          NO INTERESADO         2 - Ag 2ra

# %% [markdown]
# Dropeamos la última columna que no tiene datos

# %% [markdown]
# Creamos una columna que contenga IDMOROSO + DATOADIC según corresponda

# %%
#df_pyp.loc[(df_pyp['IDCLIENTE'].str.startswith('AMEX')) , 'NRO_DOC'] = df_pyp['DATOADIC']

# %%
df_pyp.loc[~(df_pyp['IDCLIENTE'].str.startswith('AMEX')) , 'NRO_DOC'] = df_pyp['IDMOROSO']

# %%
df_pyp.head()
# Out:
#              IDMOROSO                                    NOMBRE  \
# 0  DNI 10021189        MOYA ALBERTO RENE
# 1  DNI 11225038        FORAY SUSANA MARGARITA
# 2  DNI 11352773        BAEZ DANIEL
# 3  DNI 11704949        HUELMO CARLOS AVELINO
# 4  DNI 11734026        CELANO OSCAR ALBERTO
#
#               IDCLIENTE                ESTADO               FILTROA  \
# 0  FRANCES_2012          ASIGNADO              2 - Ag 2ra
# 1  FRANCES_2012          FALLECIDO             1 - Ag 1ra
# 2  FRANCES_2012          INTERESADO            2 - Ag 2ra
# 3  FRANCES_2012          ROTACION              1 - Ag 1ra
# 4  FRANCES_2012          NO INTERESADO         2 - Ag 2ra
#
#               NRO_DOC
# 0  DNI 10021189
# 1  DNI 11225038
# 2  DNI 11352773
# 3  DNI 11704949
# 4  DNI 11734026

# %% [markdown]
# ## 12.2) DNI Cleaning

# %% [markdown]
# Limpiamos el dataframe __df_pyp__, ya que dentro de DATO_A_ENVIAR tenemos 9 tipos de casos diferentes de datos:
#
# - DNI 12345678
# - DNI12345678
# - DNIE1234678
# - LC  1234567
# - LE  1234567
# - CUIT00123456780
# - 00123456780 --> Es un CUIT.
# - 00 12345678 0 --> Es un CUIT.
# - DNI 00123456780 --> Dice DNI pero es un CUIT de una persona __jurídica__ (TO DO)

# %% [markdown]
# Para eso definimos 5 funciones:
#
# - __Tipo_DOC__: Se definen dos funciones para determinar el tipo de DNI. Una inicial, y otra para corregir sobre el dataframe resultante.
# - __Standard DNI__: Estandariza los DNI para 7 de los casos. Esta función debe ejecutarse en primer lugar.
# - __DNI Spaces__: Elimina los espacios.
# - __DNI Zero__: Elimina los ceros iniciales de ciertos CUITs para que coincidan con los DNI.
# - __Cuit__: Decisión sobre dejar un cuit o volverlo DNI

# %%
def tipo_doc_1 (string_dni):
    
    if 'DNI' in string_dni:
        tipo = 'DNI'
    
    elif 'LC' in string_dni:
        tipo = 'LC'
    
    elif 'LE' in string_dni:
        tipo = 'LE'
    
    elif 'DNIE' in string_dni:
        tipo = 'DNIE'    
    
    elif ((string_dni.startswith(('CUIT30','CUIT33','CUIT34'))) & (len(string_dni)>8)):
        tipo = 'CUIT'
        
    elif ((string_dni.startswith(('30','33','34'))) & (len(string_dni)>8)):
        tipo = 'CUIT'

    elif ((string_dni.startswith(('20','23','24','27'))) & (len(string_dni)>8)):
        tipo = 'DNI'

    elif ((string_dni.startswith(('CUIT20','CUIT23','CUIT24','CUIT27'))) & (len(string_dni)>8)):
        tipo = 'DNI'
        
    else:
        tipo = 'DNI'
    
    return tipo

# %%
def tipo_doc_2 (string_dni, tipo_original):
    
    if (len(string_dni) > 8) & (tipo_original == 'DNI'):
        tipo = 'CUIT'
    else:
        tipo = tipo_original
    return tipo

# %%
def standard_dni (string_dni):
    """DNI separation by each case.
    """
    
    if 'DNI ' in string_dni:
        dni = string_dni.split('DNI ')[1]
        
    elif 'DNIE' in string_dni:
        dni = string_dni.split('DNIE')[1]
    
    elif 'DNI' in string_dni:
        dni = string_dni.split('DNI')[1]
    
    elif 'LC  ' in string_dni:
        dni = string_dni.split('LC  ')[1]
    
    elif 'LE  ' in string_dni:
        dni = string_dni.split('LE  ')[1]
    
    elif 'CUIT' in string_dni:
        dni = string_dni.split('CUIT')[1]
        
    else:
        dni = string_dni
        
    return dni

# %%
def dni_characters (string_dni):
    
    if ' ' in string_dni:
        dni = string_dni.replace(' ','')
        
    elif '-' in string_dni:
        dni = string_dni.replace('-','')

    else:
        dni = string_dni
    
    return dni

# %%
def cuit (string_dni):
    
    if ((string_dni.startswith('20')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]
        
    elif ((string_dni.startswith('23')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]
        
    elif ((string_dni.startswith('24')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]

    elif ((string_dni.startswith('27')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]

    else:
        cuit = string_dni
        
    return cuit

# %%
def dni_zero (string_dni):
    
    if string_dni.startswith('0'):
        dni = string_dni [1:]

    else:
        dni = string_dni
    
    return dni

# %% [markdown]
# En primer lugar, trimmeamos los espacios que sobran:

# %%
df_pyp['NRO_DOC'] = [(str(df_pyp['NRO_DOC'][i]).strip()) for i in range (df_pyp['NRO_DOC'].count())]

# %% [markdown]
# Se implementan estas funciones:

# %% [markdown]
# Para determinar el __TIPO DE DOCUMENTO__ en primer lugar:

# %%
df_pyp['TIPO_DOC'] = [tipo_doc_1(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %% [markdown]
# Para la limpieza de DNIs:

# %%
df_pyp['NRO_DOC'] = [standard_dni(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %%
df_pyp['NRO_DOC'] = [dni_characters(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %%
df_pyp['NRO_DOC'] = [cuit(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %%
df_pyp['NRO_DOC'] = [dni_zero(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %% [markdown]
# Para corregir el __TIPO DE DOCUMENTO__ sobre el dataframe resultante

# %%
df_pyp['TIPO_DOC'] = [tipo_doc_2(df_pyp['NRO_DOC'][i],df_pyp['TIPO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %%
df_pyp.head()
# Out:
#              IDMOROSO                                    NOMBRE  \
# 0  DNI 10021189        MOYA ALBERTO RENE
# 1  DNI 11225038        FORAY SUSANA MARGARITA
# 2  DNI 11352773        BAEZ DANIEL
# 3  DNI 11704949        HUELMO CARLOS AVELINO
# 4  DNI 11734026        CELANO OSCAR ALBERTO
#
#               IDCLIENTE                ESTADO               FILTROA   NRO_DOC  \
# 0  FRANCES_2012          ASIGNADO              2 - Ag 2ra            10021189
# 1  FRANCES_2012          FALLECIDO             1 - Ag 1ra            11225038
# 2  FRANCES_2012          INTERESADO            2 - Ag 2ra            11352773
# 3  FRANCES_2012          ROTACION              1 - Ag 1ra            11704949
# 4  FRANCES_2012          NO INTERESADO         2 - Ag 2ra            11734026
#
#   TIPO_DOC
# 0      DNI
# 1      DNI
# 2      DNI
# 3      DNI
# 4      DNI

# %% [markdown]
# # 5) Union de Dataframes

# %% [markdown]
# Se unen ambos dataframes en la columna NRO_DOC

# %% [markdown]
# Convertimos la columna NRO_DOC de objeto a INT para hacer la unión

# %%
df = df.rename(columns = {'Dni':'NRO_DOC'})

# %%
df = df.astype({'NRO_DOC': 'str'})

# %%
df_union = pd.merge(df,df_pyp, on='NRO_DOC', how='inner')

# %%
df_union.shape
# Out:
# (571, 238)

# %%
df_union.head()
# Out:
#           Cuil  NRO_DOC Fecha de Nac. Fecha de Defuncion Sexo  \
# 0  27037093993  3709399    1937-12-08                NaN    F
# 1  27056924243  5692424    1947-10-25                NaN    F
# 2  27059339341  5933934    1948-09-24                NaN    F
# 3  20061549715  6154971    1936-01-01                NaN    M
# 4  27063607423  6360742    1950-05-12                NaN    F
#
#                  Titular                    Calle Numero Piso y Depto  \
# 0         RODRIGUEZ HEBE             BUENOS AIRES   2747          NaN
# 1    BULFONI GLADYS ROSA  H YRIGOYEN S/N-CARDALES    S/N          NaN
# 2      BENITEZ ANA MARIA                    ZINNY   7210          NaN
# 3      OLIVER OSCAR RAUL              TRIUNVIRATO   2873          NaN
# 4  PORTALEA ALICIA NOEMI              SAN VICENTE   5430          NaN
#
#    Codigo Postal  ... UNA PROPIEDAD SIN PROPIEDADES  \
# 0           7600  ...           NaN             NaN
# 1           2814  ...           1.0             NaN
# 2           1758  ...           NaN             1.0
# 3           1736  ...           NaN             NaN
# 4           1650  ...           NaN             1.0
#
#   TITULAR CON SITUACION 1 o 2 GRUPO FAMILIAR CON SITUACION 1 o 2  \
# 0                         1.0                                NaN
# 1                         1.0                                NaN
# 2                         1.0                                NaN
# 3                         1.0                                1.0
# 4                         1.0                                NaN
#
#              IDMOROSO                                    NOMBRE  \
# 0  LC  3709399         RODRIGUEZ HEBE
# 1  LC  5692424         BULFONI GLADYS ROSA
# 2  LC  5933934         BENITEZ ANA MARIA
# 3  LE  6154971         OLIVER OSCAR
# 4  LC  6360742         PORTALEA ALICIA NOEMI
#
#               IDCLIENTE                ESTADO               FILTROA  TIPO_DOC
# 0  FRANCES_2012          COMPROMISO            2 - Ag 2ra                  LC
# 1  FRANCES_2012          NO INTERESADO         1 - Ag 1ra                  LC
# 2  FRANCES_2012          ROTACION              1 - Ag 1ra                  LC
# 3  FRANCES_2012          ROTACION              1 - Ag 1ra                  LE
# 4  FRANCES_2012          ROTACION              1 - Ag 1ra                  LC
#
# [5 rows x 238 columns]

# %% [markdown]
# # 6) Rango de Ingresos

# %%
#df_union.to_excel('df_union_test_columns.xlsx')

# %%
df_export = df_union[['IDMOROSO','IDCLIENTE','ESTADO','FILTROA','TIPO_DOC','NRO_DOC','NOMBRE','Cuil','Marca Defuncion'
                     ,'PATENTADOS 2015-2020','PATENTADOS MENOR AL 2015','SIN AUTOS PATENTADOS','DOS O MAS PROPIEDADES'
                     ,'UNA PROPIEDAD','SIN PROPIEDADES','TITULAR CON SITUACION 1 o 2','GRUPO FAMILIAR CON SITUACION 1 o 2'
                     ,'Ingresos Mes 6','Rango Ingresos autonomo','Rango de ingresos grupo familiar']]

# %%
df_export = df_export.rename(columns = {'Cuil':'CUIT_CUIL', 'Marca Defuncion':'MARCA_DEFUNCION'
                                       ,'Ingresos Mes 6':'ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA','Rango Ingresos autonomo':'RANGO DE INGRESOS AUTONOMO TITULAR'
                                       ,'Rango de ingresos grupo familiar': 'RANGO DE INGRESOS GRUPO FAMILIAR'})

# %%
df_export.head()
# Out:
#              IDMOROSO             IDCLIENTE                ESTADO  \
# 0  LC  3709399         FRANCES_2012          COMPROMISO
# 1  LC  5692424         FRANCES_2012          NO INTERESADO
# 2  LC  5933934         FRANCES_2012          ROTACION
# 3  LE  6154971         FRANCES_2012          ROTACION
# 4  LC  6360742         FRANCES_2012          ROTACION
#
#                 FILTROA TIPO_DOC  NRO_DOC  \
# 0  2 - Ag 2ra                 LC  3709399
# 1  1 - Ag 1ra                 LC  5692424
# 2  1 - Ag 1ra                 LC  5933934
# 3  1 - Ag 1ra                 LE  6154971
# 4  1 - Ag 1ra                 LC  6360742
#
#                                      NOMBRE    CUIT_CUIL  MARCA_DEFUNCION  \
# 0  RODRIGUEZ HEBE                            27037093993                0
# 1  BULFONI GLADYS ROSA                       27056924243                0
# 2  BENITEZ ANA MARIA                         27059339341                0
# 3  OLIVER OSCAR                              20061549715                0
# 4  PORTALEA ALICIA NOEMI                     27063607423                0
#
#    PATENTADOS 2015-2020  PATENTADOS MENOR AL 2015  SIN AUTOS PATENTADOS  \
# 0                   NaN                       NaN                   1.0
# 1                   NaN                       NaN                   1.0
# 2                   NaN                       NaN                   1.0
# 3                   NaN                       1.0                   NaN
# 4                   NaN                       NaN                   1.0
#
#    DOS O MAS PROPIEDADES  UNA PROPIEDAD  SIN PROPIEDADES  \
# 0                    1.0            NaN              NaN
# 1                    NaN            1.0              NaN
# 2                    NaN            NaN              1.0
# 3                    1.0            NaN              NaN
# 4                    NaN            NaN              1.0
#
#    TITULAR CON SITUACION 1 o 2  GRUPO FAMILIAR CON SITUACION 1 o 2  \
# 0                          1.0                                 NaN
# 1                          1.0                                 NaN
# 2                          1.0                                 NaN
# 3                          1.0                                 1.0
# 4                          1.0                                 NaN
#
#   ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA  \
# 0                                                 A5
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   RANGO DE INGRESOS AUTONOMO TITULAR RANGO DE INGRESOS GRUPO FAMILIAR
# 0                                NaN                              NaN
# 1                                NaN                               A7
# 2                                NaN                               A4
# 3                                NaN                               A1
# 4                                NaN                              NaN

# %% [markdown]
# ### Relación de Dependencia

# %%
df_export.loc[((df_export['ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] == 'A7')
            ) , 'SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] = 10

# %%
df_export.loc[((df_export['ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] == 'A6')
            ) , 'SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] = 7

# %%
df_export.loc[((df_export['ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] == 'A5')
            ) , 'SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] = 5

# %%
df_export.loc[((df_export['ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] == 'A4')
            ) , 'SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] = 4

# %%
df_export.loc[((df_export['ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] == 'A3')
            ) , 'SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] = 3

# %%
df_export.loc[((df_export['ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] == 'A2')
            ) , 'SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] = 2

# %%
df_export.loc[((df_export['ULTIMO RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] == 'A1')
            ) , 'SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA'] = 1

# %% [markdown]
# ### Autonomo

# %%
df_export.loc[((df_export['RANGO DE INGRESOS AUTONOMO TITULAR'] == 'A7')
            ) , 'SCORING RANGO DE INGRESOS AUTONOMO TITULAR'] = 10

# %%
df_export.loc[((df_export['RANGO DE INGRESOS AUTONOMO TITULAR'] == 'A6')
            ) , 'SCORING RANGO DE INGRESOS AUTONOMO TITULAR'] = 7

# %%
df_export.loc[((df_export['RANGO DE INGRESOS AUTONOMO TITULAR'] == 'A5')
            ) , 'SCORING RANGO DE INGRESOS AUTONOMO TITULAR'] = 5

# %%
df_export.loc[((df_export['RANGO DE INGRESOS AUTONOMO TITULAR'] == 'A4')
            ) , 'SCORING RANGO DE INGRESOS AUTONOMO TITULAR'] = 4

# %%
df_export.loc[((df_export['RANGO DE INGRESOS AUTONOMO TITULAR'] == 'A3')
            ) , 'SCORING RANGO DE INGRESOS AUTONOMO TITULAR'] = 3

# %%
df_export.loc[((df_export['RANGO DE INGRESOS AUTONOMO TITULAR'] == 'A2')
            ) , 'SCORING RANGO DE INGRESOS AUTONOMO TITULAR'] = 2

# %%
df_export.loc[((df_export['RANGO DE INGRESOS AUTONOMO TITULAR'] == 'A1')
            ) , 'SCORING RANGO DE INGRESOS AUTONOMO TITULAR'] = 1

# %% [markdown]
# ### Grupo Familiar

# %%
df_export.loc[((df_export['RANGO DE INGRESOS GRUPO FAMILIAR'] == 'A7')
            ) , 'SCORING RANGO DE INGRESOS GRUPO FAMILIAR'] = 5

# %%
df_export.loc[((df_export['RANGO DE INGRESOS GRUPO FAMILIAR'] == 'A6')
            ) , 'SCORING RANGO DE INGRESOS GRUPO FAMILIAR'] = 3.5

# %%
df_export.loc[((df_export['RANGO DE INGRESOS GRUPO FAMILIAR'] == 'A5')
            ) , 'SCORING RANGO DE INGRESOS GRUPO FAMILIAR'] = 2.5

# %%
df_export.loc[((df_export['RANGO DE INGRESOS GRUPO FAMILIAR'] == 'A4')
            ) , 'SCORING RANGO DE INGRESOS GRUPO FAMILIAR'] = 2

# %%
df_export.loc[((df_export['RANGO DE INGRESOS GRUPO FAMILIAR'] == 'A3')
            ) , 'SCORING RANGO DE INGRESOS GRUPO FAMILIAR'] = 1.5

# %%
df_export.loc[((df_export['RANGO DE INGRESOS GRUPO FAMILIAR'] == 'A2')
            ) , 'SCORING RANGO DE INGRESOS GRUPO FAMILIAR'] = 1

# %%
df_export.loc[((df_export['RANGO DE INGRESOS GRUPO FAMILIAR'] == 'A1')
            ) , 'SCORING RANGO DE INGRESOS GRUPO FAMILIAR'] = 0.5

# %% [markdown]
# # 7) Scoring Vehiculos, Propiedades y Situación BCRA

# %%
df_export.loc[((df_export['PATENTADOS 2015-2020'] == 1)
            ) , 'SCORING PATENTADOS 2015-2020'] = 3

# %%
df_export.loc[((df_export['PATENTADOS MENOR AL 2015'] == 1)
            ) , 'SCORING PATENTADOS MENOR AL 2015'] = 2

# %%
df_export.loc[((df_export['DOS O MAS PROPIEDADES'] == 1)
            ) , 'SCORING DOS O MAS PROPIEDADES'] = 7

# %%
df_export.loc[((df_export['UNA PROPIEDAD'] == 1)
            ) , 'SCORING UNA PROPIEDAD'] = 3.5

# %%
df_export.loc[((df_export['TITULAR CON SITUACION 1 o 2'] == 1)
            ) , 'SCORING TITULAR CON SITUACION 1 o 2'] = 7

# %%
df_export.loc[((df_export['GRUPO FAMILIAR CON SITUACION 1 o 2'] == 1)
            ) , 'SCORING GRUPO FAMILIAR CON SITUACION 1 o 2'] = 3.5

# %%
df_export.head()
# Out:
#              IDMOROSO             IDCLIENTE                ESTADO  \
# 0  LC  3709399         FRANCES_2012          COMPROMISO
# 1  LC  5692424         FRANCES_2012          NO INTERESADO
# 2  LC  5933934         FRANCES_2012          ROTACION
# 3  LE  6154971         FRANCES_2012          ROTACION
# 4  LC  6360742         FRANCES_2012          ROTACION
#
#                 FILTROA TIPO_DOC  NRO_DOC  \
# 0  2 - Ag 2ra                 LC  3709399
# 1  1 - Ag 1ra                 LC  5692424
# 2  1 - Ag 1ra                 LC  5933934
# 3  1 - Ag 1ra                 LE  6154971
# 4  1 - Ag 1ra                 LC  6360742
#
#                                      NOMBRE    CUIT_CUIL  MARCA_DEFUNCION  \
# 0  RODRIGUEZ HEBE                            27037093993                0
# 1  BULFONI GLADYS ROSA                       27056924243                0
# 2  BENITEZ ANA MARIA                         27059339341                0
# 3  OLIVER OSCAR                              20061549715                0
# 4  PORTALEA ALICIA NOEMI                     27063607423                0
#
#    PATENTADOS 2015-2020  ...  RANGO DE INGRESOS GRUPO FAMILIAR  \
# 0                   NaN  ...                               NaN
# 1                   NaN  ...                                A7
# 2                   NaN  ...                                A4
# 3                   NaN  ...                                A1
# 4                   NaN  ...                               NaN
#
#    SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    SCORING RANGO DE INGRESOS AUTONOMO TITULAR  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    SCORING RANGO DE INGRESOS GRUPO FAMILIAR  SCORING PATENTADOS 2015-2020  \
# 0                                       NaN                           NaN
# 1                                       5.0                           NaN
# 2                                       2.0                           NaN
# 3                                       0.5                           NaN
# 4                                       NaN                           NaN
#
#    SCORING PATENTADOS MENOR AL 2015  SCORING DOS O MAS PROPIEDADES  \
# 0                               NaN                            7.0
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               2.0                            7.0
# 4                               NaN                            NaN
#
#   SCORING UNA PROPIEDAD SCORING TITULAR CON SITUACION 1 o 2  \
# 0                   NaN                                 7.0
# 1                   3.5                                 7.0
# 2                   NaN                                 7.0
# 3                   NaN                                 7.0
# 4                   NaN                                 7.0
#
#   SCORING GRUPO FAMILIAR CON SITUACION 1 o 2
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        3.5
# 4                                        NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # Scoring Total

# %%
columns_to_sum = ['SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA', 'SCORING RANGO DE INGRESOS AUTONOMO TITULAR'
,'SCORING RANGO DE INGRESOS GRUPO FAMILIAR','SCORING PATENTADOS 2015-2020','SCORING PATENTADOS MENOR AL 2015'
                                        ,'SCORING DOS O MAS PROPIEDADES','SCORING UNA PROPIEDAD', 'SCORING TITULAR CON SITUACION 1 o 2'
,'SCORING GRUPO FAMILIAR CON SITUACION 1 o 2']

# %%
columns_to_sum
# Out:
# ['SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA',
#  'SCORING RANGO DE INGRESOS AUTONOMO TITULAR',
#  'SCORING RANGO DE INGRESOS GRUPO FAMILIAR',
#  'SCORING PATENTADOS 2015-2020',
#  'SCORING PATENTADOS MENOR AL 2015',
#  'SCORING DOS O MAS PROPIEDADES',
#  'SCORING UNA PROPIEDAD',
#  'SCORING TITULAR CON SITUACION 1 o 2',
#  'SCORING GRUPO FAMILIAR CON SITUACION 1 o 2']

# %%
df_export['SCORING TOTAL'] = df_export[columns_to_sum].sum(axis=1)

# %%
df_export.head()
# Out:
#              IDMOROSO             IDCLIENTE                ESTADO  \
# 0  LC  3709399         FRANCES_2012          COMPROMISO
# 1  LC  5692424         FRANCES_2012          NO INTERESADO
# 2  LC  5933934         FRANCES_2012          ROTACION
# 3  LE  6154971         FRANCES_2012          ROTACION
# 4  LC  6360742         FRANCES_2012          ROTACION
#
#                 FILTROA TIPO_DOC  NRO_DOC  \
# 0  2 - Ag 2ra                 LC  3709399
# 1  1 - Ag 1ra                 LC  5692424
# 2  1 - Ag 1ra                 LC  5933934
# 3  1 - Ag 1ra                 LE  6154971
# 4  1 - Ag 1ra                 LC  6360742
#
#                                      NOMBRE    CUIT_CUIL  MARCA_DEFUNCION  \
# 0  RODRIGUEZ HEBE                            27037093993                0
# 1  BULFONI GLADYS ROSA                       27056924243                0
# 2  BENITEZ ANA MARIA                         27059339341                0
# 3  OLIVER OSCAR                              20061549715                0
# 4  PORTALEA ALICIA NOEMI                     27063607423                0
#
#    PATENTADOS 2015-2020  ...  \
# 0                   NaN  ...
# 1                   NaN  ...
# 2                   NaN  ...
# 3                   NaN  ...
# 4                   NaN  ...
#
#    SCORING RANGO DE INGRESOS TITULAR RELACION DEPENDENCIA  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    SCORING RANGO DE INGRESOS AUTONOMO TITULAR  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    SCORING RANGO DE INGRESOS GRUPO FAMILIAR  SCORING PATENTADOS 2015-2020  \
# 0                                       NaN                           NaN
# 1                                       5.0                           NaN
# 2                                       2.0                           NaN
# 3                                       0.5                           NaN
# 4                                       NaN                           NaN
#
#    SCORING PATENTADOS MENOR AL 2015  SCORING DOS O MAS PROPIEDADES  \
# 0                               NaN                            7.0
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               2.0                            7.0
# 4                               NaN                            NaN
#
#    SCORING UNA PROPIEDAD SCORING TITULAR CON SITUACION 1 o 2  \
# 0                    NaN                                 7.0
# 1                    3.5                                 7.0
# 2                    NaN                                 7.0
# 3                    NaN                                 7.0
# 4                    NaN                                 7.0
#
#   SCORING GRUPO FAMILIAR CON SITUACION 1 o 2 SCORING TOTAL
# 0                                        NaN          19.0
# 1                                        NaN          15.5
# 2                                        NaN           9.0
# 3                                        3.5          20.0
# 4                                        NaN           7.0
#
# [5 rows x 30 columns]

# %%
#df_export = df_export.rename(columns={'Estado':'ESTADO'})

# %%
df_export.shape
# Out:
# (571, 30)

# %% [markdown]
# ### Categoria: AA, A, B y C

# %%
df_export.loc[((df_export['SCORING TOTAL'] >= 13.5)
            ) , 'CATEGORIA'] = 'AA'

# %%
df_export.loc[((df_export['SCORING TOTAL'] >= 10) & (df_export['SCORING TOTAL'] <= 13)
            ) , 'CATEGORIA'] = 'A'

# %%
df_export.loc[((df_export['SCORING TOTAL'] >= 4) & (df_export['SCORING TOTAL'] <= 9.5)
            ) , 'CATEGORIA'] = 'B'

# %%
df_export.loc[((df_export['SCORING TOTAL'] <= 3.5)
            ) , 'CATEGORIA'] = 'C'

# %% [markdown]
# # Export supervisores

# %%
df_export = df_export[['IDMOROSO','IDCLIENTE','ESTADO','FILTROA','NOMBRE','MARCA_DEFUNCION','SCORING TOTAL','CATEGORIA']]

# %%
#df_export = df_export[['IDMOROSO','IDCLIENTE','ESTADO','FILTROA','TIPO_DOC','NRO_DOC','NOMBRE','CUIT_CUIL','MARCA_DEFUNCION'
 #                    ,'SCORING TOTAL']]

# %%
#df_export.to_excel('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/PyP/Exports/Score Morosos/PyP_score_morosos_2201.xlsx', index=False)

# %% [markdown]
# # Export DAM_DATOS_PERSONALES

# %%
df_export_dam = df_export[['IDMOROSO','SCORING TOTAL']]

# %%
df_export_dam.shape
# Out:
# (571, 2)

# %%
df_export_dam = df_export_dam.drop_duplicates(subset=['IDMOROSO','SCORING TOTAL'])

# %%
df_export_dam.shape
# Out:
# (571, 2)

# %% [markdown]
# ### Columnas adicionales (por ahora nulas)

# %%
df_export_dam = df_export_dam.assign(NOMBRE_COMPLETO=np.nan)

# %%
df_export_dam = df_export_dam.assign(GENERO=np.nan)

# %%
df_export_dam = df_export_dam.assign(FECHA_NACIMIENTO=np.nan)

# %%
df_export_dam = df_export_dam.assign(ESTADO_CIVIL=np.nan)

# %%
df_export_dam = df_export_dam.assign(HIJOS=np.nan)

# %%
df_export_dam = df_export_dam.assign(SCORING_FINANCIERO=np.nan)

# %%
df_export_dam = df_export_dam.assign(SCORING_TERCEROS=np.nan)

# %%
df_export_dam = df_export_dam.assign(NIVEL_DE_INGRESO=np.nan)

# %%
df_export_dam = df_export_dam.assign(FECHA_ULTIMO_PAGO=np.nan)

# %%
df_export_dam.head()
# Out:
#              IDMOROSO  SCORING TOTAL  NOMBRE_COMPLETO  GENERO  \
# 0  LC  3709399                  19.0              NaN     NaN
# 1  LC  5692424                  15.5              NaN     NaN
# 2  LC  5933934                   9.0              NaN     NaN
# 3  LE  6154971                  20.0              NaN     NaN
# 4  LC  6360742                   7.0              NaN     NaN
#
#    FECHA_NACIMIENTO  ESTADO_CIVIL  HIJOS  SCORING_FINANCIERO  \
# 0               NaN           NaN    NaN                 NaN
# 1               NaN           NaN    NaN                 NaN
# 2               NaN           NaN    NaN                 NaN
# 3               NaN           NaN    NaN                 NaN
# 4               NaN           NaN    NaN                 NaN
#
#    SCORING_TERCEROS  NIVEL_DE_INGRESO  FECHA_ULTIMO_PAGO
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN

# %%
df_export_dam = df_export_dam.rename(columns={'SCORING TOTAL':'SCORING_MOPC'})

# %%
df_export_dam = df_export_dam[['IDMOROSO','NOMBRE_COMPLETO','GENERO','FECHA_NACIMIENTO','ESTADO_CIVIL','HIJOS','SCORING_MOPC'
                              ,'SCORING_FINANCIERO','SCORING_TERCEROS','NIVEL_DE_INGRESO','FECHA_ULTIMO_PAGO']]

# %%
df_export_dam.head()
# Out:
#              IDMOROSO  NOMBRE_COMPLETO  GENERO  FECHA_NACIMIENTO  \
# 0  LC  3709399                     NaN     NaN               NaN
# 1  LC  5692424                     NaN     NaN               NaN
# 2  LC  5933934                     NaN     NaN               NaN
# 3  LE  6154971                     NaN     NaN               NaN
# 4  LC  6360742                     NaN     NaN               NaN
#
#    ESTADO_CIVIL  HIJOS  SCORING_MOPC  SCORING_FINANCIERO  SCORING_TERCEROS  \
# 0           NaN    NaN          19.0                 NaN               NaN
# 1           NaN    NaN          15.5                 NaN               NaN
# 2           NaN    NaN           9.0                 NaN               NaN
# 3           NaN    NaN          20.0                 NaN               NaN
# 4           NaN    NaN           7.0                 NaN               NaN
#
#    NIVEL_DE_INGRESO  FECHA_ULTIMO_PAGO
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN

# %%
df_export_dam.to_excel('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/PyP/Exports/DAM_DATOS_PERSONALES/PyP_DAM_DATOS_PERSONALES_1401.xlsx', index=False)
df_export_dam.to_csv('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/PyP/Exports/DAM_DATOS_PERSONALES/PyP_DAM_DATOS_PERSONALES_1401.csv', index=False)

# %% [markdown]
# # Analisis total (incluyendo estado devuelto)

# %%
#deuda_con_devuelto = df_bsr.groupby("SCORING TOTAL").sum()["DEUDA_TOTAL"]

# %%
#deuda_con_devuelto.to_excel('D:\MOPC\Enriquecimiento de Datos\Data Cleaning\PyP\Exports\Analisis Cartera Completa\Deuda_con_devuelto.xlsx')

# %%
#cantidad_morosos_devuelto = df_export['SCORING TOTAL'].value_counts().sort_index(ascending=False)

# %%
#cantidad_morosos_devuelto

# %%
#cantidad_morosos_devuelto.to_excel('D:\MOPC\Enriquecimiento de Datos\Data Cleaning\PyP\Exports\Analisis Cartera Completa\Cantidad_morosos_devuelto.xlsx')

# %% [markdown]
# # Analisis sin estado devuelto

# %%
#df_sin_devuelto = df_bsr[df_bsr['ESTADO AL 04-12']!='DEVUELTO            ']

# %%
#deuda = df_sin_devuelto.groupby("SCORING TOTAL").sum()["DEUDA_TOTAL"]

# %%
#deuda.to_excel('D:\MOPC\Enriquecimiento de Datos\Data Cleaning\PyP\Exports\Analisis Cartera Completa\Deuda_sin_devuelto.xlsx')

# %% [markdown]
# ## Value Counts sin devuelto

# %%
#subset_df = df_bsr[df_bsr["ESTADO AL 04-12"] != 'DEVUELTO            ']

# %%
#cantidad_morosos = subset_df ['SCORING TOTAL'].value_counts().sort_index(ascending=False)

# %%
#cantidad_morosos

# %%
#cantidad_morosos.to_excel('D:\MOPC\Enriquecimiento de Datos\Data Cleaning\PyP\Exports\Analisis Cartera Completa\Cantidad_morosos_sin_devuelto.xlsx')
