# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/PyP/Datasets/Datos duplicados/PyP_telefonos_2402_duplicados.csv')

# %%
df.head()
# Out:
#              IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO  PERSONAL
# 1  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO   LABORAL
# 2  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO   LABORAL
# 3  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO  PERSONAL
# 4  DNI 35923953            DNI  35923953  20359239530  TEL.CELULAR  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  2644231196           Propio             P2  2021-02-24 10:20:28.717029
# 1  3546463805  Ajeno_empleador             P2  2021-02-24 10:20:28.717029
# 2  3546463806  Ajeno_empleador             P2  2021-02-24 10:20:28.717029
# 3  2644231196   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
# 4  2646737373   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         1.0
# 2           0                 NaN                    NaN         1.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0

# %%
df.shape
# Out:
# (4183, 14)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (4183, 14)

# %% [markdown]
# ## Dato a str + strip()

# %%
df ['DATO'] = df['DATO'].astype(str)

# %%
df['DATO'] = df['DATO'].str.strip()

# %% [markdown]
# ## Verificados

# %% [markdown]
# Si verificado es false, pasamos a NaN la fecha de verificación

# %%
df.loc[df['VERIFICADO'] == 0, 'FECHA_VERIFICACION'] = np.nan

# %%
df.tail()
# Out:
#                 IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL      TIPO   SUBTIPO  \
# 4178  DNI 30749617            DNI  30749617  20307496179  TEL.FIJO  PERSONAL
# 4179  DNI 22244613            DNI  22244613  27222446134  TEL.FIJO  PERSONAL
# 4180  DNI 2080464             DNI   2080464  27020804640  TEL.FIJO  PERSONAL
# 4181  DNI 30529846            DNI  30529846  27305298463  TEL.FIJO  PERSONAL
# 4182  DNI 30906890            DNI  30906890  23309068904  TEL.FIJO  PERSONAL
#
#             DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 4178  1144633936            Ajeno             P2  2021-02-24 10:20:28.717029
# 4179  3414578578            Ajeno             P2  2021-02-24 10:20:28.717029
# 4180  3424833473            Ajeno             P2  2021-02-24 10:20:28.717029
# 4181  2920432065            Ajeno             P2  2021-02-24 10:20:28.717029
# 4182  3814830545            Ajeno             P2  2021-02-24 10:20:28.717029
#
#       VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 4178           0                 NaN                    NaN         2.0
# 4179           0                 NaN                    NaN         2.0
# 4180           0                 NaN                    NaN         2.0
# 4181           0                 NaN                    NaN         2.0
# 4182           0                 NaN                    NaN         2.0

# %% [markdown]
# # Subset: Duplicados

# %% [markdown]
# Me quedo con los todos los que tienen duplicados la combinatoria IDMOROSO, DATO y PROVEEDOR DATO, y reviso qué pasa en cada caso

# %%
duplicates_subset = df[df.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
duplicates_subset.head()
# Out:
#               IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL      TIPO   SUBTIPO  \
# 0   DNI 35923953            DNI  35923953  20359239530  TEL.FIJO  PERSONAL
# 3   DNI 35923953            DNI  35923953  20359239530  TEL.FIJO  PERSONAL
# 5   DNI 27244548            DNI  27244548  20272445487  TEL.FIJO  PERSONAL
# 7   DNI 27244548            DNI  27244548  20272445487  TEL.FIJO  PERSONAL
# 24  DNI 38608367            DNI  38608367  27386083679  TEL.FIJO  PERSONAL
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0   2644231196           Propio             P2  2021-02-24 10:20:28.717029
# 3   2644231196   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
# 5   1147409350           Propio             P2  2021-02-24 10:20:28.717029
# 7   1147409350   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
# 24  2284431449           Propio             P2  2021-02-24 10:20:28.717029
#
#     VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 0            0                 NaN                    NaN         2.0
# 3            0                 NaN                    NaN         2.0
# 5            0                 NaN                    NaN         2.0
# 7            0                 NaN                    NaN         2.0
# 24           0                 NaN                    NaN         2.0

# %%
duplicates_subset.shape
# Out:
# (540, 14)

# %%
#duplicates_subset[duplicates_subset['VERIFICADO'] == True]

# %% [markdown]
# # 1. Puntajes

# %% [markdown]
# Asignamos puntajes a cada posible dato que aparezca en las categorías:
#
# - Tipo.
# - Subtipo.
# - Propietario
# - Verificación

# %%
duplicates_subset.loc[duplicates_subset['VERIFICADO'] == 1, 'PUNTAJE_VERIFICADO'] = 6
# Out:
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
duplicates_subset.loc[duplicates_subset['VERIFICADO'] == 0, 'PUNTAJE_VERIFICADO'] = 0
# Out:
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
duplicates_subset.loc[duplicates_subset['PROPIETARIO_DATO'] == 'Propio', 'PUNTAJE_PROPIETARIO'] = 5
# Out:
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)

# %%
duplicates_subset.loc[duplicates_subset['PROPIETARIO_DATO'] == 'Ajeno_familiar', 'PUNTAJE_PROPIETARIO'] = 4

# %%
duplicates_subset.loc[duplicates_subset['PROPIETARIO_DATO'] == 'Ajeno_empleador', 'PUNTAJE_PROPIETARIO'] = 3

# %%
duplicates_subset.loc[duplicates_subset['PROPIETARIO_DATO'] == 'Ajeno', 'PUNTAJE_PROPIETARIO'] = 2

# %%
duplicates_subset.loc[duplicates_subset['SUBTIPO'] == 'PERSONAL', 'PUNTAJE_TIPO'] = 2

# %%
duplicates_subset.loc[duplicates_subset['SUBTIPO'] == 'LABORAL', 'PUNTAJE_TIPO'] = 0

# %%
duplicates_subset.loc[duplicates_subset['TIPO'] == 'EMAIL', 'PUNTAJE_SUBTIPO'] = 4

# %%
duplicates_subset.loc[duplicates_subset['TIPO'] == 'TEL.FIJO', 'PUNTAJE_SUBTIPO'] = 2

# %%
duplicates_subset.loc[duplicates_subset['TIPO'] == 'TEL.CELULAR', 'PUNTAJE_SUBTIPO'] = 4

# %% [markdown]
# ## Suma de Puntajes

# %%
columns_to_sum = ['PUNTAJE_VERIFICADO','PUNTAJE_PROPIETARIO','PUNTAJE_TIPO','PUNTAJE_SUBTIPO']

# %%
duplicates_subset['PUNTAJE_TOTAL'] = duplicates_subset[columns_to_sum].sum(axis=1)
# Out:
# <ipython-input-28-0ec8c926888a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates_subset['PUNTAJE_TOTAL'] = duplicates_subset[columns_to_sum].sum(axis=1)

# %%
duplicates_subset.head()
# Out:
#               IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL      TIPO   SUBTIPO  \
# 0   DNI 35923953            DNI  35923953  20359239530  TEL.FIJO  PERSONAL
# 3   DNI 35923953            DNI  35923953  20359239530  TEL.FIJO  PERSONAL
# 5   DNI 27244548            DNI  27244548  20272445487  TEL.FIJO  PERSONAL
# 7   DNI 27244548            DNI  27244548  20272445487  TEL.FIJO  PERSONAL
# 24  DNI 38608367            DNI  38608367  27386083679  TEL.FIJO  PERSONAL
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0   2644231196           Propio             P2  2021-02-24 10:20:28.717029
# 3   2644231196   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
# 5   1147409350           Propio             P2  2021-02-24 10:20:28.717029
# 7   1147409350   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
# 24  2284431449           Propio             P2  2021-02-24 10:20:28.717029
#
#     VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO  \
# 0            0                 NaN                    NaN         2.0
# 3            0                 NaN                    NaN         2.0
# 5            0                 NaN                    NaN         2.0
# 7            0                 NaN                    NaN         2.0
# 24           0                 NaN                    NaN         2.0
#
#     PUNTAJE_VERIFICADO  PUNTAJE_PROPIETARIO  PUNTAJE_TIPO  PUNTAJE_SUBTIPO  \
# 0                  0.0                  5.0           2.0              2.0
# 3                  0.0                  4.0           2.0              2.0
# 5                  0.0                  5.0           2.0              2.0
# 7                  0.0                  4.0           2.0              2.0
# 24                 0.0                  5.0           2.0              2.0
#
#     PUNTAJE_TOTAL
# 0             9.0
# 3             8.0
# 5             9.0
# 7             8.0
# 24            9.0

# %%
duplicates_subset.shape
# Out:
# (540, 19)

# %%
df
# Out:
#                 IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO  \
# 0     DNI 35923953            DNI  35923953  20359239530     TEL.FIJO
# 1     DNI 35923953            DNI  35923953  20359239530     TEL.FIJO
# 2     DNI 35923953            DNI  35923953  20359239530     TEL.FIJO
# 3     DNI 35923953            DNI  35923953  20359239530     TEL.FIJO
# 4     DNI 35923953            DNI  35923953  20359239530  TEL.CELULAR
# ...                  ...      ...       ...          ...          ...
# 4178  DNI 30749617            DNI  30749617  20307496179     TEL.FIJO
# 4179  DNI 22244613            DNI  22244613  27222446134     TEL.FIJO
# 4180  DNI 2080464             DNI   2080464  27020804640     TEL.FIJO
# 4181  DNI 30529846            DNI  30529846  27305298463     TEL.FIJO
# 4182  DNI 30906890            DNI  30906890  23309068904     TEL.FIJO
#
#        SUBTIPO        DATO PROPIETARIO_DATO PROVEEDOR_DATO  \
# 0     PERSONAL  2644231196           Propio             P2
# 1      LABORAL  3546463805  Ajeno_empleador             P2
# 2      LABORAL  3546463806  Ajeno_empleador             P2
# 3     PERSONAL  2644231196   Ajeno_familiar             P2
# 4     PERSONAL  2646737373   Ajeno_familiar             P2
# ...        ...         ...              ...            ...
# 4178  PERSONAL  1144633936            Ajeno             P2
# 4179  PERSONAL  3414578578            Ajeno             P2
# 4180  PERSONAL  3424833473            Ajeno             P2
# 4181  PERSONAL  2920432065            Ajeno             P2
# 4182  PERSONAL  3814830545            Ajeno             P2
#
#               FECHA_INGRESO_DATO  VERIFICADO  FECHA_VERIFICACION  \
# 0     2021-02-24 10:20:28.717029           0                 NaN
# 1     2021-02-24 10:20:28.717029           0                 NaN
# 2     2021-02-24 10:20:28.717029           0                 NaN
# 3     2021-02-24 10:20:28.717029           0                 NaN
# 4     2021-02-24 10:20:28.717029           0                 NaN
# ...                          ...         ...                 ...
# 4178  2021-02-24 10:20:28.717029           0                 NaN
# 4179  2021-02-24 10:20:28.717029           0                 NaN
# 4180  2021-02-24 10:20:28.717029           0                 NaN
# 4181  2021-02-24 10:20:28.717029           0                 NaN
# 4182  2021-02-24 10:20:28.717029           0                 NaN
#
#       OPERADOR_VERIFICACION  SCORE_DATO
# 0                       NaN         2.0
# 1                       NaN         1.0
# 2                       NaN         1.0
# 3                       NaN         2.0
# 4                       NaN         2.0
# ...                     ...         ...
# 4178                    NaN         2.0
# 4179                    NaN         2.0
# 4180                    NaN         2.0
# 4181                    NaN         2.0
# 4182                    NaN         2.0
#
# [4183 rows x 14 columns]

# %% [markdown]
# ## Agrupo

# %%
#duplicates_subset['ID'] = duplicates_subset['ID'].astype(str)

# %%
df_best = duplicates_subset.groupby(['IDMOROSO','DATO','PROVEEDOR_DATO'], as_index = False).max(numeric_only=True)

# %%
df_best
# Out:
#                IDMOROSO        DATO PROVEEDOR_DATO   NRO_DOC    CUIT_CUIL  \
# 0    DNI 10248810        1149123530             P2  10248810  20102488106
# 1    DNI 10552120        2204930328             P2  10552120  27105521206
# 2    DNI 10704247        1149823082             P2  10704247  23107042474
# 3    DNI 11423863        2352416822             P2  11423863  27114238630
# 4    DNI 12025698        3794467530             P2  12025698  20120256980
# ..                  ...         ...            ...       ...          ...
# 254  LC  5162309         1145039363             P2   5162309  27051623091
# 255  LC  6066442         1143022569             P2   6066442  27060664426
# 256  LE  5094735         1142369923             P2   5094735  20050947352
# 257  LE  5460817         2284427657             P2   5460817  23054608179
# 258  LE  5793367         3514814615             P2   5793367  20057933675
#
#      VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO  \
# 0             0                 NaN                    NaN         2.0
# 1             0                 NaN                    NaN         2.0
# 2             0                 NaN                    NaN         2.0
# 3             0                 NaN                    NaN         2.0
# 4             0                 NaN                    NaN         2.0
# ..          ...                 ...                    ...         ...
# 254           0                 NaN                    NaN         2.0
# 255           0                 NaN                    NaN         2.0
# 256           0                 NaN                    NaN         2.0
# 257           0                 NaN                    NaN         2.0
# 258           0                 NaN                    NaN         2.0
#
#      PUNTAJE_VERIFICADO  PUNTAJE_PROPIETARIO  PUNTAJE_TIPO  PUNTAJE_SUBTIPO  \
# 0                   0.0                  5.0           2.0              2.0
# 1                   0.0                  5.0           2.0              2.0
# 2                   0.0                  5.0           2.0              2.0
# 3                   0.0                  5.0           2.0              4.0
# 4                   0.0                  5.0           2.0              2.0
# ..                  ...                  ...           ...              ...
# 254                 0.0                  5.0           2.0              2.0
# 255                 0.0                  5.0           2.0              2.0
# 256                 0.0                  5.0           2.0              2.0
# 257                 0.0                  5.0           2.0              2.0
# 258                 0.0                  5.0           2.0              2.0
#
#      PUNTAJE_TOTAL
# 0              9.0
# 1              9.0
# 2              9.0
# 3             11.0
# 4              9.0
# ..             ...
# 254            9.0
# 255            9.0
# 256            9.0
# 257            9.0
# 258            9.0
#
# [259 rows x 14 columns]

# %% [markdown]
# # Join

# %%
df_joined = pd.merge(duplicates_subset,df_best,on=['IDMOROSO','DATO','PROVEEDOR_DATO','PUNTAJE_TOTAL'])

# %%
df_joined.shape
# Out:
# (259, 29)

# %%
df_joined.head(10)
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC_x  CUIT_CUIL_x         TIPO   SUBTIPO  \
# 0  DNI 35923953            DNI   35923953  20359239530     TEL.FIJO  PERSONAL
# 1  DNI 27244548            DNI   27244548  20272445487     TEL.FIJO  PERSONAL
# 2  DNI 38608367            DNI   38608367  27386083679     TEL.FIJO  PERSONAL
# 3  DNIE92331200            DNI   92331200  20923312006     TEL.FIJO  PERSONAL
# 4  DNI 37161906            DNI   37161906  27371619068     TEL.FIJO  PERSONAL
# 5  DNI 20645228            DNI   20645228  20206452286     TEL.FIJO  PERSONAL
# 6  DNI 32702712            DNI   32702712  27327027129     TEL.FIJO  PERSONAL
# 7  DNI 32702712            DNI   32702712  27327027129  TEL.CELULAR  PERSONAL
# 8  DNI 25809095            DNI   25809095  20258090951     TEL.FIJO  PERSONAL
# 9  DNI 32067384            DNI   32067384  20320673845  TEL.CELULAR  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  2644231196           Propio             P2  2021-02-24 10:20:28.717029
# 1  1147409350           Propio             P2  2021-02-24 10:20:28.717029
# 2  2284431449           Propio             P2  2021-02-24 10:20:28.717029
# 3  1145233043           Propio             P2  2021-02-24 10:20:28.717029
# 4  1142963994           Propio             P2  2021-02-24 10:20:28.717029
# 5  3415184920           Propio             P2  2021-02-24 10:20:28.717029
# 6  1147610028           Propio             P2  2021-02-24 10:20:28.717029
# 7  1141778057           Propio             P2  2021-02-24 10:20:28.717029
# 8  1146903969           Propio             P2  2021-02-24 10:20:28.717029
# 9  2281544390           Propio             P2  2021-02-24 10:20:28.717029
#
#    ...  NRO_DOC_y  CUIT_CUIL_y  VERIFICADO_y  FECHA_VERIFICACION_y  \
# 0  ...   35923953  20359239530             0                   NaN
# 1  ...   27244548  20272445487             0                   NaN
# 2  ...   38608367  27386083679             0                   NaN
# 3  ...   92331200  20923312006             0                   NaN
# 4  ...   37161906  27371619068             0                   NaN
# 5  ...   20645228  20206452286             0                   NaN
# 6  ...   32702712  27327027129             0                   NaN
# 7  ...   32702712  27327027129             0                   NaN
# 8  ...   25809095  20258090951             0                   NaN
# 9  ...   32067384  20320673845             0                   NaN
#
#    OPERADOR_VERIFICACION_y  SCORE_DATO_y  PUNTAJE_VERIFICADO_y  \
# 0                      NaN           2.0                   0.0
# 1                      NaN           2.0                   0.0
# 2                      NaN           2.0                   0.0
# 3                      NaN           2.0                   0.0
# 4                      NaN           2.0                   0.0
# 5                      NaN           2.0                   0.0
# 6                      NaN           2.0                   0.0
# 7                      NaN           2.0                   0.0
# 8                      NaN           2.0                   0.0
# 9                      NaN           2.0                   0.0
#
#    PUNTAJE_PROPIETARIO_y  PUNTAJE_TIPO_y  PUNTAJE_SUBTIPO_y
# 0                    5.0             2.0                2.0
# 1                    5.0             2.0                2.0
# 2                    5.0             2.0                2.0
# 3                    5.0             2.0                2.0
# 4                    5.0             2.0                2.0
# 5                    5.0             2.0                2.0
# 6                    5.0             2.0                2.0
# 7                    5.0             2.0                4.0
# 8                    5.0             2.0                2.0
# 9                    5.0             2.0                4.0
#
# [10 rows x 29 columns]

# %% [markdown]
# # Duplicados con diferentes fechas de ingreso

# %%
duplicates_fecha = df_joined[df_joined.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
duplicates_fecha = duplicates_fecha.sort_values('FECHA_INGRESO_DATO').drop_duplicates('IDMOROSO',keep='first')

# %% [markdown]
# # Append

# %%
df_joined = df_joined[['IDMOROSO','TIPO_DOC','NRO_DOC_x','CUIT_CUIL_x','TIPO','SUBTIPO','DATO','PROPIETARIO_DATO'
                               ,'PROVEEDOR_DATO','FECHA_INGRESO_DATO','VERIFICADO_x','FECHA_VERIFICACION_x'
                               ,'OPERADOR_VERIFICACION_x','SCORE_DATO_x']]

# %%
df_joined.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC_x  CUIT_CUIL_x      TIPO   SUBTIPO  \
# 0  DNI 35923953            DNI   35923953  20359239530  TEL.FIJO  PERSONAL
# 1  DNI 27244548            DNI   27244548  20272445487  TEL.FIJO  PERSONAL
# 2  DNI 38608367            DNI   38608367  27386083679  TEL.FIJO  PERSONAL
# 3  DNIE92331200            DNI   92331200  20923312006  TEL.FIJO  PERSONAL
# 4  DNI 37161906            DNI   37161906  27371619068  TEL.FIJO  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 0  2644231196           Propio             P2  2021-02-24 10:20:28.717029
# 1  1147409350           Propio             P2  2021-02-24 10:20:28.717029
# 2  2284431449           Propio             P2  2021-02-24 10:20:28.717029
# 3  1145233043           Propio             P2  2021-02-24 10:20:28.717029
# 4  1142963994           Propio             P2  2021-02-24 10:20:28.717029
#
#    VERIFICADO_x  FECHA_VERIFICACION_x  OPERADOR_VERIFICACION_x  SCORE_DATO_x
# 0             0                   NaN                      NaN           2.0
# 1             0                   NaN                      NaN           2.0
# 2             0                   NaN                      NaN           2.0
# 3             0                   NaN                      NaN           2.0
# 4             0                   NaN                      NaN           2.0

# %%
df_joined.shape
# Out:
# (259, 14)

# %%
df_joined = df_joined.rename(columns={"VERIFICADO_x": "VERIFICADO", "SCORE_DATO_x": "SCORE_DATO"
                                     ,'NRO_DOC_x': 'NRO_DOC','CUIT_CUIL_x':'CUIT_CUIL'
                                     ,'FECHA_VERIFICACION_x':'FECHA_VERIFICACION'})

# %%
df_joined = df_joined[~df_joined.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
df_joined.shape
# Out:
# (259, 14)

# %%
duplicates_fecha = duplicates_fecha[['IDMOROSO','TIPO_DOC','NRO_DOC_x','CUIT_CUIL_x','TIPO','SUBTIPO','DATO','PROPIETARIO_DATO'
                               ,'PROVEEDOR_DATO','FECHA_INGRESO_DATO','VERIFICADO_x','FECHA_VERIFICACION_x'
                               ,'OPERADOR_VERIFICACION_x','SCORE_DATO_x']]

# %%
duplicates_fecha.shape
# Out:
# (0, 14)

# %%
duplicates_fecha = duplicates_fecha.rename(columns={"VERIFICADO_x": "VERIFICADO", "SCORE_DATO_x": "SCORE_DATO"})

# %% [markdown]
# Dataframe inicial sin los duplicados

# %%
df.shape
# Out:
# (4183, 14)

# %%
non_duplicates = df[~df.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
non_duplicates.shape
# Out:
# (3643, 14)

# %% [markdown]
# Unimos los 3 dataframes y revisamos que no haya duplicados en el mismo subset IDMOROSO-DATO-PROVEEDOR

# %%
non_duplicates = non_duplicates.dropna(subset=['DATO'])

# %%
non_duplicates [non_duplicates['NRO_DOC'].isnull()]
# Out:
# Empty DataFrame
# Columns: [IDMOROSO, TIPO_DOC, NRO_DOC, CUIT_CUIL, TIPO, SUBTIPO, DATO, PROPIETARIO_DATO, PROVEEDOR_DATO, FECHA_INGRESO_DATO, VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, SCORE_DATO]
# Index: []

# %%
non_duplicates.head()
# Out:
#              IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 1  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO   LABORAL
# 2  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO   LABORAL
# 4  DNI 35923953            DNI  35923953  20359239530  TEL.CELULAR  PERSONAL
# 6  DNI 27244548            DNI  27244548  20272445487  TEL.CELULAR  PERSONAL
# 8  DNI 35348234            DNI  35348234  27353482349     TEL.FIJO  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 1  3546463805  Ajeno_empleador             P2  2021-02-24 10:20:28.717029
# 2  3546463806  Ajeno_empleador             P2  2021-02-24 10:20:28.717029
# 4  2646737373   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
# 6  1168885576           Propio             P2  2021-02-24 10:20:28.717029
# 8  2224421607           Propio             P2  2021-02-24 10:20:28.717029
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 1           0                 NaN                    NaN         1.0
# 2           0                 NaN                    NaN         1.0
# 4           0                 NaN                    NaN         2.0
# 6           0                 NaN                    NaN         2.0
# 8           0                 NaN                    NaN         2.0

# %% [markdown]
# **SÓLO** concateno estos dos porque DUPLICATES_FECHA tiene nulls. Sino, hay que concatenar todos.

# %%
#df_export = pd.concat([non_duplicates,df_joined,duplicates_fecha])
df_export = pd.concat([non_duplicates,df_joined])

# %%
df_export.head()
# Out:
#              IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 1  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO   LABORAL
# 2  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO   LABORAL
# 4  DNI 35923953            DNI  35923953  20359239530  TEL.CELULAR  PERSONAL
# 6  DNI 27244548            DNI  27244548  20272445487  TEL.CELULAR  PERSONAL
# 8  DNI 35348234            DNI  35348234  27353482349     TEL.FIJO  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 1  3546463805  Ajeno_empleador             P2  2021-02-24 10:20:28.717029
# 2  3546463806  Ajeno_empleador             P2  2021-02-24 10:20:28.717029
# 4  2646737373   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
# 6  1168885576           Propio             P2  2021-02-24 10:20:28.717029
# 8  2224421607           Propio             P2  2021-02-24 10:20:28.717029
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO  \
# 1           0                 NaN                    NaN         1.0
# 2           0                 NaN                    NaN         1.0
# 4           0                 NaN                    NaN         2.0
# 6           0                 NaN                    NaN         2.0
# 8           0                 NaN                    NaN         2.0
#
#    OPERADOR_VERIFICACION_x
# 1                      NaN
# 2                      NaN
# 4                      NaN
# 6                      NaN
# 8                      NaN

# %%
df_export.shape
# Out:
# (3902, 15)

# %% [markdown]
# # QA Duplicados

# %%
qa_duplicados = df_export[df_export.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
qa_duplicados
# Out:
# Empty DataFrame
# Columns: [IDMOROSO, TIPO_DOC, NRO_DOC, CUIT_CUIL, TIPO, SUBTIPO, DATO, PROPIETARIO_DATO, PROVEEDOR_DATO, FECHA_INGRESO_DATO, VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, SCORE_DATO, OPERADOR_VERIFICACION_x]
# Index: []

# %%
df_export.head()
# Out:
#              IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 1  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO   LABORAL
# 2  DNI 35923953            DNI  35923953  20359239530     TEL.FIJO   LABORAL
# 4  DNI 35923953            DNI  35923953  20359239530  TEL.CELULAR  PERSONAL
# 6  DNI 27244548            DNI  27244548  20272445487  TEL.CELULAR  PERSONAL
# 8  DNI 35348234            DNI  35348234  27353482349     TEL.FIJO  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO          FECHA_INGRESO_DATO  \
# 1  3546463805  Ajeno_empleador             P2  2021-02-24 10:20:28.717029
# 2  3546463806  Ajeno_empleador             P2  2021-02-24 10:20:28.717029
# 4  2646737373   Ajeno_familiar             P2  2021-02-24 10:20:28.717029
# 6  1168885576           Propio             P2  2021-02-24 10:20:28.717029
# 8  2224421607           Propio             P2  2021-02-24 10:20:28.717029
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO  \
# 1           0                 NaN                    NaN         1.0
# 2           0                 NaN                    NaN         1.0
# 4           0                 NaN                    NaN         2.0
# 6           0                 NaN                    NaN         2.0
# 8           0                 NaN                    NaN         2.0
#
#    OPERADOR_VERIFICACION_x
# 1                      NaN
# 2                      NaN
# 4                      NaN
# 6                      NaN
# 8                      NaN

# %%
df_export['VERIFICADO'].value_counts()
# Out:
# 0    3902
# Name: VERIFICADO, dtype: int64

# %%
non_duplicates['VERIFICADO'].value_counts()
# Out:
# 0    3643
# Name: VERIFICADO, dtype: int64

# %%
df_joined['VERIFICADO'].value_counts()
# Out:
# 0    259
# Name: VERIFICADO, dtype: int64

# %%
duplicates_fecha['VERIFICADO'].value_counts()
# Out:
# Series([], Name: VERIFICADO, dtype: int64)

# %%
df_export[df_export['IDMOROSO'] == 'LE  4003299       ']
# Out:
# Empty DataFrame
# Columns: [IDMOROSO, TIPO_DOC, NRO_DOC, CUIT_CUIL, TIPO, SUBTIPO, DATO, PROPIETARIO_DATO, PROVEEDOR_DATO, FECHA_INGRESO_DATO, VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, SCORE_DATO, OPERADOR_VERIFICACION_x]
# Index: []

# %%
df[df['IDMOROSO'] == 'LE  4003299       ']
# Out:
# Empty DataFrame
# Columns: [IDMOROSO, TIPO_DOC, NRO_DOC, CUIT_CUIL, TIPO, SUBTIPO, DATO, PROPIETARIO_DATO, PROVEEDOR_DATO, FECHA_INGRESO_DATO, VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, SCORE_DATO]
# Index: []

# %% [markdown]
# # Export a DAM_CONTACTABILIDAD

# %%
df_export = df_export[['IDMOROSO', 'TIPO_DOC','NRO_DOC','CUIT_CUIL','TIPO','SUBTIPO','DATO','PROPIETARIO_DATO','PROVEEDOR_DATO','FECHA_INGRESO_DATO','VERIFICADO','FECHA_VERIFICACION','OPERADOR_VERIFICACION','SCORE_DATO']]

# %%
df_export.to_csv('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/PyP/Exports/DAM_CONTACTABILIDAD/DAM_CONTACTABILIDAD_TELEFONOS_2402.csv',index=False)
