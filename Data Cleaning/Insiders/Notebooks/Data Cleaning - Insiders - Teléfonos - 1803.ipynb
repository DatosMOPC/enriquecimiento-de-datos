# %% [markdown]
# # 1) Datasets

# %% [markdown]
# Vamos a leer el dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/mnt/c/users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Insiders/Datasets/Datasets recibidos/ENRIQ_IN_1672_20210317.xlsx',skiprows=2, header=[0,1])

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                 Cuil                Dni      Fecha de Nac. Fecha de Defuncion
# 0       2.700187e+10           187386.0         1929-04-02                NaN
# 1       2.700508e+10           507550.0         1939-03-05                NaN
# 2       2.704172e+10          4171534.0         1940-06-02         2020-12-15
# 3       2.004174e+10          4173550.0         1936-01-28                NaN
# 4       2.004200e+10          4200228.0         1936-12-08                NaN
#
#   Unnamed: 4_level_0           Unnamed: 5_level_0       Unnamed: 6_level_0  \
#                 Sexo                      Titular                    Calle
# 0                  F             HERRERA ENA ELSA         REP DE VENEZUELA
# 1                  F         ENTRATICO IRMA CLARA               AV URUGUAY
# 2                  F  ITUARTE MARGARITA HORTENSIA             PJE GRANDOLI
# 3                  M        VISCONTI EDUARDO JUAN       JUAN JOSE VIAMONTE
# 4                  M       CACCHIONE MIGUEL ANGEL  BRUNO MARIANO DE ZABALA
#
#   Unnamed: 7_level_0 Unnamed: 8_level_0 Unnamed: 9_level_0  ...  \
#               Numero       Piso y Depto      Codigo Postal  ...
# 0               3700                NaN             1211.0  ...
# 1                875                NaN             4400.0  ...
# 2               6100                NaN             1439.0  ...
# 3               1592                NaN             1055.0  ...
# 4               1706                NaN             1426.0  ...
#
#   Contactacion Opcional (Familiar)                                          \
#                         Tel Fijo 2 Celular 1 Celular 2 Celular 3 Celular 4
# 0                              NaN       NaN       NaN       NaN       NaN
# 1                              NaN       NaN       NaN       NaN       NaN
# 2                              NaN       NaN       NaN       NaN       NaN
# 3                              NaN       NaN       NaN       NaN       NaN
# 4                              NaN       NaN       NaN       NaN       NaN
#
#                   Contactacion Opcional (Vecino)
#   Celular 5 Email                         Nombre      Telefono  SCORE
# 0       NaN   NaN                            NaN           NaN    0.0
# 1       NaN   NaN          PATRON COSTAS GUSTAVO  3.874321e+09   34.0
# 2       NaN   NaN                            NaN           NaN  891.0
# 3       NaN   NaN                            NaN           NaN  958.0
# 4       NaN   NaN                            NaN           NaN  345.0
#
# [5 rows x 226 columns]

# %%
df.shape
# Out:
# (14872, 226)

# %% [markdown]
# ## 1.2) Data Cleaning: Datasets

# %% [markdown]
# Vamos a dropear aquellas columnas y filas que no tengan ningún valor (es decir, que sean todos NaNs)

# %%
df = df.dropna(axis=0, how='all')

# %%
#df = df.dropna(axis=1, how='all')

# %%
df.shape
# Out:
# (664, 226)

# %% [markdown]
# Ahora todas las filas tienen al menos 1 dato.

# %% [markdown]
# # 2) Teléfonos

# %% [markdown]
# Vamos a obtener los teléfonos de las columnas donde pueden aparecer, que son:
#
# - Teléfono Fijo 1, 2 y 3.
# - Teléfono Movil 1, 2, 3, 4, 5, 6 y 7.
# - Teléfono Laboral 1, 2 y 3.
# - Contactación Opcional (Familiar): Tel Fijo 1, Tel Fijo 2, Celular 1, Celular 2, Celular 3, Celular 4, Celular 5.
# - Contactación Opcional (Vecino): Telefono.

# %%
#df.to_excel('columns.xlsx')

# %%
df_reduced = df [[('Unnamed: 0_level_0','Cuil'),('Unnamed: 1_level_0','Dni'), ('Unnamed: 5_level_0','Titular')
                  ,('Unnamed: 15_level_0','Telefono Fijo 1'),('Unnamed: 16_level_0','Telefono Fijo 2') 
                  ,('Unnamed: 17_level_0','Telefono Movil 1')
                  ,('Unnamed: 18_level_0','Telefono Movil 2'),('Unnamed: 19_level_0','Telefono Movil 3')
                  ,('Unnamed: 20_level_0','Telefono Movil 4'),('Unnamed: 21_level_0','Telefono Movil 5')
                  ,('Telefono Laboral 1', 'Unnamed: 160_level_1') ,('Telefono Laboral 2', 'Unnamed: 161_level_1')
                  ,('Telefono Laboral 3', 'Unnamed: 162_level_1')
                  ,('Contactacion Opcional (Familiar)','Tel Fijo 1'),('Contactacion Opcional (Familiar)','Tel Fijo 2')
                  ,('Contactacion Opcional (Familiar)','Celular 1'),('Contactacion Opcional (Familiar)','Celular 2')
                  ,('Contactacion Opcional (Familiar)','Celular 3'),('Contactacion Opcional (Familiar)','Celular 4')
                  ,('Contactacion Opcional (Familiar)','Celular 5')
                  ,('Contactacion Opcional (Vecino)','Telefono')
                  ]]

# %%
df_reduced.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0           Unnamed: 5_level_0  \
#                 Cuil                Dni                      Titular
# 0       2.700187e+10           187386.0             HERRERA ENA ELSA
# 1       2.700508e+10           507550.0         ENTRATICO IRMA CLARA
# 2       2.704172e+10          4171534.0  ITUARTE MARGARITA HORTENSIA
# 3       2.004174e+10          4173550.0        VISCONTI EDUARDO JUAN
# 4       2.004200e+10          4200228.0       CACCHIONE MIGUEL ANGEL
#
#   Unnamed: 15_level_0 Unnamed: 16_level_0 Unnamed: 17_level_0  \
#       Telefono Fijo 1     Telefono Fijo 2    Telefono Movil 1
# 0        1.149578e+09                 NaN        1.131591e+09
# 1        3.874312e+09                 NaN                 NaN
# 2        1.142090e+09        1.146872e+09        1.161079e+09
# 3        1.143729e+09                 NaN        1.136028e+09
# 4        1.147731e+09                 NaN                 NaN
#
#   Unnamed: 18_level_0 Unnamed: 19_level_0 Unnamed: 20_level_0  \
#      Telefono Movil 2    Telefono Movil 3    Telefono Movil 4
# 0        1.163578e+09                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3        1.162520e+09                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#   Unnamed: 21_level_0  ...   Telefono Laboral 2   Telefono Laboral 3  \
#      Telefono Movil 5  ... Unnamed: 161_level_1 Unnamed: 162_level_1
# 0                 NaN  ...                  NaN                  NaN
# 1                 NaN  ...                  NaN                  NaN
# 2                 NaN  ...                  NaN                  NaN
# 3                 NaN  ...                  NaN                  NaN
# 4                 NaN  ...                  NaN                  NaN
#
#   Contactacion Opcional (Familiar)                                           \
#                         Tel Fijo 1 Tel Fijo 2 Celular 1 Celular 2 Celular 3
# 0                              NaN        NaN       NaN       NaN       NaN
# 1                              NaN        NaN       NaN       NaN       NaN
# 2                              NaN        NaN       NaN       NaN       NaN
# 3                              NaN        NaN       NaN       NaN       NaN
# 4                              NaN        NaN       NaN       NaN       NaN
#
#                       Contactacion Opcional (Vecino)
#   Celular 4 Celular 5                       Telefono
# 0       NaN       NaN                            NaN
# 1       NaN       NaN                   3.874321e+09
# 2       NaN       NaN                            NaN
# 3       NaN       NaN                            NaN
# 4       NaN       NaN                            NaN
#
# [5 rows x 21 columns]

# %%
df_reduced.shape
# Out:
# (664, 21)

# %% [markdown]
# Eliminamos el multilevel de las columnas, y las renombramos:

# %%
df_reduced.columns = df_reduced.columns.droplevel()

# %%
df_reduced.head()
# Out:
#            Cuil        Dni                      Titular  Telefono Fijo 1  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA     1.149578e+09
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA     3.874312e+09
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA     1.142090e+09
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN     1.143729e+09
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL     1.147731e+09
#
#    Telefono Fijo 2  Telefono Movil 1  Telefono Movil 2  Telefono Movil 3  \
# 0              NaN      1.131591e+09      1.163578e+09               NaN
# 1              NaN               NaN               NaN               NaN
# 2     1.146872e+09      1.161079e+09               NaN               NaN
# 3              NaN      1.136028e+09      1.162520e+09               NaN
# 4              NaN               NaN               NaN               NaN
#
#    Telefono Movil 4  Telefono Movil 5  ...  Unnamed: 161_level_1  \
# 0               NaN               NaN  ...                   NaN
# 1               NaN               NaN  ...                   NaN
# 2               NaN               NaN  ...                   NaN
# 3               NaN               NaN  ...                   NaN
# 4               NaN               NaN  ...                   NaN
#
#    Unnamed: 162_level_1  Tel Fijo 1  Tel Fijo 2  Celular 1  Celular 2  \
# 0                   NaN         NaN         NaN        NaN        NaN
# 1                   NaN         NaN         NaN        NaN        NaN
# 2                   NaN         NaN         NaN        NaN        NaN
# 3                   NaN         NaN         NaN        NaN        NaN
# 4                   NaN         NaN         NaN        NaN        NaN
#
#    Celular 3  Celular 4  Celular 5      Telefono
# 0        NaN        NaN        NaN           NaN
# 1        NaN        NaN        NaN  3.874321e+09
# 2        NaN        NaN        NaN           NaN
# 3        NaN        NaN        NaN           NaN
# 4        NaN        NaN        NaN           NaN
#
# [5 rows x 21 columns]

# %%
df_reduced = df_reduced.rename(columns={"Cuil": "CUIT_CUIL", 'Dni': 'NRO_DOC','Unnamed: 160_level_1':'Telefono Laboral 1'
                                        ,'Unnamed: 161_level_1':'Telefono Laboral 2','Unnamed: 162_level_1':'Telefono Laboral 3'
                                       ,'Telefono':'Telefono_vecino'
                                       , 'Tel Fijo 1': 'Tel_familiar_fijo_1', 'Tel Fijo 2': 'Tel_familiar_fijo_2'
                                       , 'Celular 1': 'celular_familiar_1', 'Celular 2': 'celular_familiar_2'
                                       , 'Celular 3': 'celular_familiar_3', 'Celular 4': 'celular_familiar_4'
                                       , 'Celular 5': 'celular_familiar_5'})

# %%
df_reduced.head()
# Out:
#       CUIT_CUIL    NRO_DOC                      Titular  Telefono Fijo 1  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA     1.149578e+09
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA     3.874312e+09
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA     1.142090e+09
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN     1.143729e+09
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL     1.147731e+09
#
#    Telefono Fijo 2  Telefono Movil 1  Telefono Movil 2  Telefono Movil 3  \
# 0              NaN      1.131591e+09      1.163578e+09               NaN
# 1              NaN               NaN               NaN               NaN
# 2     1.146872e+09      1.161079e+09               NaN               NaN
# 3              NaN      1.136028e+09      1.162520e+09               NaN
# 4              NaN               NaN               NaN               NaN
#
#    Telefono Movil 4  Telefono Movil 5  ...  Telefono Laboral 2  \
# 0               NaN               NaN  ...                 NaN
# 1               NaN               NaN  ...                 NaN
# 2               NaN               NaN  ...                 NaN
# 3               NaN               NaN  ...                 NaN
# 4               NaN               NaN  ...                 NaN
#
#    Telefono Laboral 3  Tel_familiar_fijo_1  Tel_familiar_fijo_2  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    celular_familiar_1  celular_familiar_2  celular_familiar_3  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    celular_familiar_4  celular_familiar_5  Telefono_vecino
# 0                 NaN                 NaN              NaN
# 1                 NaN                 NaN     3.874321e+09
# 2                 NaN                 NaN              NaN
# 3                 NaN                 NaN              NaN
# 4                 NaN                 NaN              NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # 3) Concatenación de Teléfonos

# %% [markdown]
# Como PyP envía un teléfono por celda, tengo que concatenar las columnas de teléfonos en una lista dentro de una nueva columna denominada "Dato"

# %%
df_reduced.columns
# Out:
# Index(['CUIT_CUIL', 'NRO_DOC', 'Titular', 'Telefono Fijo 1', 'Telefono Fijo 2',
#        'Telefono Movil 1', 'Telefono Movil 2', 'Telefono Movil 3',
#        'Telefono Movil 4', 'Telefono Movil 5', 'Telefono Laboral 1',
#        'Telefono Laboral 2', 'Telefono Laboral 3', 'Tel_familiar_fijo_1',
#        'Tel_familiar_fijo_2', 'celular_familiar_1', 'celular_familiar_2',
#        'celular_familiar_3', 'celular_familiar_4', 'celular_familiar_5',
#        'Telefono_vecino'],
#       dtype='object')

# %%
df_melt = pd.melt(df_reduced, id_vars=['CUIT_CUIL', 'NRO_DOC', 'Titular']
                  , value_vars=['Telefono Fijo 1', 'Telefono Fijo 2',
                               'Telefono Movil 1', 'Telefono Movil 2',
                               'Telefono Movil 3', 'Telefono Movil 4', 'Telefono Movil 5',
                                'Telefono Laboral 1',
                               'Telefono Laboral 2', 'Telefono Laboral 3', 'Tel_familiar_fijo_1',
                               'Tel_familiar_fijo_2', 'celular_familiar_1', 'celular_familiar_2',
                               'celular_familiar_3', 'celular_familiar_4', 'celular_familiar_5',
                               'Telefono_vecino'],value_name='Dato')

# %%
df_melt.head()
# Out:
#       CUIT_CUIL    NRO_DOC                      Titular         variable  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA  Telefono Fijo 1
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA  Telefono Fijo 1
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA  Telefono Fijo 1
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN  Telefono Fijo 1
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL  Telefono Fijo 1
#
#            Dato
# 0  1.149578e+09
# 1  3.874312e+09
# 2  1.142090e+09
# 3  1.143729e+09
# 4  1.147731e+09

# %%
#df_melt.to_excel('df_melt_telefonos.xlsx')

# %% [markdown]
# # 4) Drop NaNs

# %% [markdown]
# Dropeamos aquellas filas que tengan NaN en la columna Dato, ya que no nos aporta nada:

# %%
df_melt = df_melt.dropna(subset=['Dato'])

# %%
df_melt.shape
# Out:
# (1921, 5)

# %%
df_melt.head()
# Out:
#       CUIT_CUIL    NRO_DOC                      Titular         variable  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA  Telefono Fijo 1
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA  Telefono Fijo 1
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA  Telefono Fijo 1
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN  Telefono Fijo 1
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL  Telefono Fijo 1
#
#            Dato
# 0  1.149578e+09
# 1  3.874312e+09
# 2  1.142090e+09
# 3  1.143729e+09
# 4  1.147731e+09

# %% [markdown]
# # 5) Propietario del Dato

# %% [markdown]
# En función de la columna "variable" creamos una nueva columna PROPIETARIO_DATO

# %%
df_melt.loc[((df_melt['variable'] == 'Telefono Fijo 1') | (df_melt['variable'] == 'Telefono Fijo 2')
            | (df_melt['variable'] == 'Telefono Movil 1')
            | (df_melt['variable'] == 'Telefono Movil 2') | (df_melt['variable'] == 'Telefono Movil 3')
            | (df_melt['variable'] == 'Telefono Movil 4') | (df_melt['variable'] == 'Telefono Movil 5')
            ) , 'PROPIETARIO_DATO'] = 'Propio'

# %%
df_melt.loc[((df_melt['variable'] == 'Tel_familiar_fijo_1')
            | (df_melt['variable'] == 'Tel_familiar_fijo_2') | (df_melt['variable'] == 'celular_familiar_1')
            | (df_melt['variable'] == 'celular_familiar_2') | (df_melt['variable'] == 'celular_familiar_3')
            | (df_melt['variable'] == 'celular_familiar_4') | (df_melt['variable'] == 'celular_familiar_5')
            ) , 'PROPIETARIO_DATO'] = 'Ajeno_familiar'

# %%
df_melt.loc[((df_melt['variable'] == 'Telefono_vecino') 
            ) , 'PROPIETARIO_DATO'] = 'Ajeno'

# %%
df_melt.loc[((df_melt['variable'] == 'Telefono Laboral 1') | (df_melt['variable'] == 'Telefono Laboral 2')
            | (df_melt['variable'] == 'Telefono Laboral 3')
            ) , 'PROPIETARIO_DATO'] = 'Ajeno_empleador'

# %%
#df_melt.to_excel('test_tel_v2.xlsx')

# %%
df_melt.head()
# Out:
#       CUIT_CUIL    NRO_DOC                      Titular         variable  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA  Telefono Fijo 1
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA  Telefono Fijo 1
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA  Telefono Fijo 1
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN  Telefono Fijo 1
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL  Telefono Fijo 1
#
#            Dato PROPIETARIO_DATO
# 0  1.149578e+09           Propio
# 1  3.874312e+09           Propio
# 2  1.142090e+09           Propio
# 3  1.143729e+09           Propio
# 4  1.147731e+09           Propio

# %% [markdown]
# # 6) Columna Proveedor

# %% [markdown]
# Agregamos la columna PROVEEDOR_DATO, con el código correspondiente.

# %%
cod_pyp = 'AD'

# %%
df_clean = df_melt.assign(PROVEEDOR_DATO=cod_pyp)

# %%
df_clean.tail()
# Out:
#           CUIT_CUIL     NRO_DOC                         Titular  \
# 11921  2.794300e+10  94300255.0             OVANDO MARIA ELIANA
# 11923  2.794672e+10  94671953.0          SERVIN LEZCANO ARCENIA
# 11930  2.095097e+10  95097265.0  SANSUSTE CUELLAR MARCO ANTONIO
# 11931  2.095142e+10  95141691.0           MARECO BENITEZ OVIDIO
# 11936  2.095366e+10  95366021.0   GIMENEZ ALLENDE RICHAR DANIEL
#
#               variable          Dato PROPIETARIO_DATO PROVEEDOR_DATO
# 11921  Telefono_vecino  1.145562e+09            Ajeno             AD
# 11923  Telefono_vecino  2.974999e+09            Ajeno             AD
# 11930  Telefono_vecino  1.146192e+09            Ajeno             AD
# 11931  Telefono_vecino  1.144559e+09            Ajeno             AD
# 11936  Telefono_vecino  2.320627e+09            Ajeno             AD

# %% [markdown]
# # 7) Columna Tipo

# %% [markdown]
# Agregamos la columna TIPO, con el código correspondiente

# %%
df_clean.loc[((df_clean['variable'] == 'Telefono Fijo 1') | (df_clean['variable'] == 'Telefono Fijo 2')
            | (df_clean['variable'] == 'Telefono Laboral 1') | (df_clean['variable'] == 'Telefono Laboral 2')
            | (df_clean['variable'] == 'Telefono Laboral 3') | (df_clean['variable'] == 'Tel_familiar_fijo_1')
            | (df_clean['variable'] == 'Tel_familiar_fijo_2') 
            | (df_clean['variable'] == 'Telefono_vecino')
            ) , 'TIPO'] = 'TEL.FIJO'

# %%
df_clean.loc[((df_clean['variable'] == 'Telefono Movil 1') | (df_clean['variable'] == 'Telefono Movil 2') 
            | (df_clean['variable'] == 'Telefono Movil 3') | (df_clean['variable'] == 'Telefono Movil 4') 
            | (df_clean['variable'] == 'Telefono Movil 5') 
            | (df_clean['variable'] == 'celular_familiar_1')
            | (df_clean['variable'] == 'celular_familiar_2') | (df_clean['variable'] == 'celular_familiar_3')
            | (df_clean['variable'] == 'celular_familiar_4') | (df_clean['variable'] == 'celular_familiar_5')  
            ) , 'TIPO'] = 'TEL.CELULAR'

# %%
df_clean.head()
# Out:
#       CUIT_CUIL    NRO_DOC                      Titular         variable  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA  Telefono Fijo 1
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA  Telefono Fijo 1
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA  Telefono Fijo 1
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN  Telefono Fijo 1
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL  Telefono Fijo 1
#
#            Dato PROPIETARIO_DATO PROVEEDOR_DATO      TIPO
# 0  1.149578e+09           Propio             AD  TEL.FIJO
# 1  3.874312e+09           Propio             AD  TEL.FIJO
# 2  1.142090e+09           Propio             AD  TEL.FIJO
# 3  1.143729e+09           Propio             AD  TEL.FIJO
# 4  1.147731e+09           Propio             AD  TEL.FIJO

# %% [markdown]
# # 8) Columna Subtipo

# %% [markdown]
# Agregamos la columna SUBTIPO, que va a contener información sobre el tipo de teléfono que se encuentra en el campo Dato.
#
# - Personal: si es propio.
# - Laboral: si es ajeno.

# %%
df_clean.loc[((df_clean['variable'] == 'Telefono Laboral 1') | (df_clean['variable'] == 'Telefono Laboral 2')
            | (df_clean['variable'] == 'Telefono Laboral 3')
            ) , 'SUBTIPO'] = 'LABORAL'

# %%
df_clean.loc[((df_clean['variable'] == 'Telefono Movil 1') | (df_clean['variable'] == 'Telefono Movil 2') 
            | (df_clean['variable'] == 'Telefono Movil 3') | (df_clean['variable'] == 'Telefono Movil 4') 
            | (df_clean['variable'] == 'Telefono Movil 5')
            | (df_clean['variable'] == 'celular_familiar_1')
            | (df_clean['variable'] == 'celular_familiar_2') | (df_clean['variable'] == 'celular_familiar_3')
            | (df_clean['variable'] == 'celular_familiar_4') | (df_clean['variable'] == 'celular_familiar_5')
            | (df_clean['variable'] == 'Telefono Fijo 1') | (df_clean['variable'] == 'Telefono Fijo 2')
            | (df_clean['variable'] == 'Tel_familiar_fijo_1')
            | (df_clean['variable'] == 'Tel_familiar_fijo_2') 
            | (df_clean['variable'] == 'Telefono_vecino')               
            ) , 'SUBTIPO'] = 'PERSONAL'

# %%
#df_clean.to_excel('df_refuerzo_test_1.xlsx')

# %%
df_clean = df_clean.drop(columns=['variable'])

# %%
df_clean.head()
# Out:
#       CUIT_CUIL    NRO_DOC                      Titular          Dato  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA  1.149578e+09
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA  3.874312e+09
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA  1.142090e+09
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN  1.143729e+09
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL  1.147731e+09
#
#   PROPIETARIO_DATO PROVEEDOR_DATO      TIPO   SUBTIPO
# 0           Propio             AD  TEL.FIJO  PERSONAL
# 1           Propio             AD  TEL.FIJO  PERSONAL
# 2           Propio             AD  TEL.FIJO  PERSONAL
# 3           Propio             AD  TEL.FIJO  PERSONAL
# 4           Propio             AD  TEL.FIJO  PERSONAL

# %% [markdown]
# # 9) Columna Score

# %% [markdown]
# El campo **Score** se construye en función de los datos obtenidos:
#
# - Nivel 4: Dato que otorga la propia persona.
# - Nivel 3: Dato que otorgan los clientes (los bancos).
# - Nivel 2: Dato que otorga un proveedor externo (Informes Digitales en este caso), con subtipo "Personal".
# - Nivel 1: Dato que otorga un proveedor externo, pero tiene como subtipo "Laboral".

# %%
# Nivel 1: Laboral, proveedor externo.

df_clean.loc[(df_clean['SUBTIPO'] == 'LABORAL') , 'SCORE_DATO'] = 1

# %%
# Nivel 2: Personal, proveedor externo.

df_clean.loc[(df_clean['SUBTIPO'] == 'PERSONAL') , 'SCORE_DATO'] = 2

# %%
df_clean.head()
# Out:
#       CUIT_CUIL    NRO_DOC                      Titular          Dato  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA  1.149578e+09
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA  3.874312e+09
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA  1.142090e+09
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN  1.143729e+09
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL  1.147731e+09
#
#   PROPIETARIO_DATO PROVEEDOR_DATO      TIPO   SUBTIPO  SCORE_DATO
# 0           Propio             AD  TEL.FIJO  PERSONAL         2.0
# 1           Propio             AD  TEL.FIJO  PERSONAL         2.0
# 2           Propio             AD  TEL.FIJO  PERSONAL         2.0
# 3           Propio             AD  TEL.FIJO  PERSONAL         2.0
# 4           Propio             AD  TEL.FIJO  PERSONAL         2.0

# %% [markdown]
# # 10) Columna Fecha

# %% [markdown]
# Para el campo FECHA_INGRESO_DATO, usamos la fecha en la que se hace la inserción de los datos:

# %%
fecha_ingreso = pd.to_datetime('today')

# %%
df_clean = df_clean.assign(FECHA_INGRESO_DATO=fecha_ingreso)

# %%
df_clean.head()
# Out:
#       CUIT_CUIL    NRO_DOC                      Titular          Dato  \
# 0  2.700187e+10   187386.0             HERRERA ENA ELSA  1.149578e+09
# 1  2.700508e+10   507550.0         ENTRATICO IRMA CLARA  3.874312e+09
# 2  2.704172e+10  4171534.0  ITUARTE MARGARITA HORTENSIA  1.142090e+09
# 3  2.004174e+10  4173550.0        VISCONTI EDUARDO JUAN  1.143729e+09
# 4  2.004200e+10  4200228.0       CACCHIONE MIGUEL ANGEL  1.147731e+09
#
#   PROPIETARIO_DATO PROVEEDOR_DATO      TIPO   SUBTIPO  SCORE_DATO  \
# 0           Propio             AD  TEL.FIJO  PERSONAL         2.0
# 1           Propio             AD  TEL.FIJO  PERSONAL         2.0
# 2           Propio             AD  TEL.FIJO  PERSONAL         2.0
# 3           Propio             AD  TEL.FIJO  PERSONAL         2.0
# 4           Propio             AD  TEL.FIJO  PERSONAL         2.0
#
#           FECHA_INGRESO_DATO
# 0 2021-03-18 13:13:26.505652
# 1 2021-03-18 13:13:26.505652
# 2 2021-03-18 13:13:26.505652
# 3 2021-03-18 13:13:26.505652
# 4 2021-03-18 13:13:26.505652

# %% [markdown]
# # 11) Campos adicionales

# %% [markdown]
# Creamos las columnas VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, que en principio van en nulls.

# %%
df_clean['VERIFICADO'] = 0

# %%
df_clean['FECHA_VERIFICACION'] = np.nan

# %%
df_clean['OPERADOR_VERIFICACION'] = np.nan

# %% [markdown]
# # 12) Concatenación con .csv enviado

# %% [markdown]
# Vamos a concatenar nuestro dataframe con el dataframe enviado para enriquecer. Para esto, vamos a hacer una limpieza inicial de cómo se enviaron esos datos. Finalmente, se uniran ambos dataframes por __DNI__.

# %% [markdown]
# ## 12.1) Dataset

# %% [markdown]
# Vamos a analizar y limpiar el dataset enviado para el enriquecimiento:

# %%
df_pyp = pd.read_csv('/mnt/c/users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Insiders/Datasets/Datasets enviados/Envio Insiders - Estado-IDCliente - 1603.csv')

# %%
df_pyp.shape
# Out:
# (696, 6)

# %% [markdown]
# Creamos una columna que contenga IDMOROSO + DATOADIC según corresponda

# %%
df_pyp.head()
# Out:
#              IDMOROSO                                    NOMBRE  \
# 0  DNI 14384837        ACOSTA MARIA CRISTINA
# 1  DNI 33803357        CARRASCO SERGIO DAMIAN
# 2  DNI 34570749        TOLDI PRESENTADO SOLANGE GISELLE
# 3  DNI 36991995        ANTECAO MAURO LEANDRO
# 4  DNI 40359046        VATTOVAZ VICTORIA
#
#               IDCLIENTE                ESTADO               FILTROA DATOADIC
# 0  FRANCES_2012          NO VISTO              3 - Ag 3ra                NaN
# 1  FRANCES_2012          NO VISTO              1 - Ag 1ra                NaN
# 2  FRANCES_2012          NO VISTO              1 - Ag 1ra                NaN
# 3  FRANCES_2012          NO VISTO              2 - Ag 2ra                NaN
# 4  FRANCES_2012          NO VISTO              1 - Ag 1ra                NaN

# %%
df_pyp.loc[(df_pyp['IDCLIENTE'].str.startswith('AMEX')) , 'NRO_DOC'] = df_pyp['DATOADIC']
df_pyp.loc[(~df_pyp['IDCLIENTE'].str.startswith('AMEX')) , 'NRO_DOC'] = df_pyp['IDMOROSO']
#df_pyp ['NRO_DOC'] = df_pyp ['IDMOROSO']

# %%
df_pyp.head()
# Out:
#              IDMOROSO                                    NOMBRE  \
# 0  DNI 14384837        ACOSTA MARIA CRISTINA
# 1  DNI 33803357        CARRASCO SERGIO DAMIAN
# 2  DNI 34570749        TOLDI PRESENTADO SOLANGE GISELLE
# 3  DNI 36991995        ANTECAO MAURO LEANDRO
# 4  DNI 40359046        VATTOVAZ VICTORIA
#
#               IDCLIENTE                ESTADO               FILTROA DATOADIC  \
# 0  FRANCES_2012          NO VISTO              3 - Ag 3ra                NaN
# 1  FRANCES_2012          NO VISTO              1 - Ag 1ra                NaN
# 2  FRANCES_2012          NO VISTO              1 - Ag 1ra                NaN
# 3  FRANCES_2012          NO VISTO              2 - Ag 2ra                NaN
# 4  FRANCES_2012          NO VISTO              1 - Ag 1ra                NaN
#
#               NRO_DOC
# 0  DNI 14384837
# 1  DNI 33803357
# 2  DNI 34570749
# 3  DNI 36991995
# 4  DNI 40359046

# %%
#df_pyp = df_pyp [['IDMOROSO','NOMBRE','IDCLIENTE','NRO_DOC']]
df_pyp = df_pyp [['IDMOROSO','IDCLIENTE','NRO_DOC']]

# %%
df_pyp.head()
# Out:
#              IDMOROSO             IDCLIENTE             NRO_DOC
# 0  DNI 14384837        FRANCES_2012          DNI 14384837
# 1  DNI 33803357        FRANCES_2012          DNI 33803357
# 2  DNI 34570749        FRANCES_2012          DNI 34570749
# 3  DNI 36991995        FRANCES_2012          DNI 36991995
# 4  DNI 40359046        FRANCES_2012          DNI 40359046

# %%
df_pyp = df_pyp.dropna(subset=['NRO_DOC'])

# %%
df_pyp.tail()
# Out:
#                IDMOROSO             IDCLIENTE             NRO_DOC
# 691  DNI 24191912        FRAVEGA_LEGALES548    DNI 24191912
# 692  DNI 26763078        FRAVEGA_LEGALES548    DNI 26763078
# 693  DNI 14129384        FRAVEGA_LEGALES548    DNI 14129384
# 694  DNI 16490348        FRAVEGA_LEGALES548    DNI 16490348
# 695  DNI 21385894        FRAVEGA_LEGALES548    DNI 21385894

# %% [markdown]
# ## 12.2) DNI Cleaning

# %% [markdown]
# Limpiamos el dataframe __df_pyp__, ya que dentro de DATO_A_ENVIAR tenemos 9 tipos de casos diferentes de datos:
#
# - DNI 12345678
# - DNI12345678
# - DNIE1234678
# - LC  1234567
# - LE  1234567
# - CUIT00123456780
# - 00123456780 --> Es un CUIT.
# - 00 12345678 0 --> Es un CUIT.
# - DNI 00123456780 --> Dice DNI pero es un CUIT de una persona __jurídica__ (TO DO)

# %% [markdown]
# Para eso definimos 5 funciones:
#
# - __Tipo_DOC__: Se definen dos funciones para determinar el tipo de DNI. Una inicial, y otra para corregir sobre el dataframe resultante.
# - __Standard DNI__: Estandariza los DNI para 7 de los casos. Esta función debe ejecutarse en primer lugar.
# - __DNI Spaces__: Elimina los espacios.
# - __DNI Zero__: Elimina los ceros iniciales de ciertos CUITs para que coincidan con los DNI.
# - __Cuit__: Decisión sobre dejar un cuit o volverlo DNI

# %%
def tipo_doc_1 (string_dni):
    
    if 'DNI' in string_dni:
        tipo = 'DNI'
    
    elif 'LC' in string_dni:
        tipo = 'LC'
    
    elif 'LE' in string_dni:
        tipo = 'LE'
    
    elif 'DNIE' in string_dni:
        tipo = 'DNIE'    
    
    elif ((string_dni.startswith(('CUIT30','CUIT33','CUIT34'))) & (len(string_dni)>8)):
        tipo = 'CUIT'
        
    elif ((string_dni.startswith(('30','33','34'))) & (len(string_dni)>8)):
        tipo = 'CUIT'

    elif ((string_dni.startswith(('20','23','24','27'))) & (len(string_dni)>8)):
        tipo = 'DNI'

    elif ((string_dni.startswith(('CUIT20','CUIT23','CUIT24','CUIT27'))) & (len(string_dni)>8)):
        tipo = 'DNI'
        
    else:
        tipo = 'DNI'
    
    return tipo

# %%
def tipo_doc_2 (string_dni, tipo_original):
    
    if (len(string_dni) > 8) & (tipo_original == 'DNI'):
        tipo = 'CUIT'
    else:
        tipo = tipo_original
    return tipo

# %%
def standard_dni (string_dni):
    """DNI separation by each case.
    """
    
    if 'DNI ' in string_dni:
        dni = string_dni.split('DNI ')[1]
        
    elif 'DNIE' in string_dni:
        dni = string_dni.split('DNIE')[1]
    
    elif 'DNI' in string_dni:
        dni = string_dni.split('DNI')[1]
    
    elif 'LC  ' in string_dni:
        dni = string_dni.split('LC  ')[1]
    
    elif 'LE  ' in string_dni:
        dni = string_dni.split('LE  ')[1]
    
    elif 'CUIT' in string_dni:
        dni = string_dni.split('CUIT')[1]
        
    else:
        dni = string_dni
        
    return dni

# %%
def dni_characters (string_dni):
    
    if ' ' in string_dni:
        dni = string_dni.replace(' ','')
        
    elif '-' in string_dni:
        dni = string_dni.replace('-','')

    else:
        dni = string_dni
    
    return dni

# %%
def cuit (string_dni):
    
    if ((string_dni.startswith('20')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]
        
    elif ((string_dni.startswith('23')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]
        
    elif ((string_dni.startswith('24')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]

    elif ((string_dni.startswith('27')) & (len(string_dni)>8)):
        cuit = string_dni [2:-1]

    else:
        cuit = string_dni
        
    return cuit

# %%
def dni_zero (string_dni):
    
    if string_dni.startswith('0'):
        dni = string_dni [1:]

    else:
        dni = string_dni
    
    return dni

# %% [markdown]
# En primer lugar, trimmeamos los espacios que sobran:

# %%
df_pyp['NRO_DOC'] = [(str(df_pyp['NRO_DOC'][i]).strip()) for i in range (df_pyp['NRO_DOC'].count())]

# %% [markdown]
# Se implementan estas funciones:

# %% [markdown]
# Para determinar el __TIPO DE DOCUMENTO__ en primer lugar:

# %%
df_pyp['TIPO_DOC'] = [tipo_doc_1(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %% [markdown]
# Para la limpieza de DNIs:

# %%
df_pyp['NRO_DOC'] = [standard_dni(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %%
df_pyp['NRO_DOC'] = [dni_characters(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %%
df_pyp['NRO_DOC'] = [cuit(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %%
df_pyp['NRO_DOC'] = [dni_zero(df_pyp['NRO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %% [markdown]
# Para corregir el __TIPO DE DOCUMENTO__ sobre el dataframe resultante

# %%
df_pyp['TIPO_DOC'] = [tipo_doc_2(df_pyp['NRO_DOC'][i],df_pyp['TIPO_DOC'][i]) for i in range (df_pyp['NRO_DOC'].count())]

# %%
df_pyp.head()
# Out:
#              IDMOROSO             IDCLIENTE   NRO_DOC TIPO_DOC
# 0  DNI 14384837        FRANCES_2012          14384837      DNI
# 1  DNI 33803357        FRANCES_2012          33803357      DNI
# 2  DNI 34570749        FRANCES_2012          34570749      DNI
# 3  DNI 36991995        FRANCES_2012          36991995      DNI
# 4  DNI 40359046        FRANCES_2012          40359046      DNI

# %%
df_pyp.tail()
# Out:
#                IDMOROSO             IDCLIENTE   NRO_DOC TIPO_DOC
# 691  DNI 24191912        FRAVEGA_LEGALES548    24191912      DNI
# 692  DNI 26763078        FRAVEGA_LEGALES548    26763078      DNI
# 693  DNI 14129384        FRAVEGA_LEGALES548    14129384      DNI
# 694  DNI 16490348        FRAVEGA_LEGALES548    16490348      DNI
# 695  DNI 21385894        FRAVEGA_LEGALES548    21385894      DNI

# %% [markdown]
# # 13) Union de Dataframes

# %% [markdown]
# Se unen ambos dataframes en la columna NRO_DOC

# %% [markdown]
# Convertimos la columna NRO_DOC de objeto a INT para hacer la unión

# %%
df_clean = df_clean.astype({'NRO_DOC': 'str'})

# %%
df_clean ['NRO_DOC'] = df_clean ['NRO_DOC'].str.split('.').str[0]

# %%
df_union = pd.merge(df_clean,df_pyp, on='NRO_DOC', how='inner')

# %%
df_union.shape
# Out:
# (1931, 16)

# %%
df_union.head()
# Out:
#       CUIT_CUIL  NRO_DOC                      Titular          Dato  \
# 0  2.704172e+10  4171534  ITUARTE MARGARITA HORTENSIA  1.142090e+09
# 1  2.704172e+10  4171534  ITUARTE MARGARITA HORTENSIA  1.146872e+09
# 2  2.704172e+10  4171534  ITUARTE MARGARITA HORTENSIA  1.161079e+09
# 3  2.004174e+10  4173550        VISCONTI EDUARDO JUAN  1.143729e+09
# 4  2.004174e+10  4173550        VISCONTI EDUARDO JUAN  1.136028e+09
#
#   PROPIETARIO_DATO PROVEEDOR_DATO         TIPO   SUBTIPO  SCORE_DATO  \
# 0           Propio             AD     TEL.FIJO  PERSONAL         2.0
# 1           Propio             AD     TEL.FIJO  PERSONAL         2.0
# 2           Propio             AD  TEL.CELULAR  PERSONAL         2.0
# 3           Propio             AD     TEL.FIJO  PERSONAL         2.0
# 4           Propio             AD  TEL.CELULAR  PERSONAL         2.0
#
#           FECHA_INGRESO_DATO  VERIFICADO  FECHA_VERIFICACION  \
# 0 2021-03-18 13:13:26.505652           0                 NaN
# 1 2021-03-18 13:13:26.505652           0                 NaN
# 2 2021-03-18 13:13:26.505652           0                 NaN
# 3 2021-03-18 13:13:26.505652           0                 NaN
# 4 2021-03-18 13:13:26.505652           0                 NaN
#
#    OPERADOR_VERIFICACION            IDMOROSO             IDCLIENTE TIPO_DOC
# 0                    NaN  DNI 4171534         FRAVEGA_LEGALES548        DNI
# 1                    NaN  DNI 4171534         FRAVEGA_LEGALES548        DNI
# 2                    NaN  DNI 4171534         FRAVEGA_LEGALES548        DNI
# 3                    NaN  RMS379977155103007  AMEX_TNLM                 DNI
# 4                    NaN  RMS379977155103007  AMEX_TNLM                 DNI

# %% [markdown]
# # 14) Export

# %% [markdown]
# Renombramos, dropeamos y reordenamos las columnas

# %%
df_union = df_union.rename(columns = {'Dato':'DATO'})

# %% [markdown]
# Dropeamos columnas que no nos sirven

# %%
df_export = df_union.drop(columns=['IDCLIENTE'], axis=0)

# %%
df_export = df_export[['IDMOROSO', 'TIPO_DOC','NRO_DOC','CUIT_CUIL','TIPO','SUBTIPO','DATO','PROPIETARIO_DATO','PROVEEDOR_DATO','FECHA_INGRESO_DATO','VERIFICADO','FECHA_VERIFICACION','OPERADOR_VERIFICACION','SCORE_DATO']]

# %%
df_export.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC     CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 4171534             DNI  4171534  2.704172e+10     TEL.FIJO  PERSONAL
# 1  DNI 4171534             DNI  4171534  2.704172e+10     TEL.FIJO  PERSONAL
# 2  DNI 4171534             DNI  4171534  2.704172e+10  TEL.CELULAR  PERSONAL
# 3  RMS379977155103007      DNI  4173550  2.004174e+10     TEL.FIJO  PERSONAL
# 4  RMS379977155103007      DNI  4173550  2.004174e+10  TEL.CELULAR  PERSONAL
#
#            DATO PROPIETARIO_DATO PROVEEDOR_DATO         FECHA_INGRESO_DATO  \
# 0  1.142090e+09           Propio             AD 2021-03-18 13:13:26.505652
# 1  1.146872e+09           Propio             AD 2021-03-18 13:13:26.505652
# 2  1.161079e+09           Propio             AD 2021-03-18 13:13:26.505652
# 3  1.143729e+09           Propio             AD 2021-03-18 13:13:26.505652
# 4  1.136028e+09           Propio             AD 2021-03-18 13:13:26.505652
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         2.0
# 2           0                 NaN                    NaN         2.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0

# %%
#df_export.to_csv('test.csv')

# %%
df_export.shape
# Out:
# (1931, 14)

# %%
#df_export['DATO'] = [(str(int(round(df_export['DATO'][i],0)))) for i in range (df_export['DATO'].count())]
df_export ['DATO'] = df_export ['DATO'].astype(str)
df_export ['DATO'] = df_export ['DATO'].str.strip()
df_export ['DATO'] = df_export ['DATO'].str.split('.').str[0]

# %%
df_export['CUIT_CUIL'] = [(str(int(round(df_export['CUIT_CUIL'][i],0)))) for i in range (df_export['CUIT_CUIL'].count())]

# %%
df_export.head()
# Out:
#              IDMOROSO TIPO_DOC  NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 1  DNI 4171534             DNI  4171534  27041715346     TEL.FIJO  PERSONAL
# 2  DNI 4171534             DNI  4171534  27041715346  TEL.CELULAR  PERSONAL
# 3  RMS379977155103007      DNI  4173550  20041735504     TEL.FIJO  PERSONAL
# 4  RMS379977155103007      DNI  4173550  20041735504  TEL.CELULAR  PERSONAL
#
#          DATO PROPIETARIO_DATO PROVEEDOR_DATO         FECHA_INGRESO_DATO  \
# 0  1142089570           Propio             AD 2021-03-18 13:13:26.505652
# 1  1146871791           Propio             AD 2021-03-18 13:13:26.505652
# 2  1161078686           Propio             AD 2021-03-18 13:13:26.505652
# 3  1143729113           Propio             AD 2021-03-18 13:13:26.505652
# 4  1136028479           Propio             AD 2021-03-18 13:13:26.505652
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# 0           0                 NaN                    NaN         2.0
# 1           0                 NaN                    NaN         2.0
# 2           0                 NaN                    NaN         2.0
# 3           0                 NaN                    NaN         2.0
# 4           0                 NaN                    NaN         2.0

# %%
df_duplicates = df_export[df_export.duplicated(keep=False)]

# %%
df_duplicates
# Out:
#                 IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO  \
# 544   RMS376411252931006      DNI  25001881  23250018819     TEL.FIJO
# 545   RMS376411252931006      DNI  25001881  23250018819     TEL.FIJO
# 546   RMS376411252931006      DNI  25001881  23250018819     TEL.FIJO
# 589   RMS376685543861003      DNI  26153353  27261533532  TEL.CELULAR
# 590   RMS376685543861003      DNI  26153353  27261533532  TEL.CELULAR
# 1037  DNI 39962676            DNI  39962676  27399626760     TEL.FIJO
# 1038  DNI 39962676            DNI  39962676  27399626760     TEL.FIJO
# 1039  DNI 39962676            DNI  39962676  27399626760     TEL.FIJO
# 1054  DNI 40370532            DNI  40370532  20403705323     TEL.FIJO
# 1055  DNI 40370532            DNI  40370532  20403705323     TEL.FIJO
# 1106  DNI 41352357            DNI  41352357  27413523570     TEL.FIJO
# 1107  DNI 41352357            DNI  41352357  27413523570     TEL.FIJO
# 1342  DNI 24102297            DNI  24102297  27241022973     TEL.FIJO
# 1343  DNI 24102297            DNI  24102297  27241022973     TEL.FIJO
# 1371  RMS376711639474004      DNI  25324540  23253245409     TEL.FIJO
# 1372  RMS376711639474004      DNI  25324540  23253245409     TEL.FIJO
# 1373  RMS376711639474004      DNI  25324540  23253245409     TEL.FIJO
# 1378  RMS379977408044008      DNI  25440331  20254403319     TEL.FIJO
# 1379  RMS379977408044008      DNI  25440331  20254403319     TEL.FIJO
# 1380  RMS379977408044008      DNI  25440331  20254403319     TEL.FIJO
# 1609  DNI 38594992            DNI  38594992  20385949929     TEL.FIJO
# 1610  DNI 38594992            DNI  38594992  20385949929     TEL.FIJO
# 1651  DNI 41171320            DNI  41171320  27411713208     TEL.FIJO
# 1652  DNI 41171320            DNI  41171320  27411713208     TEL.FIJO
# 1718  DNI 30656231            DNI  30656231  20306562313     TEL.FIJO
# 1719  DNI 30656231            DNI  30656231  20306562313     TEL.FIJO
# 1720  DNI 30656231            DNI  30656231  20306562313     TEL.FIJO
# 1725  DNI 32886533            DNI  32886533  20328865336     TEL.FIJO
# 1727  DNI 32886533            DNI  32886533  20328865336     TEL.FIJO
# 1728  DNI 34273495            DNI  34273495  20342734953     TEL.FIJO
# 1729  DNI 34273495            DNI  34273495  20342734953     TEL.FIJO
#
#        SUBTIPO        DATO PROPIETARIO_DATO PROVEEDOR_DATO  \
# 544    LABORAL  1149190959  Ajeno_empleador             AD
# 545    LABORAL  1149190959  Ajeno_empleador             AD
# 546    LABORAL  1149190959  Ajeno_empleador             AD
# 589   PERSONAL  3487508591           Propio             AD
# 590   PERSONAL  3487508591           Propio             AD
# 1037   LABORAL  2214250880  Ajeno_empleador             AD
# 1038   LABORAL  2214250880  Ajeno_empleador             AD
# 1039   LABORAL  2214250880  Ajeno_empleador             AD
# 1054   LABORAL  2614294885  Ajeno_empleador             AD
# 1055   LABORAL  2614294885  Ajeno_empleador             AD
# 1106   LABORAL  1141322200  Ajeno_empleador             AD
# 1107   LABORAL  1141322200  Ajeno_empleador             AD
# 1342   LABORAL  1146363991  Ajeno_empleador             AD
# 1343   LABORAL  1146363991  Ajeno_empleador             AD
# 1371   LABORAL  3414570678  Ajeno_empleador             AD
# 1372   LABORAL  3414570678  Ajeno_empleador             AD
# 1373   LABORAL  3414570678  Ajeno_empleador             AD
# 1378   LABORAL  1147471023  Ajeno_empleador             AD
# 1379   LABORAL  1147471023  Ajeno_empleador             AD
# 1380   LABORAL  1147471023  Ajeno_empleador             AD
# 1609   LABORAL  2644912660  Ajeno_empleador             AD
# 1610   LABORAL  2644912660  Ajeno_empleador             AD
# 1651   LABORAL  1147650689  Ajeno_empleador             AD
# 1652   LABORAL  1147650689  Ajeno_empleador             AD
# 1718   LABORAL  3514557965  Ajeno_empleador             AD
# 1719   LABORAL  3514557965  Ajeno_empleador             AD
# 1720   LABORAL  3514557965  Ajeno_empleador             AD
# 1725   LABORAL  1145224374  Ajeno_empleador             AD
# 1727   LABORAL  1145224374  Ajeno_empleador             AD
# 1728   LABORAL  3541436079  Ajeno_empleador             AD
# 1729   LABORAL  3541436079  Ajeno_empleador             AD
#
#              FECHA_INGRESO_DATO  VERIFICADO  FECHA_VERIFICACION  \
# 544  2021-03-18 13:13:26.505652           0                 NaN
# 545  2021-03-18 13:13:26.505652           0                 NaN
# 546  2021-03-18 13:13:26.505652           0                 NaN
# 589  2021-03-18 13:13:26.505652           0                 NaN
# 590  2021-03-18 13:13:26.505652           0                 NaN
# 1037 2021-03-18 13:13:26.505652           0                 NaN
# 1038 2021-03-18 13:13:26.505652           0                 NaN
# 1039 2021-03-18 13:13:26.505652           0                 NaN
# 1054 2021-03-18 13:13:26.505652           0                 NaN
# 1055 2021-03-18 13:13:26.505652           0                 NaN
# 1106 2021-03-18 13:13:26.505652           0                 NaN
# 1107 2021-03-18 13:13:26.505652           0                 NaN
# 1342 2021-03-18 13:13:26.505652           0                 NaN
# 1343 2021-03-18 13:13:26.505652           0                 NaN
# 1371 2021-03-18 13:13:26.505652           0                 NaN
# 1372 2021-03-18 13:13:26.505652           0                 NaN
# 1373 2021-03-18 13:13:26.505652           0                 NaN
# 1378 2021-03-18 13:13:26.505652           0                 NaN
# 1379 2021-03-18 13:13:26.505652           0                 NaN
# 1380 2021-03-18 13:13:26.505652           0                 NaN
# 1609 2021-03-18 13:13:26.505652           0                 NaN
# 1610 2021-03-18 13:13:26.505652           0                 NaN
# 1651 2021-03-18 13:13:26.505652           0                 NaN
# 1652 2021-03-18 13:13:26.505652           0                 NaN
# 1718 2021-03-18 13:13:26.505652           0                 NaN
# 1719 2021-03-18 13:13:26.505652           0                 NaN
# 1720 2021-03-18 13:13:26.505652           0                 NaN
# 1725 2021-03-18 13:13:26.505652           0                 NaN
# 1727 2021-03-18 13:13:26.505652           0                 NaN
# 1728 2021-03-18 13:13:26.505652           0                 NaN
# 1729 2021-03-18 13:13:26.505652           0                 NaN
#
#       OPERADOR_VERIFICACION  SCORE_DATO
# 544                     NaN         1.0
# 545                     NaN         1.0
# 546                     NaN         1.0
# 589                     NaN         2.0
# 590                     NaN         2.0
# 1037                    NaN         1.0
# 1038                    NaN         1.0
# 1039                    NaN         1.0
# 1054                    NaN         1.0
# 1055                    NaN         1.0
# 1106                    NaN         1.0
# 1107                    NaN         1.0
# 1342                    NaN         1.0
# 1343                    NaN         1.0
# 1371                    NaN         1.0
# 1372                    NaN         1.0
# 1373                    NaN         1.0
# 1378                    NaN         1.0
# 1379                    NaN         1.0
# 1380                    NaN         1.0
# 1609                    NaN         1.0
# 1610                    NaN         1.0
# 1651                    NaN         1.0
# 1652                    NaN         1.0
# 1718                    NaN         1.0
# 1719                    NaN         1.0
# 1720                    NaN         1.0
# 1725                    NaN         1.0
# 1727                    NaN         1.0
# 1728                    NaN         1.0
# 1729                    NaN         1.0

# %%
df_export = df_export.drop_duplicates()

# %%
df_export.shape
# Out:
# (1913, 14)

# %% [markdown]
# ## Dato a str + strip()

# %%
df_export ['DATO'] = df_export['DATO'].str.strip()

# %% [markdown]
# # Revisión de duplicados

# %%
duplicates_subset = df_export[df_export.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
duplicates_subset
# Out:
#                 IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO  \
# 7     DNI 4553548             DNI   4553548  27045535482     TEL.FIJO
# 10    DNI 4553548             DNI   4553548  27045535482     TEL.FIJO
# 16    RMS376710296861008      DNI   5255032  27052550322     TEL.FIJO
# 17    RMS376710296861008      DNI   5255032  27052550322     TEL.FIJO
# 18    DNI 5592216             DNI   5592216  27055922166     TEL.FIJO
# ...                  ...      ...       ...          ...          ...
# 1548  DNI 34768962            DNI  34768962  27347689624  TEL.CELULAR
# 1549  DNI 34768962            DNI  34768962  27347689624  TEL.CELULAR
# 1550  DNI 34768962            DNI  34768962  27347689624  TEL.CELULAR
# 1820  DNI 41106748            DNI  41106748  27411067489     TEL.FIJO
# 1821  DNI 41106748            DNI  41106748  27411067489     TEL.FIJO
#
#        SUBTIPO        DATO PROPIETARIO_DATO PROVEEDOR_DATO  \
# 7     PERSONAL  1142275223           Propio             AD
# 10    PERSONAL  1142275223   Ajeno_familiar             AD
# 16    PERSONAL  1147745633           Propio             AD
# 17    PERSONAL  1147745633   Ajeno_familiar             AD
# 18    PERSONAL  1144623807           Propio             AD
# ...        ...         ...              ...            ...
# 1548  PERSONAL  3516226829   Ajeno_familiar             AD
# 1549  PERSONAL  3516752589   Ajeno_familiar             AD
# 1550  PERSONAL  3512489208   Ajeno_familiar             AD
# 1820  PERSONAL  1142676535   Ajeno_familiar             AD
# 1821  PERSONAL  1142676535            Ajeno             AD
#
#              FECHA_INGRESO_DATO  VERIFICADO  FECHA_VERIFICACION  \
# 7    2021-03-18 13:13:26.505652           0                 NaN
# 10   2021-03-18 13:13:26.505652           0                 NaN
# 16   2021-03-18 13:13:26.505652           0                 NaN
# 17   2021-03-18 13:13:26.505652           0                 NaN
# 18   2021-03-18 13:13:26.505652           0                 NaN
# ...                         ...         ...                 ...
# 1548 2021-03-18 13:13:26.505652           0                 NaN
# 1549 2021-03-18 13:13:26.505652           0                 NaN
# 1550 2021-03-18 13:13:26.505652           0                 NaN
# 1820 2021-03-18 13:13:26.505652           0                 NaN
# 1821 2021-03-18 13:13:26.505652           0                 NaN
#
#       OPERADOR_VERIFICACION  SCORE_DATO
# 7                       NaN         2.0
# 10                      NaN         2.0
# 16                      NaN         2.0
# 17                      NaN         2.0
# 18                      NaN         2.0
# ...                     ...         ...
# 1548                    NaN         2.0
# 1549                    NaN         2.0
# 1550                    NaN         2.0
# 1820                    NaN         2.0
# 1821                    NaN         2.0
#
# [234 rows x 14 columns]

# %% [markdown]
# Tenemos duplicados en la tríada IDMOROSO-DATO-PROVEEDOR_DATO. Exportamos e inicializamos el pipeline de duplicados:

# %% [markdown]
# ## Insert a tabla DAM_CONTACTABILIDAD:

# %%
#df_export.to_excel('D:\MOPC\Enriquecimiento de Datos\Data Cleaning\PyP\Exports\DAM_CONTACTABILIDAD\PyP_DAM_CONTACTABILIDAD_telefonos_refuerzo.xlsx',index=False)
#df_export.to_csv('D:\MOPC\Enriquecimiento de Datos\Data Cleaning\PyP\Exports\DAM_CONTACTABILIDAD\PyP_DAM_CONTACTABILIDAD_telefonos_refuerzo.csv',index=False)

# %% [markdown]
# # Export a Pipeline: Duplicados

# %%
df_export.to_csv('/mnt/c/users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Insiders/Datasets/Datos duplicados/Insiders_telefonos_1803_duplicados.csv',index=False)
