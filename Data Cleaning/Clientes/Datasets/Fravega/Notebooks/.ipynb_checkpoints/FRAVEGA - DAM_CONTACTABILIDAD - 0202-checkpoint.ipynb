# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Clientes/Fravega/Datasets/Fravega 548.xlsx')

# %%
df.head()
# Out:
#   TipoDocu  NumeDocu  NumeCuenta  Entid  Sucur   Pmipes  FechaAlta FechaVenci  \
# 0        D  29272432      445801    300    143   722796 2015-06-10 2021-04-30
# 1        D  24321733      836700    300    570  2126570 2018-08-16 2021-05-19
# 2        D  22370545      897308    300    570  2916891 2019-01-15 2021-01-20
# 3        D  39470038      903608    300      7   294555 2019-07-16 2021-04-30
# 4        D   5393989    39759292    400      7  3786912 1998-01-15 2021-04-30
#
#      Pesos  Cancuo  ...  FechaPaseLegal  FechaPaseCobra  Vended  Respue Forma  \
# 0   939634       1  ...      2020-04-28      2020-11-06       0      SA   NaN
# 1  2764541       1  ...      2019-10-29      2020-07-06       0      SA   NaN
# 2  3791958       1  ...      2019-09-29      2020-07-06       0      SA   NaN
# 3   382921       1  ...      2020-04-28      2020-11-06       0      SA   NaN
# 4  4922985       1  ...      2020-04-28      2020-11-06       0      SA   NaN
#
# ...

# %% [markdown]
# ## Dataframe reducido

# %%
df_reduced = df [['Cuit','Nombre','TipoDocu','NumeDocu','Refno1','Area1','Prefij1','Refte1','Refno2','Area2','Prefij2','Refte2']]

# %%
df_reduced.head()
# Out:
#           Cuit                        Nombre TipoDocu  NumeDocu  \
# 0  27292724328      BATTAGLIA ANGELA BEATRIZ        D  29272432
# 1  23243217334              VELAZQUEZ CARINA        D  24321733
# 2  27223705451  QUINTEROS MARCELA EVANGELINA        D  22370545
# 3  27394700385     MONTENEGRO MAYRA MACARENA        D  39470038
# 4  23053939899           MONJES MIGUEL ANGEL        D   5393989
#
#                            Refno1  Area1  Prefij1      Refte1  \
# 0                          SUSANA   11.0      0.0  20074277.0
# 1                             NaN    NaN      NaN         NaN
# 2                             NaN    NaN      NaN         NaN
# 3                         CLAUDIA   11.0      0.0  40407062.0
# 4  HECTOR ANSELUGHI 394-7649/7847    NaN      NaN         NaN
#
#                   Refno2  Area2  Prefij2      Refte2
# 0                  NADIA   11.0      0.0  42683497.0
# 1                    NaN    NaN      NaN         NaN
# ...

# %%
df_reduced['Refno1'].unique()
# Out:
# array(['SUSANA', nan, 'CLAUDIA', 'HECTOR ANSELUGHI 394-7649/7847',
#        'LAURA', 'SR MARIO HERMANO', 'HIJA ANDREA', 'SRA MIRTA GIMENEZ',
#        'CUNADA SARA', 'VANESA', 'JUAN TIO', 'CASTILLO CLAUDIA MAMA',
#        'GUSTAVO CNERO', 'LEONARDO', 'ALICIA', 'ZULEMA MORENO HNA',
#        'DANIELA', 'GABRIELA CUNADA', 'SRA.SARA', 'GISELLE NOVIA',
#        'ROSARIO-AMIGA', 'VIVIANA HIJA', 'PAOLA VECINA', 'LETICIA',
#        'DUARTE ANIBAL', 'SUSANA O NATALIA', 'CARMEN ABUELA',
#        'MARCOS (FLIAR)', 'DIEGO', 'MABEL PIANTELLI MAMA',
#        'SUSANA-PUNZI-HNA OK', 'SOLEDAD LUGO S', 'OLGA -MAMA-',
#        'SUSANA COMPA ERA', 'MIGUEL PRIMO', 'TIA RAQUEL', 'ISABEL -VECINA',
#        'MAGALI', 'AIDE', 'ELODIA', 'RAUL', 'GABRIELA', 'ALEJANDRINA',
#        'NUERA LORENA', 'SRA MONICA', 'FACUNDA ORTEGA', 'MARI',
#        'WALTER CONOCIDO', 'TERESA', 'PAULINA SERRANO', 'GLADIS',
#        'JOSEFINA CASTILLO', 'ESTELA AMIGA', 'DENISE', 'FLIA SUAREZ',
# ...

# %%
df_reduced['TipoDocu'].unique()
# Out:
# array(['D'], dtype=object)

# %%
df_reduced ['TIPO_DOC'] = 'DNI'
# Out:
# <ipython-input-8-1c9465a49d1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['TIPO_DOC'] = 'DNI'

# %%
df_reduced.head()
# Out:
#           Cuit                        Nombre TipoDocu  NumeDocu  \
# 0  27292724328      BATTAGLIA ANGELA BEATRIZ        D  29272432
# 1  23243217334              VELAZQUEZ CARINA        D  24321733
# 2  27223705451  QUINTEROS MARCELA EVANGELINA        D  22370545
# 3  27394700385     MONTENEGRO MAYRA MACARENA        D  39470038
# 4  23053939899           MONJES MIGUEL ANGEL        D   5393989
#
#                            Refno1  Area1  Prefij1      Refte1  \
# 0                          SUSANA   11.0      0.0  20074277.0
# 1                             NaN    NaN      NaN         NaN
# 2                             NaN    NaN      NaN         NaN
# 3                         CLAUDIA   11.0      0.0  40407062.0
# 4  HECTOR ANSELUGHI 394-7649/7847    NaN      NaN         NaN
#
#                   Refno2  Area2  Prefij2      Refte2 TIPO_DOC
# 0                  NADIA   11.0      0.0  42683497.0      DNI
# 1                    NaN    NaN      NaN         NaN      DNI
# ...

# %%
df_reduced ['NumeDocu'] = df_reduced['NumeDocu'].astype(str)
# Out:
# <ipython-input-10-33b1558d52a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['NumeDocu'] = df_reduced['NumeDocu'].astype(str)

# %% [markdown]
# ### Generación de IDMOROSO

# %%
df_reduced ['IDMOROSO'] = df_reduced ['TIPO_DOC'] + " " + df_reduced ['NumeDocu']
# Out:
# <ipython-input-11-b323cf1063ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['IDMOROSO'] = df_reduced ['TIPO_DOC'] + " " + df_reduced ['NumeDocu']

# %%
df_reduced.head()
# Out:
#           Cuit                        Nombre TipoDocu  NumeDocu  \
# 0  27292724328      BATTAGLIA ANGELA BEATRIZ        D  29272432
# 1  23243217334              VELAZQUEZ CARINA        D  24321733
# 2  27223705451  QUINTEROS MARCELA EVANGELINA        D  22370545
# 3  27394700385     MONTENEGRO MAYRA MACARENA        D  39470038
# 4  23053939899           MONJES MIGUEL ANGEL        D   5393989
#
#                            Refno1  Area1  Prefij1      Refte1  \
# 0                          SUSANA   11.0      0.0  20074277.0
# 1                             NaN    NaN      NaN         NaN
# 2                             NaN    NaN      NaN         NaN
# 3                         CLAUDIA   11.0      0.0  40407062.0
# 4  HECTOR ANSELUGHI 394-7649/7847    NaN      NaN         NaN
#
#                   Refno2  Area2  Prefij2      Refte2 TIPO_DOC      IDMOROSO
# 0                  NADIA   11.0      0.0  42683497.0      DNI  DNI 29272432
# ...

# %% [markdown]
# ### Concatenación de los campos de teléfono

# %%
df_reduced ['Area1'] = df_reduced['Area1'].astype(str)
df_reduced ['Area2'] = df_reduced['Area2'].astype(str)

df_reduced ['Prefij1'] = df_reduced['Prefij1'].astype(str)
df_reduced ['Prefij2'] = df_reduced['Prefij2'].astype(str)

df_reduced ['Refte1'] = df_reduced['Refte1'].astype(str)
df_reduced ['Refte2'] = df_reduced['Refte2'].astype(str)

df_reduced ['Cuit'] = df_reduced['Cuit'].astype(str)
# Out:
# <ipython-input-13-2d5627a2a732>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['Area1'] = df_reduced['Area1'].astype(str)
# <ipython-input-13-2d5627a2a732>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['Area2'] = df_reduced['Area2'].astype(str)
# <ipython-input-13-2d5627a2a732>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_reduced.loc[df_reduced ['Area1'] == 'nan', 'Area1'] = np.nan
df_reduced.loc[df_reduced ['Area2'] == 'nan', 'Area2'] = np.nan

df_reduced.loc[df_reduced ['Prefij1'] == 'nan', 'Prefij1'] = np.nan
df_reduced.loc[df_reduced ['Prefij2'] == 'nan', 'Prefij2'] = np.nan

df_reduced.loc[df_reduced ['Refte1'] == 'nan', 'Refte1'] = np.nan
df_reduced.loc[df_reduced ['Refte2'] == 'nan', 'Refte2'] = np.nan

df_reduced.loc[df_reduced ['Cuit'] == 'nan', 'Cuit'] = np.nan
# Out:
# /home/dleg/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_reduced.head()
# Out:
#           Cuit                        Nombre TipoDocu  NumeDocu  \
# 0  27292724328      BATTAGLIA ANGELA BEATRIZ        D  29272432
# 1  23243217334              VELAZQUEZ CARINA        D  24321733
# 2  27223705451  QUINTEROS MARCELA EVANGELINA        D  22370545
# 3  27394700385     MONTENEGRO MAYRA MACARENA        D  39470038
# 4  23053939899           MONJES MIGUEL ANGEL        D   5393989
#
#                            Refno1 Area1 Prefij1      Refte1  \
# 0                          SUSANA  11.0     0.0  20074277.0
# 1                             NaN   NaN     NaN         NaN
# 2                             NaN   NaN     NaN         NaN
# 3                         CLAUDIA  11.0     0.0  40407062.0
# 4  HECTOR ANSELUGHI 394-7649/7847   NaN     NaN         NaN
#
#                   Refno2  Area2 Prefij2      Refte2 TIPO_DOC      IDMOROSO
# 0                  NADIA   11.0     0.0  42683497.0      DNI  DNI 29272432
# ...

# %%
df_reduced ['Area1'] = df_reduced ['Area1'].str.split('.').str[0]
df_reduced ['Prefij1'] = df_reduced ['Prefij1'].str.split('.').str[0]
df_reduced ['Refte1'] = df_reduced ['Refte1'].str.split('.').str[0]

df_reduced ['Area2'] = df_reduced ['Area2'].str.split('.').str[0]
df_reduced ['Prefij2'] = df_reduced ['Prefij2'].str.split('.').str[0]
df_reduced ['Refte2'] = df_reduced ['Refte2'].str.split('.').str[0]

df_reduced ['Cuit'] = df_reduced ['Cuit'].str.split('.').str[0]
# Out:
# <ipython-input-16-c3d13822647d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['Area1'] = df_reduced ['Area1'].str.split('.').str[0]
# <ipython-input-16-c3d13822647d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['Prefij1'] = df_reduced ['Prefij1'].str.split('.').str[0]
# <ipython-input-16-c3d13822647d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_reduced.head()
# Out:
#           Cuit                        Nombre TipoDocu  NumeDocu  \
# 0  27292724328      BATTAGLIA ANGELA BEATRIZ        D  29272432
# 1  23243217334              VELAZQUEZ CARINA        D  24321733
# 2  27223705451  QUINTEROS MARCELA EVANGELINA        D  22370545
# 3  27394700385     MONTENEGRO MAYRA MACARENA        D  39470038
# 4  23053939899           MONJES MIGUEL ANGEL        D   5393989
#
#                            Refno1 Area1 Prefij1    Refte1  \
# 0                          SUSANA    11       0  20074277
# 1                             NaN   NaN     NaN       NaN
# 2                             NaN   NaN     NaN       NaN
# 3                         CLAUDIA    11       0  40407062
# 4  HECTOR ANSELUGHI 394-7649/7847   NaN     NaN       NaN
#
#                   Refno2 Area2 Prefij2    Refte2 TIPO_DOC      IDMOROSO
# 0                  NADIA    11       0  42683497      DNI  DNI 29272432
# 1                    NaN   NaN     NaN       NaN      DNI  DNI 24321733
# ...

# %%
df_reduced ['TEL1'] = df_reduced ['Prefij1'] + df_reduced ['Area1'] + df_reduced ['Refte1']
df_reduced ['TEL2'] = df_reduced ['Prefij2'] + df_reduced ['Area2'] + df_reduced ['Refte2']
# Out:
# <ipython-input-18-76caad04e8c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['TEL1'] = df_reduced ['Prefij1'] + df_reduced ['Area1'] + df_reduced ['Refte1']
# <ipython-input-18-76caad04e8c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced ['TEL2'] = df_reduced ['Prefij2'] + df_reduced ['Area2'] + df_reduced ['Refte2']

# %%
df_reduced.head()
# Out:
#           Cuit                        Nombre TipoDocu  NumeDocu  \
# 0  27292724328      BATTAGLIA ANGELA BEATRIZ        D  29272432
# 1  23243217334              VELAZQUEZ CARINA        D  24321733
# 2  27223705451  QUINTEROS MARCELA EVANGELINA        D  22370545
# 3  27394700385     MONTENEGRO MAYRA MACARENA        D  39470038
# 4  23053939899           MONJES MIGUEL ANGEL        D   5393989
#
#                            Refno1 Area1 Prefij1    Refte1  \
# 0                          SUSANA    11       0  20074277
# 1                             NaN   NaN     NaN       NaN
# 2                             NaN   NaN     NaN       NaN
# 3                         CLAUDIA    11       0  40407062
# 4  HECTOR ANSELUGHI 394-7649/7847   NaN     NaN       NaN
#
#                   Refno2 Area2 Prefij2    Refte2 TIPO_DOC      IDMOROSO  \
# 0                  NADIA    11       0  42683497      DNI  DNI 29272432
# 1                    NaN   NaN     NaN       NaN      DNI  DNI 24321733
# ...

# %% [markdown]
# ### Dropeamos y renombramos

# %%
df_reduced = df_reduced.rename(columns = {'NumeDocu':'NRO_DOC','Cuit':'CUIT_CUIL'})

# %%
df_reduced = df_reduced [['IDMOROSO','Nombre','TIPO_DOC','NRO_DOC','CUIT_CUIL','TEL1','TEL2']]

# %%
df_reduced.head()
# Out:
#        IDMOROSO                        Nombre TIPO_DOC   NRO_DOC    CUIT_CUIL  \
# 0  DNI 29272432      BATTAGLIA ANGELA BEATRIZ      DNI  29272432  27292724328
# 1  DNI 24321733              VELAZQUEZ CARINA      DNI  24321733  23243217334
# 2  DNI 22370545  QUINTEROS MARCELA EVANGELINA      DNI  22370545  27223705451
# 3  DNI 39470038     MONTENEGRO MAYRA MACARENA      DNI  39470038  27394700385
# 4   DNI 5393989           MONJES MIGUEL ANGEL      DNI   5393989  23053939899
#
#           TEL1         TEL2
# 0  01120074277  01142683497
# 1          NaN          NaN
# 2          NaN          NaN
# 3  01140407062  02204933146
# 4          NaN          NaN

# %%
df_melt = pd.melt(df_reduced, id_vars=['IDMOROSO','Nombre','TIPO_DOC','NRO_DOC','CUIT_CUIL'], value_vars=['TEL1','TEL2'],value_name='DATO')

# %%
df_melt.head()
# Out:
#        IDMOROSO                        Nombre TIPO_DOC   NRO_DOC    CUIT_CUIL  \
# 0  DNI 29272432      BATTAGLIA ANGELA BEATRIZ      DNI  29272432  27292724328
# 1  DNI 24321733              VELAZQUEZ CARINA      DNI  24321733  23243217334
# 2  DNI 22370545  QUINTEROS MARCELA EVANGELINA      DNI  22370545  27223705451
# 3  DNI 39470038     MONTENEGRO MAYRA MACARENA      DNI  39470038  27394700385
# 4   DNI 5393989           MONJES MIGUEL ANGEL      DNI   5393989  23053939899
#
#   variable         DATO
# 0     TEL1  01120074277
# 1     TEL1          NaN
# 2     TEL1          NaN
# 3     TEL1  01140407062
# 4     TEL1          NaN

# %%
df_melt.shape
# Out:
# (1782, 7)

# %%
df_melt = df_melt.dropna(subset=['DATO'])

# %%
df_melt.shape
# Out:
# (1522, 7)

# %% [markdown]
# ### Propietario del Dato

# %% [markdown]
# En este caso, será "Ajeno_referente"

# %%
df_clean = df_melt.assign(PROPIETARIO_DATO='Ajeno_referente')

# %%
df_clean = df_clean.assign(PROVEEDOR_DATO='C_FRV')

# %%
df_clean = df_clean.assign(TIPO='TEL.CELULAR')

# %%
df_clean = df_clean.assign(SUBTIPO='PERSONAL')

# %%
df_clean = df_clean.drop(columns=['variable'])

# %%
df_clean.head()
# Out:
#        IDMOROSO                     Nombre TIPO_DOC   NRO_DOC    CUIT_CUIL  \
# 0  DNI 29272432   BATTAGLIA ANGELA BEATRIZ      DNI  29272432  27292724328
# 3  DNI 39470038  MONTENEGRO MAYRA MACARENA      DNI  39470038  27394700385
# 5  DNI 23858990           GONZALEZ ROBERTO      DNI  23858990  20238589909
# 6  DNI 13317374             SANTILLAN RAUL      DNI  13317374  23133173749
# 7  DNI 13638460     PALACIOS MIRTA BEATRIZ      DNI  13638460  27136384606
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO         TIPO   SUBTIPO
# 0  01120074277  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 3  01140407062  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 5  01146320827  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 6  01148337361  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 7  01148489425  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL

# %% [markdown]
# # 9) Columna Score

# %% [markdown]
# El campo **Score** se construye en función de los datos obtenidos:
#
# - Nivel 4: Dato que otorga la propia persona.
# - Nivel 3: Dato que otorgan los clientes (los bancos).
# - Nivel 2: Dato que otorga un proveedor externo (Informes Digitales en este caso), con subtipo "Personal".
# - Nivel 1: Dato que otorga un proveedor externo, pero tiene como subtipo "Laboral".

# %%
# Nivel 1: Laboral, proveedor externo.

df_clean.loc[(df_clean['SUBTIPO'] == 'LABORAL') , 'SCORE_DATO'] = 1

# %%
# Nivel 2: Personal, proveedor externo.

df_clean.loc[(df_clean['SUBTIPO'] == 'PERSONAL') , 'SCORE_DATO'] = 2

# %%
df_clean.head()
# Out:
#        IDMOROSO                     Nombre TIPO_DOC   NRO_DOC    CUIT_CUIL  \
# 0  DNI 29272432   BATTAGLIA ANGELA BEATRIZ      DNI  29272432  27292724328
# 3  DNI 39470038  MONTENEGRO MAYRA MACARENA      DNI  39470038  27394700385
# 5  DNI 23858990           GONZALEZ ROBERTO      DNI  23858990  20238589909
# 6  DNI 13317374             SANTILLAN RAUL      DNI  13317374  23133173749
# 7  DNI 13638460     PALACIOS MIRTA BEATRIZ      DNI  13638460  27136384606
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO         TIPO   SUBTIPO  \
# 0  01120074277  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 3  01140407062  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 5  01146320827  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 6  01148337361  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 7  01148489425  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
#
#    SCORE_DATO
# 0         2.0
# 3         2.0
# 5         2.0
# 6         2.0
# 7         2.0

# %% [markdown]
# # 10) Columna Fecha

# %% [markdown]
# Para el campo FECHA_INGRESO_DATO, usamos la fecha en la que se hace la inserción de los datos:

# %%
fecha_ingreso = pd.to_datetime('today')

# %%
df_clean = df_clean.assign(FECHA_INGRESO_DATO=fecha_ingreso)

# %%
df_clean.head()
# Out:
#        IDMOROSO                     Nombre TIPO_DOC   NRO_DOC    CUIT_CUIL  \
# 0  DNI 29272432   BATTAGLIA ANGELA BEATRIZ      DNI  29272432  27292724328
# 3  DNI 39470038  MONTENEGRO MAYRA MACARENA      DNI  39470038  27394700385
# 5  DNI 23858990           GONZALEZ ROBERTO      DNI  23858990  20238589909
# 6  DNI 13317374             SANTILLAN RAUL      DNI  13317374  23133173749
# 7  DNI 13638460     PALACIOS MIRTA BEATRIZ      DNI  13638460  27136384606
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO         TIPO   SUBTIPO  \
# 0  01120074277  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 3  01140407062  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 5  01146320827  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 6  01148337361  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 7  01148489425  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
#
#    SCORE_DATO         FECHA_INGRESO_DATO
# 0         2.0 2021-02-02 14:24:02.126423
# ...

# %% [markdown]
# # 11) Campos adicionales

# %% [markdown]
# Creamos las columnas VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, que en principio van en nulls.

# %%
df_clean['VERIFICADO'] = False

# %%
df_clean['FECHA_VERIFICACION'] = np.nan

# %%
df_clean['OPERADOR_VERIFICACION'] = np.nan

# %%
df_clean.head()
# Out:
#        IDMOROSO                     Nombre TIPO_DOC   NRO_DOC    CUIT_CUIL  \
# 0  DNI 29272432   BATTAGLIA ANGELA BEATRIZ      DNI  29272432  27292724328
# 3  DNI 39470038  MONTENEGRO MAYRA MACARENA      DNI  39470038  27394700385
# 5  DNI 23858990           GONZALEZ ROBERTO      DNI  23858990  20238589909
# 6  DNI 13317374             SANTILLAN RAUL      DNI  13317374  23133173749
# 7  DNI 13638460     PALACIOS MIRTA BEATRIZ      DNI  13638460  27136384606
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO         TIPO   SUBTIPO  \
# 0  01120074277  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 3  01140407062  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 5  01146320827  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 6  01148337361  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
# 7  01148489425  Ajeno_referente          C_FRV  TEL.CELULAR  PERSONAL
#
#    SCORE_DATO         FECHA_INGRESO_DATO  VERIFICADO  FECHA_VERIFICACION  \
# ...

# %%
df_export = df_clean[['IDMOROSO', 'TIPO_DOC','NRO_DOC','CUIT_CUIL','TIPO','SUBTIPO','DATO','PROPIETARIO_DATO','PROVEEDOR_DATO','FECHA_INGRESO_DATO','VERIFICADO','FECHA_VERIFICACION','OPERADOR_VERIFICACION','SCORE_DATO']]

# %%
df_export.head()
# Out:
#        IDMOROSO TIPO_DOC   NRO_DOC    CUIT_CUIL         TIPO   SUBTIPO  \
# 0  DNI 29272432      DNI  29272432  27292724328  TEL.CELULAR  PERSONAL
# 3  DNI 39470038      DNI  39470038  27394700385  TEL.CELULAR  PERSONAL
# 5  DNI 23858990      DNI  23858990  20238589909  TEL.CELULAR  PERSONAL
# 6  DNI 13317374      DNI  13317374  23133173749  TEL.CELULAR  PERSONAL
# 7  DNI 13638460      DNI  13638460  27136384606  TEL.CELULAR  PERSONAL
#
#           DATO PROPIETARIO_DATO PROVEEDOR_DATO         FECHA_INGRESO_DATO  \
# 0  01120074277  Ajeno_referente          C_FRV 2021-02-02 14:24:02.126423
# 3  01140407062  Ajeno_referente          C_FRV 2021-02-02 14:24:02.126423
# 5  01146320827  Ajeno_referente          C_FRV 2021-02-02 14:24:02.126423
# 6  01148337361  Ajeno_referente          C_FRV 2021-02-02 14:24:02.126423
# 7  01148489425  Ajeno_referente          C_FRV 2021-02-02 14:24:02.126423
#
#    VERIFICADO  FECHA_VERIFICACION  OPERADOR_VERIFICACION  SCORE_DATO
# ...

# %%
df_export.shape
# Out:
# (1518, 14)

# %% [markdown]
# ## Duplicados

# %%
df_export = df_export.drop_duplicates()

# %%
df_export.shape
# Out:
# (1518, 14)

# %%
duplicates_subset = df_export[df_export.duplicated(subset=['IDMOROSO','DATO','PROVEEDOR_DATO'],keep=False)]

# %%
duplicates_subset
# Out:
# Empty DataFrame
# Columns: [IDMOROSO, TIPO_DOC, NRO_DOC, CUIT_CUIL, TIPO, SUBTIPO, DATO, PROPIETARIO_DATO, PROVEEDOR_DATO, FECHA_INGRESO_DATO, VERIFICADO, FECHA_VERIFICACION, OPERADOR_VERIFICACION, SCORE_DATO]
# Index: []

# %% [markdown]
# # Export

# %%
df_export.to_excel('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Clientes/Fravega/Exports/DAM_CONTACTABILIDAD/FRV_DAM_CONTACTABILIDAD_telefonos_0202.xlsx',index=False)
df_export.to_csv('/mnt/c/Users/Dleg/Data/MOPC/MOPC/Enriquecimiento de Datos/Data Cleaning/Clientes/Fravega/Exports/DAM_CONTACTABILIDAD/FRV_DAM_CONTACTABILIDAD_telefonos_0202.csv',index=False)
